# %% [markdown]
# ## A Deep Reinforcement Learning Algorithm Based on Push-Relabel to Optimizing Max Flow Problem

# %% [markdown]
# ### Benchmark Instance Info:
#
# c Two-Way Transit Grid Network
# c for Max-Flow
# p max 1026 4096
# n 1 s
# n 1026 t

# %% [markdown]
# ### INPUTS:
#
# There are 5 inputs you are supposed to give at first:
# 3 inputs associated with the algorithm as follows:

# %%
n_neurons=24   # The number of neurons in each layer of neural network: Totally we have 4 layers (2 hidden)

perc_neigb=0.125  #Considered percentage of "max_neighbors" in the network. It should be between 0 and 1.

#AND The total numbers of optimum you want the algorithm finds:

total_optimum= 7 #for this benchmark, 7 optimum points need around 5,300,000 steps (each around 750,000 steps)

# %% [markdown]
# #### And 2 inputs are related to the benchmark instance (located in your users folder)

# %%
#Important: Source has to be Node 0: so modify the instance in this way
import networkx as nx

#1: name of the benchmark instance file
G = nx.DiGraph()

G = nx.read_weighted_edgelist("EX11_Transit_Grid_1026_1_corrected.txt",create_using=nx.DiGraph(), nodetype = int)

#2: source (start), sink (goal) and number of nodes (n_nodes):

goal=1025
start=0
n_nodes=1026

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
import pylab as plt
import pandas as pd
from numpy import random
from scipy import stats


from collections import deque
import random
import time
from scipy.sparse import coo_matrix

import tensorflow as tf
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
keras.__version__
# Out:
# '2.4.0'

# %%
weight=nx.get_edge_attributes(G,'weight')

#A test: : answer=94.0

weight[0,6]
# Out:
# 94.0

# %%
#Looking at the Network

plt.figure(1)
weight = nx.get_edge_attributes(G,'weight')
pos=nx.spring_layout(G)
#nx.draw_circular(G)
plt.figure(3,figsize=(12,12)) 
nx.draw_networkx(G,pos)
#nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
plt.show()
#nx.draw_networkx(G, with_labels=True)

# %%
#edge_list and #labels:

edge_list=G.edges(data = False)
SIZE_MATRIX=7
#edge_list

labels=np.zeros((n_nodes,1))
for i in range(1,n_nodes):
    labels[i]=nx.shortest_path_length(G, source=i, target=goal)
labels[0]=n_nodes

# %%
#The input of NN is the max possible neighbors or percentage of it:

#finding the node with max neigbors

max_neighbors=0
dist_neighbors=[]
for i in range(n_nodes):
    add=0
    neigbor=G.neighbors(i)
    for j in neigbor:
        add+=1
    dist_neighbors.append(add)
    if add>max_neighbors:
        max_neighbors=add

print("max_neighbors=",max_neighbors)
# Out:
# max_neighbors= 32

# %%
# Looking at the distribution of the neighbors

plt.hist(dist_neighbors)

print("mean=",np.mean(dist_neighbors))
print("median=",np.median(dist_neighbors))

mode= stats.mode(dist_neighbors)
print("mode=",int(mode[0]),"count of mode is",int(mode[1]))
# Out:
# mean= 3.992202729044834
# median= 4.0
# mode= 4 count of mode is 960

# %% [markdown]
# Features (length in parentheses):
#
# 	[Number of neighbors of selected active node (1),
#
# 	Excess of selected active node (1),
# 	Label of selected active node (1),
#
# 	Excess of “admissible” neighbors (to the lengths of perc_neigb*max_neighbors: label-ordered),
#
#      Capacity of “admissible” neighbors (to the lengths of perc_neigb*max_neighbors: label-ordered),
# ]
#
# Total lengths=3+2* (perc_neigb*max_neighbors)

# %%
#Considering percentage of "max_neighbors"

max_neighbors=int(np.round(perc_neigb*max_neighbors))

print("max_considering_neighbors=",max_neighbors)
print("input",3+2*max_neighbors)
# Out:
# max_considering_neighbors= 4
# input 11

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Lambda
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import LeakyReLU
    
learning_rate = 0.005
tau = .125
inputs=3+2*max_neighbors

output=1 #all nodes can be selected except source and sink

def build_model(state):
    model = Sequential()
    model.add(Dense(n_neurons,input_shape=(1,inputs), activation=LeakyReLU(alpha=0.1)))
    model.add(Dense(n_neurons, activation=LeakyReLU(alpha=0.1)))
    model.add(Dense(n_neurons, activation=LeakyReLU(alpha=0.1)))
    model.add(Dense(output, activation='relu'))


    model.compile(loss='mean_squared_error',
            optimizer='adam',metrics=['accuracy'])
    return model

# %%
#run once: NN1

state=np.zeros((1,2*n_nodes))

local_state=np.zeros((1,inputs))

weight_copy=weight.copy()
flow=coo_matrix((n_nodes,n_nodes)).toarray()

#pre-process:

for edge in G.edges(): #check edge list
    if edge[0]==0:  #if it emanates from source
        flow[0,edge[1]]=weight_copy[0,edge[1]]  #push all flows from source
              
#Updating Excess and the active nodes
active_nodes=[]
excess=np.zeros((n_nodes,1))

for i in range (1,n_nodes):
        excess[i]=flow[:,i].sum()-flow[i,:].sum()
        if excess[i]>0:
            active_nodes.append(i)

#for example put one in active node:
action=int(np.random.choice(active_nodes,1))

direct=G.neighbors(action) #it is not an array so we have to make an array:

all_neighbors=[]
all_neighbors_labels=[]
for i in direct:
    if labels[action]==labels[i]+1:
        all_neighbors.append(i)
        all_neighbors_labels.append(int(labels[i]))

n_neighbors=len(all_neighbors)
local_state[0,0]=n_neighbors

#sort all_neighbors based on labels:
merge_neighbors=np.stack([all_neighbors,all_neighbors_labels])
merge_neighbors=merge_neighbors.T
merge_neighbors_sorted=merge_neighbors[np.argsort(merge_neighbors[:, 1])]

length_tmt=len(all_neighbors)
range_loop=min(length_tmt,max_neighbors) #since we have sparse matrix, we do not need to calculate all

j=0
for i in range(range_loop):
    j+=1
    local_state[0,2+j]=excess[merge_neighbors_sorted[i,0]]
    #local_state[0,max_neighbors+2+j]=labels[merge_neighbors_sorted[i,0]]
    local_state[0,max_neighbors+2+j]=weight_copy[action,merge_neighbors_sorted[i,0]]
    
local_state[0,1]=excess[action]
local_state[0,2]=labels[action]

# %%
NN1 = build_model(local_state)
Target_NN1 = build_model(local_state)
# Out:
# 2021-09-21 16:32:15.940211: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-21 16:32:15.940404: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
NN1.predict(local_state)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 11) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 11), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 11).
# 2021-09-21 16:32:16.446814: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# array([[57.15601]], dtype=float32)

# %%
NN1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 24)             288
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 24)             600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 24)             600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1)              25
# =================================================================
# Total params: 1,513
# Trainable params: 1,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# RL Algorithm:

# %%
#RL_based Algorithm:


start_time_total = time.time()

n_optimum=0

n_steps=-1
opt_steps=[]
solutions=[]

replay=1
memory = deque(maxlen=replay) # double-ended queue; acts like list, but elements can be added/removed from either end
mem_iter=0 #for memory deque steps

gamma = 0.95 # decay or discount rate: enables agent to take into account future actions in addition to the immediate ones, but discounted at this rate

weight_copy=weight.copy()
labels_copy=labels.copy()

decisions=[]
no_more_active_nodes=[start,goal]    #The nodes that could not be active nodes anymore

flow=coo_matrix((n_nodes,n_nodes)).toarray()

ziter=0   #It is just a measure for NN to see howmany zero predictions will it give finally (less the better)

epsilon = 1 # exploration rate: how much to act randomly; more initially than later due to epsilon decay
epsilon_decay = 0.95 # decrease number of random explorations as the agent's performance (hopefully) improves over time
epsilon_min = 0.01 # minimum amount of random exploration permitted

opt_best=0. #initial opt_best

#PREPROCESSING: pre-push from the source:
for edge in G.edges(): #check edge list
    if edge[0]==0:  #if it emanates from source
        flow[0,edge[1]]=weight_copy[0,edge[1]]  #push all flows from source
        
n_epochs=20 #Training epochs
        
#Updating Excess and the active nodes
active_nodes=[]
excess=np.zeros((n_nodes,1))

for i in range (1,n_nodes):
        excess[i]=flow[:,i].sum()-flow[i,:].sum()
        if excess[i]>0:
            active_nodes.append(i)
excess[0]=0

start_time_optimal = time.time()

#while len(active_nodes)!=0:
while n_optimum<total_optimum:

    n_steps+=1

    
    if n_steps % 500 == 0:
        print("---------------------step=",n_steps,"----------------------")

    #print("----------------step=",n_steps,"------------------")

    
    n_active_nodes=len(active_nodes)

    inputmatrixNN1=np.zeros((n_active_nodes, inputs))
    
    j=0   
    for a in active_nodes:

        local_state=np.zeros((1,inputs))


        direct_action=G.neighbors(a) #it is not an array so we have to make an array:
        all_neighbors=[]
        all_neighbors_labels=[]
        for i in direct_action:
            if labels[a]==labels[i]+1:
                all_neighbors.append(i)
                all_neighbors_labels.append(int(labels[i]))

        
        n_neighbors=len(all_neighbors)
        local_state[0,0]=n_neighbors

        #sort all_neighbors based on labels:
        merge_neighbors=np.stack([all_neighbors,all_neighbors_labels])
        merge_neighbors=merge_neighbors.T
        merge_neighbors_sorted=merge_neighbors[np.argsort(merge_neighbors[:, 1])]
               
        length_tmt=len(all_neighbors)
        range_loop=min(length_tmt,max_neighbors) #since we have sparse matrix, we do not need to calculate all    
            
        z=0
        for i in range(range_loop):
            z+=1
            #local_state[0,z]=merge_neighbors_sorted[i,0]
            local_state[0,2+z]=excess[merge_neighbors_sorted[i,0]]
            #local_state[0,max_neighbors+2+z]=labels[merge_neighbors_sorted[i,0]]
            local_state[0,max_neighbors+2+z]=weight_copy[a,merge_neighbors_sorted[i,0]]

        local_state[0,1]=excess[a]
        local_state[0,2]=labels[a]

        inputmatrixNN1[j]=local_state
        j+=1

        #make prediction"

    if np.random.rand() > epsilon: #just the first round is random

        predictionNN1=NN1.predict(inputmatrixNN1)
        
        if np.sum(predictionNN1)==0:
            ziter+=1
            action=int(np.random.choice(active_nodes,1))
            actiontarget=0
        else:
            action=np.argmax(predictionNN1) #the max probability is the action
            action=active_nodes[action]
            actiontarget=np.max(predictionNN1) #the max achieved

    else:
        action=int(np.random.choice(active_nodes,1))


    direct=G.neighbors(action) #it is not an array so we have to make an array:
    directneigbor=[]
    for i in direct:
        directneigbor.append(i) #so we make an array that contains the neigbors of actions
    
    neigb=nx.all_neighbors(G, action) #ALL NEIGHBORS

    neigbor=[]
    for i in neigb:
        neigbor.append(i) #so we make an array that contains the neigbors of actions
    valid=0 # to see if we can find a destination or not:

    destination=[]
    reward=[]
    d=-1
    for edge in neigbor: #Loop number 
        #destination=edge
        destination_temp=edge

        push_back=0

        if labels_copy[action]-labels_copy[destination_temp]==1: 

            #finding the adjacent of selected active node and
            
            if destination_temp in directneigbor and min(int(excess[action]),weight_copy[action,destination_temp])!=0:
                d+=1
                destination.append(destination_temp)
                rewardtemp=min(int(excess[action]),weight_copy[action,destination_temp])
                reward.append(rewardtemp)
                
                flow[action,destination_temp]=flow[action,destination_temp]+rewardtemp #flow is updated
                weight_copy[action,destination_temp]=weight_copy[action,destination_temp]-rewardtemp   #the weight is updated
                valid=1 #means we could find a destination
                decisions.append([action,destination_temp])
                decisions.append(rewardtemp)
                
                #Updating excess since we want to continue the destinations:
                excess[action]=flow[:,action].sum()-flow[action,:].sum()
            
            elif flow[destination_temp,action]>0:
                d+=1
                destination.append(destination_temp)
                push_back=1 #we know that we push_back
                rewardtemp=min(int(excess[action]),flow[destination_temp,action])
                reward.append(-rewardtemp) #negative since it is push back

                flow[destination_temp,action]=flow[destination_temp,action]-rewardtemp
                weight_copy[destination_temp,action]=weight_copy[destination_temp,action]+rewardtemp
                #weight_copy[action,destination]=weight_copy[action,destination]+reward
                valid=1
                decisions.append([action,destination_temp])
                decisions.append(rewardtemp)
                
                #Updating excess since we want to continue the destinations:
                excess[action]=flow[:,action].sum()-flow[action,:].sum()

    total_push=np.sum(reward)
    if valid ==1:
        
        #print("active:",active_nodes,"reward=",reward,"action",action,"destination",destination\
             # ,"neighb:",all_neighbors,"labels",labels,"state",local_state,"push:",total_push,"back",push_back)

        #Training:

                #Updating active nodes for next step:
        excess[action]=flow[:,action].sum()-flow[action,:].sum()
        
        for i in range(len(destination)):
            excess[destination[i]]=flow[:,destination[i]].sum()-flow[destination[i],:].sum()
            if excess[destination[i]]>0 and destination[i] not in active_nodes\
            and destination[i] not in no_more_active_nodes:
                active_nodes.append(destination[i])
        if excess[action]==0:
            active_nodes.remove(action)
       
    #checking no more active nodes    
        active_nodes=[x for x in active_nodes if x not in no_more_active_nodes]
        
        local_state_action=np.zeros((1,inputs))
        #local_state_action[0,0]=action  too specific for a feature
        
        direct=G.neighbors(action) #it is not an array so we have to make an array:

        all_neighbors=[]
        all_neighbors_labels=[]
        for i in direct:
            if labels[action]==labels[i]+1:
                all_neighbors.append(i)
                all_neighbors_labels.append(int(labels[i]))

        n_neighbors=len(all_neighbors)
        local_state_action[0,0]=n_neighbors
        
        #sort all_neighbors based on labels:
        merge_neighbors=np.stack([all_neighbors,all_neighbors_labels])
        merge_neighbors=merge_neighbors.T
        merge_neighbors_sorted=merge_neighbors[np.argsort(merge_neighbors[:, 1])]

        length_tmt=len(all_neighbors)
        range_loop=min(length_tmt,max_neighbors) #since we have sparse matrix, we do not need to calculate all

        j=0
        for i in range(range_loop):
            j+=1
            #local_state_action[0,j]=merge_neighbors_sorted[i,0]
            local_state_action[0,2+j]=excess[merge_neighbors_sorted[i,0]]
           # local_state_action[0,max_neighbors+2+j]=labels[merge_neighbors_sorted[i,0]]
            local_state_action[0,max_neighbors+2+j]=weight_copy[action,merge_neighbors_sorted[i,0]]

        local_state_action[0,1]=excess[action]
        local_state_action[0,2]=labels[action]
        
        #predicting max of one step forward
        if len(active_nodes)!=0:
            n_active_nodes=len(active_nodes)

            n_active_nodes=len(active_nodes)

            new_inputmatrixNN1=np.zeros((n_active_nodes, inputs))
            j=0

            for a in active_nodes:
                new_local_state=np.zeros((1,inputs))

                direct_action=G.neighbors(a) #it is not an array so we have to make an array:
                all_neighbors=[]
                all_neighbors_labels=[]
                for i in direct_action:
                    if labels[a]==labels[i]+1:
                        all_neighbors.append(i)
                        all_neighbors_labels.append(int(labels[i]))

                n_neighbors=len(all_neighbors)
                new_local_state[0,0]=n_neighbors
                
                #sort all_neighbors based on labels:
                merge_neighbors=np.stack([all_neighbors,all_neighbors_labels])
                merge_neighbors=merge_neighbors.T
                merge_neighbors_sorted=merge_neighbors[np.argsort(merge_neighbors[:, 1])]


                length_tmt=len(all_neighbors)
                range_loop=min(length_tmt,max_neighbors) #since we have sparse matrix, we do not need to calculate all    

                z=0
                for i in range(range_loop):
                    z+=1
                    #new_local_state[0,z]=merge_neighbors_sorted[i,0]
                    new_local_state[0,2+z]=excess[merge_neighbors_sorted[i,0]]
                    #new_local_state[0,max_neighbors+2+z]=labels[merge_neighbors_sorted[i,0]]
                    new_local_state[0,max_neighbors+2+z]=weight_copy[a,merge_neighbors_sorted[i,0]]

                new_local_state[0,1]=excess[a]
                new_local_state[0,2]=labels[a]

                new_inputmatrixNN1[j]=new_local_state
                j+=1
                
                #make prediction
            new_predictionNN1=NN1.predict(new_inputmatrixNN1)

            if np.sum(new_predictionNN1)==0:
                ziter+=1
                next_action=int(np.random.choice(active_nodes,1))
                next_actiontarget=0
            else:
                next_action=np.argmax(new_predictionNN1) #the max probability is the action
                next_action=active_nodes[next_action]

                next_actiontarget=np.max(new_predictionNN1) #the max achieved

            next_direct=G.neighbors(next_action) #it is not an array so we have to make an array:
            next_directneigbor=[]
            for i in next_direct:
                next_directneigbor.append(i) #so we make an array that contains the neigbors of actions

            #max of next reward:
            next_reward=0
            for j in next_directneigbor:
                next_destination=j
                if labels_copy[next_action]-labels_copy[next_destination]==1:
                    temp_reward=min(int(excess[next_action]),weight_copy[next_action,next_destination])
                    next_reward=max(next_reward,temp_reward) 

            #The above is just an approximation of next reward
        else:
            next_reward=0

        #   If push back means when earlier you push flow from destination to action was not good             

        # For Training:              

        memory.append((local_state_action,total_push,action,new_local_state,destination,reward,mem_iter))
        # list of previous experiences, enabling re-training later
        mem_iter+=1

        y_train_NN1=0
        #for local_state_action,total_push,action,new_local_state,destination,reward,mem_iter in memory:
            #print("inside memory:",reward)

        if total_push<0 and next_reward!=0: #means that push_back is based on a wrong decision

            y_train_NN1=(total_push+gamma*next_reward)/2

            push_back=0
        elif total_push<0 and next_reward==0: #means that push_back is good
            total_push=-total_push

            y_train_NN1=(total_push+gamma*next_reward)/2
            push_back=0

        else:
            y_train_NN1=(total_push+gamma*next_reward)/2            

        y_train_NN1=np.atleast_1d(y_train_NN1)

        #memory[0][0] means the first record in memory which is the state_action
        NN1.fit(local_state_action, y_train_NN1, epochs=n_epochs, verbose=0)

        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

        excess[0,0]=0  #to make the states similar together and help NN learn better

    if valid ==0: #means we could not find a destination in the above loop
            labels_copy[action]=max(min(labels_copy[neigbor]),labels_copy[action])+1 
               
            #Updating active nodes:
            excess[action]=flow[:,action].sum()-flow[action,:].sum()
            for i in range(len(destination)):
                excess[destination[i]]=flow[:,destination[i]].sum()-flow[destination[i],:].sum()
                if excess[destination[i]]>0 and destination[i] not in active_nodes\
                and destination[i] not in no_more_active_nodes:
                    active_nodes.append(destination[i])
                    
            if excess[action]==0:
                active_nodes.remove(action)
            
            #checking no more active nodes    
            active_nodes=[x for x in active_nodes if x not in no_more_active_nodes]
            
            excess[0,0]=0   #to make the states similar together and help NN learn better

    if len(active_nodes)==0:
        
        n_optimum+=1
        
        print("The Optimum",int(excess[goal]),"with the decisions of","decisions","Steps=", n_steps)
        process_time_optimal=time.time()-start_time_optimal
        print("process_time_optimal=",process_time_optimal/60)
        
        opt_steps.append(n_steps)
        solutions.append(int(excess[goal]))
        if int(excess[goal])>opt_best:
            opt_best=int(excess[goal])
        

        reward_opt=int(excess[goal])
        print("reward_opt",reward_opt)
            
        weight_copy=weight.copy()
        labels_copy=labels.copy()
        decisions=[]        

        flow=coo_matrix((n_nodes,n_nodes)).toarray()

        for edge in G.edges(): #check edge list
            if edge[0]==0:  #if it emanates from source
                flow[0,edge[1]]=weight_copy[0,edge[1]]  #push all flows from source
        step=0        
        
                    #Updating Excess:
        active_nodes=[]
        for i in range (1,n_nodes):
            excess[i]=flow[:,i].sum()-flow[i,:].sum()
            if excess[i]>0:
                active_nodes.append(i)
        excess[0]=0            
        
        #RESET NN:
        NN1 = build_model(state)
        print("epsilon:",epsilon)
        epsilon = 1 #again the exploration chance.


print("The best try is",opt_best)

process_time_total=time.time()-start_time_total
print("process_time_total=",process_time_total/60)
# Out:
# ---------------------step= 0 ----------------------
# WARNING:tensorflow:Model was constructed with shape (None, 1, 11) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 11), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 11).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 11) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 11), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 11).
# ---------------------step= 500 ----------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/pw/r6v3q3vj2f599vbqg62ld7nhvl0vcf/T/ipykernel_63935/2565465113.py in <module>
#     111     if np.random.rand() > epsilon: #just the first round is random
#     112
# --> 113         predictionNN1=NN1.predict(inputmatrixNN1)
#     114
#     115         if np.sum(predictionNN1)==0:
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1621       self.predict_function = self.make_predict_function()
#    1622       self._predict_counter.assign(0)
# -> 1623       callbacks.on_predict_begin()
#    1624       batch_outputs = None
#    1625       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_predict_begin(self, logs)
#     580       else:
#     581         if numpy_logs is None:  # Only convert once.
# --> 582           numpy_logs = tf_utils.to_numpy_or_python_type(logs)
#     583         callback.on_predict_begin(numpy_logs)
#     584
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#     513
# --> 514   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     515
#     516
#
# KeyboardInterrupt:

# %% [markdown]
# ### Box Plot

# %%
#1: Box Data

#Random Method:
opt_rand=np.array([745151,745836,747195,746732,745993,747102])

opt_RL=[]
opt_RL.append(opt_steps[0])
for i in range(1,len(opt_steps)):
    opt_RL.append(opt_steps[i]-opt_steps[i-1])

box_data=[opt_rand,opt_RL]


#2: Box Plot:

fig = plt.figure()
fig.suptitle('Network with 1026 nodes:', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
box=ax.boxplot(box_data,patch_artist=True,labels=['Random','RL_based'],showmeans=True)

ax.set_title('Feature: excess & label of action, admissible neighbors number and capacities')
ax.set_xlabel('Approaches')
ax.set_ylabel('n_Steps to find optimum')

#colors = ['cyan', 'lightblue', 'lightgreen', 'tan']

colors = ['cyan', 'tan']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
    
plt.show()

print("Rnadom Mean=",np.mean(opt_rand),"RL_based Mean=",np.mean(opt_RL))

print("Rnadom Median=",np.median(opt_rand),"RL_based Median=",np.median(opt_RL))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/pw/r6v3q3vj2f599vbqg62ld7nhvl0vcf/T/ipykernel_63935/310905025.py in <module>
#       5
#       6 opt_RL=[]
# ----> 7 opt_RL.append(opt_steps[0])
#       8 for i in range(1,len(opt_steps)):
#       9     opt_RL.append(opt_steps[i]-opt_steps[i-1])
#
# IndexError: list index out of range

# %% [markdown]
# ### Max Flow Algorithms: Edmonds Karp

# %%
from networkx.algorithms.flow import edmonds_karp
#start_time = time()

result = edmonds_karp(G, 0, 1025,capacity='weight')
flow_value2= nx.maximum_flow_value(G, 0, 1025,capacity='weight')
print("optimal flow from edmonds_karp algorithm is:",flow_value2)

for g in G.edges():
    print("flow of",g," is :",result[g[0]][g[1]]['flow'])

#process_time=time()-start_time
#print("process_time=",process_time)
# Out:
# optimal flow from edmonds_karp algorithm is: 9406.0
# flow of (0, 1)  is : 418.0
# flow of (0, 2)  is : 401.0
# flow of (0, 3)  is : 108.0
# flow of (0, 4)  is : 186.0
# flow of (0, 5)  is : 744.0
# flow of (0, 6)  is : 94.0
# flow of (0, 7)  is : 70.0
# flow of (0, 8)  is : 389.0
# flow of (0, 9)  is : 748.0
# flow of (0, 10)  is : 310.0
# flow of (0, 11)  is : 267.0
# flow of (0, 12)  is : 13.0
# flow of (0, 13)  is : 370.0
# flow of (0, 14)  is : 406.0
# flow of (0, 15)  is : 64.0
# flow of (0, 16)  is : 142.0
# flow of (0, 17)  is : 437.0
# flow of (0, 18)  is : 318.0
# flow of (0, 19)  is : 425.0
# flow of (0, 20)  is : 333.0
# flow of (0, 21)  is : 468.0
# flow of (0, 22)  is : 305.0
# flow of (0, 23)  is : 370.0
# flow of (0, 24)  is : 130.0
# flow of (0, 25)  is : 551.0
# flow of (0, 26)  is : 20.0
# flow of (0, 27)  is : 153.0
# flow of (0, 28)  is : 18.0
# flow of (0, 29)  is : 227.0
# flow of (0, 30)  is : 490.0
# flow of (0, 31)  is : 110.0
# flow of (0, 32)  is : 321.0
# flow of (1, 0)  is : -418.0
# flow of (1, 2)  is : 355.0
# flow of (1, 33)  is : 63.0
# flow of (2, 0)  is : -401.0
# flow of (2, 1)  is : -355.0
# flow of (2, 3)  is : 257.0
# flow of (2, 34)  is : 499.0
# flow of (3, 0)  is : -108.0
# flow of (3, 2)  is : -257.0
# flow of (3, 4)  is : 166.0
# flow of (3, 35)  is : 199.0
# flow of (4, 0)  is : -186.0
# flow of (4, 3)  is : -166.0
# flow of (4, 5)  is : -5.0
# flow of (4, 36)  is : 357.0
# flow of (5, 0)  is : -744.0
# flow of (5, 4)  is : 5.0
# flow of (5, 6)  is : 184.0
# flow of (5, 37)  is : 555.0
# flow of (6, 0)  is : -94.0
# flow of (6, 5)  is : -184.0
# flow of (6, 7)  is : -4.0
# flow of (6, 38)  is : 282.0
# flow of (7, 0)  is : -70.0
# flow of (7, 6)  is : 4.0
# flow of (7, 8)  is : -269.0
# flow of (7, 39)  is : 335.0
# flow of (8, 0)  is : -389.0
# flow of (8, 7)  is : 269.0
# flow of (8, 9)  is : 0
# flow of (8, 40)  is : 120.0
# flow of (9, 0)  is : -748.0
# flow of (9, 8)  is : 0
# flow of (9, 10)  is : 0
# flow of (9, 41)  is : 748.0
# flow of (10, 0)  is : -310.0
# flow of (10, 9)  is : 0
# flow of (10, 11)  is : 0
# flow of (10, 42)  is : 310.0
# flow of (11, 0)  is : -267.0
# flow of (11, 10)  is : 0
# flow of (11, 12)  is : 95.0
# flow of (11, 43)  is : 172.0
# flow of (12, 0)  is : -13.0
# flow of (12, 11)  is : -95.0
# flow of (12, 13)  is : 0
# flow of (12, 44)  is : 108.0
# flow of (13, 0)  is : -370.0
# flow of (13, 12)  is : 0
# flow of (13, 14)  is : 73.0
# flow of (13, 45)  is : 297.0
# flow of (14, 0)  is : -406.0
# flow of (14, 13)  is : -73.0
# flow of (14, 15)  is : 98.0
# flow of (14, 46)  is : 381.0
# flow of (15, 0)  is : -64.0
# flow of (15, 14)  is : -98.0
# flow of (15, 16)  is : 0
# flow of (15, 47)  is : 162.0
# flow of (16, 0)  is : -142.0
# flow of (16, 15)  is : 0
# flow of (16, 17)  is : 0
# flow of (16, 48)  is : 142.0
# flow of (17, 0)  is : -437.0
# flow of (17, 16)  is : 0
# flow of (17, 18)  is : 201.0
# flow of (17, 49)  is : 236.0
# flow of (18, 0)  is : -318.0
# flow of (18, 17)  is : -201.0
# flow of (18, 19)  is : -73.0
# flow of (18, 50)  is : 592.0
# flow of (19, 0)  is : -425.0
# flow of (19, 18)  is : 73.0
# flow of (19, 20)  is : 0
# flow of (19, 51)  is : 352.0
# flow of (20, 0)  is : -333.0
# flow of (20, 19)  is : 0
# flow of (20, 21)  is : 73.0
# flow of (20, 52)  is : 260.0
# flow of (21, 0)  is : -468.0
# flow of (21, 20)  is : -73.0
# flow of (21, 22)  is : 67.0
# flow of (21, 53)  is : 474.0
# flow of (22, 0)  is : -305.0
# flow of (22, 21)  is : -67.0
# flow of (22, 23)  is : -303.0
# flow of (22, 54)  is : 675.0
# flow of (23, 0)  is : -370.0
# flow of (23, 22)  is : 303.0
# flow of (23, 24)  is : 0
# flow of (23, 55)  is : 67.0
# flow of (24, 0)  is : -130.0
# flow of (24, 23)  is : 0
# flow of (24, 25)  is : 0
# flow of (24, 56)  is : 130.0
# flow of (25, 0)  is : -551.0
# flow of (25, 24)  is : 0
# flow of (25, 26)  is : 172.0
# flow of (25, 57)  is : 379.0
# flow of (26, 0)  is : -20.0
# flow of (26, 25)  is : -172.0
# flow of (26, 27)  is : -26.0
# flow of (26, 58)  is : 218.0
# flow of (27, 0)  is : -153.0
# flow of (27, 26)  is : 26.0
# flow of (27, 28)  is : 0
# flow of (27, 59)  is : 127.0
# flow of (28, 0)  is : -18.0
# flow of (28, 27)  is : 0
# flow of (28, 29)  is : 0
# flow of (28, 60)  is : 18.0
# flow of (29, 0)  is : -227.0
# flow of (29, 28)  is : 0
# flow of (29, 30)  is : 0
# flow of (29, 61)  is : 227.0
# flow of (30, 0)  is : -490.0
# flow of (30, 29)  is : 0
# flow of (30, 31)  is : 0
# flow of (30, 62)  is : 490.0
# flow of (31, 0)  is : -110.0
# flow of (31, 30)  is : 0
# flow of (31, 32)  is : 9.0
# flow of (31, 63)  is : 101.0
# flow of (32, 0)  is : -321.0
# flow of (32, 31)  is : -9.0
# flow of (32, 64)  is : 330.0
# flow of (33, 1)  is : -63.0
# flow of (33, 34)  is : -149.0
# flow of (33, 65)  is : 212.0
# flow of (34, 2)  is : -499.0
# flow of (34, 33)  is : 149.0
# flow of (34, 35)  is : 136.0
# flow of (34, 66)  is : 214.0
# flow of (35, 3)  is : -199.0
# flow of (35, 34)  is : -136.0
# flow of (35, 36)  is : -73.0
# flow of (35, 67)  is : 408.0
# flow of (36, 4)  is : -357.0
# flow of (36, 35)  is : 73.0
# flow of (36, 37)  is : -150.0
# flow of (36, 68)  is : 434.0
# flow of (37, 5)  is : -555.0
# flow of (37, 36)  is : 150.0
# flow of (37, 38)  is : 0
# flow of (37, 69)  is : 405.0
# flow of (38, 6)  is : -282.0
# flow of (38, 37)  is : 0
# flow of (38, 39)  is : -248.0
# flow of (38, 70)  is : 530.0
# flow of (39, 7)  is : -335.0
# flow of (39, 38)  is : 248.0
# flow of (39, 40)  is : 21.0
# flow of (39, 71)  is : 66.0
# flow of (40, 8)  is : -120.0
# flow of (40, 39)  is : -21.0
# flow of (40, 41)  is : -48.0
# flow of (40, 72)  is : 189.0
# flow of (41, 9)  is : -748.0
# flow of (41, 40)  is : 48.0
# flow of (41, 42)  is : 4.0
# flow of (41, 73)  is : 696.0
# flow of (42, 10)  is : -310.0
# flow of (42, 41)  is : -4.0
# flow of (42, 43)  is : 31.0
# flow of (42, 74)  is : 283.0
# flow of (43, 11)  is : -172.0
# flow of (43, 42)  is : -31.0
# flow of (43, 44)  is : 0
# flow of (43, 75)  is : 203.0
# flow of (44, 12)  is : -108.0
# flow of (44, 43)  is : 0
# flow of (44, 45)  is : -200.0
# flow of (44, 76)  is : 308.0
# flow of (45, 13)  is : -297.0
# flow of (45, 44)  is : 200.0
# flow of (45, 46)  is : 0
# flow of (45, 77)  is : 97.0
# flow of (46, 14)  is : -381.0
# flow of (46, 45)  is : 0
# flow of (46, 47)  is : 0
# flow of (46, 78)  is : 381.0
# flow of (47, 15)  is : -162.0
# flow of (47, 46)  is : 0
# flow of (47, 48)  is : 0
# flow of (47, 79)  is : 162.0
# flow of (48, 16)  is : -142.0
# flow of (48, 47)  is : 0
# flow of (48, 49)  is : 0
# flow of (48, 80)  is : 142.0
# flow of (49, 17)  is : -236.0
# flow of (49, 48)  is : 0
# flow of (49, 50)  is : 0
# flow of (49, 81)  is : 236.0
# flow of (50, 18)  is : -592.0
# flow of (50, 49)  is : 0
# flow of (50, 51)  is : -64.0
# flow of (50, 82)  is : 656.0
# flow of (51, 19)  is : -352.0
# flow of (51, 50)  is : 64.0
# flow of (51, 52)  is : 0
# flow of (51, 83)  is : 288.0
# flow of (52, 20)  is : -260.0
# flow of (52, 51)  is : 0
# flow of (52, 53)  is : 0
# flow of (52, 84)  is : 260.0
# flow of (53, 21)  is : -474.0
# flow of (53, 52)  is : 0
# flow of (53, 54)  is : 0
# flow of (53, 85)  is : 474.0
# flow of (54, 22)  is : -675.0
# flow of (54, 53)  is : 0
# flow of (54, 55)  is : 0
# flow of (54, 86)  is : 675.0
# flow of (55, 23)  is : -67.0
# flow of (55, 54)  is : 0
# flow of (55, 56)  is : 0
# flow of (55, 87)  is : 67.0
# flow of (56, 24)  is : -130.0
# flow of (56, 55)  is : 0
# flow of (56, 57)  is : 0
# flow of (56, 88)  is : 130.0
# flow of (57, 25)  is : -379.0
# flow of (57, 56)  is : 0
# flow of (57, 58)  is : 100.0
# flow of (57, 89)  is : 279.0
# flow of (58, 26)  is : -218.0
# flow of (58, 57)  is : -100.0
# flow of (58, 59)  is : 3.0
# flow of (58, 90)  is : 315.0
# flow of (59, 27)  is : -127.0
# flow of (59, 58)  is : -3.0
# flow of (59, 60)  is : 72.0
# flow of (59, 91)  is : 58.0
# flow of (60, 28)  is : -18.0
# flow of (60, 59)  is : -72.0
# flow of (60, 61)  is : -8.0
# flow of (60, 92)  is : 98.0
# flow of (61, 29)  is : -227.0
# flow of (61, 60)  is : 8.0
# flow of (61, 62)  is : 0
# flow of (61, 93)  is : 219.0
# flow of (62, 30)  is : -490.0
# flow of (62, 61)  is : 0
# flow of (62, 63)  is : 0
# flow of (62, 94)  is : 490.0
# flow of (63, 31)  is : -101.0
# flow of (63, 62)  is : 0
# flow of (63, 64)  is : 40.0
# flow of (63, 95)  is : 61.0
# flow of (64, 32)  is : -330.0
# flow of (64, 63)  is : -40.0
# flow of (64, 96)  is : 370.0
# flow of (65, 33)  is : -212.0
# flow of (65, 66)  is : 58.0
# flow of (65, 97)  is : 154.0
# flow of (66, 34)  is : -214.0
# flow of (66, 65)  is : -58.0
# flow of (66, 67)  is : -38.0
# flow of (66, 98)  is : 310.0
# flow of (67, 35)  is : -408.0
# flow of (67, 66)  is : 38.0
# flow of (67, 68)  is : 0
# flow of (67, 99)  is : 370.0
# flow of (68, 36)  is : -434.0
# flow of (68, 67)  is : 0
# flow of (68, 69)  is : -18.0
# flow of (68, 100)  is : 452.0
# flow of (69, 37)  is : -405.0
# flow of (69, 68)  is : 18.0
# flow of (69, 70)  is : -285.0
# flow of (69, 101)  is : 672.0
# flow of (70, 38)  is : -530.0
# flow of (70, 69)  is : 285.0
# flow of (70, 71)  is : 0
# flow of (70, 102)  is : 245.0
# flow of (71, 39)  is : -66.0
# flow of (71, 70)  is : 0
# flow of (71, 72)  is : 11.0
# flow of (71, 103)  is : 55.0
# flow of (72, 40)  is : -189.0
# flow of (72, 71)  is : -11.0
# flow of (72, 73)  is : -561.0
# flow of (72, 104)  is : 761.0
# flow of (73, 41)  is : -696.0
# flow of (73, 72)  is : 561.0
# flow of (73, 74)  is : -44.0
# flow of (73, 105)  is : 179.0
# flow of (74, 42)  is : -283.0
# flow of (74, 73)  is : 44.0
# flow of (74, 75)  is : 0
# flow of (74, 106)  is : 239.0
# flow of (75, 43)  is : -203.0
# flow of (75, 74)  is : 0
# flow of (75, 76)  is : 0
# flow of (75, 107)  is : 203.0
# flow of (76, 44)  is : -308.0
# flow of (76, 75)  is : 0
# flow of (76, 77)  is : 213.0
# flow of (76, 108)  is : 95.0
# flow of (77, 45)  is : -97.0
# flow of (77, 76)  is : -213.0
# flow of (77, 78)  is : 101.0
# flow of (77, 109)  is : 209.0
# flow of (78, 46)  is : -381.0
# flow of (78, 77)  is : -101.0
# flow of (78, 79)  is : 74.0
# flow of (78, 110)  is : 408.0
# flow of (79, 47)  is : -162.0
# flow of (79, 78)  is : -74.0
# flow of (79, 80)  is : 28.0
# flow of (79, 111)  is : 208.0
# flow of (80, 48)  is : -142.0
# flow of (80, 79)  is : -28.0
# flow of (80, 81)  is : -229.0
# flow of (80, 112)  is : 399.0
# flow of (81, 49)  is : -236.0
# flow of (81, 80)  is : 229.0
# flow of (81, 82)  is : 0
# flow of (81, 113)  is : 7.0
# flow of (82, 50)  is : -656.0
# flow of (82, 81)  is : 0
# flow of (82, 83)  is : 0
# flow of (82, 114)  is : 656.0
# flow of (83, 51)  is : -288.0
# flow of (83, 82)  is : 0
# flow of (83, 84)  is : 0
# flow of (83, 115)  is : 288.0
# flow of (84, 52)  is : -260.0
# flow of (84, 83)  is : 0
# flow of (84, 85)  is : 0
# flow of (84, 116)  is : 260.0
# flow of (85, 53)  is : -474.0
# flow of (85, 84)  is : 0
# flow of (85, 86)  is : 0
# flow of (85, 117)  is : 474.0
# flow of (86, 54)  is : -675.0
# flow of (86, 85)  is : 0
# flow of (86, 87)  is : 166.0
# flow of (86, 118)  is : 509.0
# flow of (87, 55)  is : -67.0
# flow of (87, 86)  is : -166.0
# flow of (87, 88)  is : -75.0
# flow of (87, 119)  is : 308.0
# flow of (88, 56)  is : -130.0
# flow of (88, 87)  is : 75.0
# flow of (88, 89)  is : 0
# flow of (88, 120)  is : 55.0
# flow of (89, 57)  is : -279.0
# flow of (89, 88)  is : 0
# flow of (89, 90)  is : 223.0
# flow of (89, 121)  is : 56.0
# flow of (90, 58)  is : -315.0
# flow of (90, 89)  is : -223.0
# flow of (90, 91)  is : 285.0
# flow of (90, 122)  is : 253.0
# flow of (91, 59)  is : -58.0
# flow of (91, 90)  is : -285.0
# flow of (91, 92)  is : 0
# flow of (91, 123)  is : 343.0
# flow of (92, 60)  is : -98.0
# flow of (92, 91)  is : 0
# flow of (92, 93)  is : -120.0
# flow of (92, 124)  is : 218.0
# flow of (93, 61)  is : -219.0
# flow of (93, 92)  is : 120.0
# flow of (93, 94)  is : 0
# flow of (93, 125)  is : 99.0
# flow of (94, 62)  is : -490.0
# flow of (94, 93)  is : 0
# flow of (94, 95)  is : 0
# flow of (94, 126)  is : 490.0
# flow of (95, 63)  is : -61.0
# flow of (95, 94)  is : 0
# flow of (95, 96)  is : 0
# flow of (95, 127)  is : 61.0
# flow of (96, 64)  is : -370.0
# flow of (96, 95)  is : 0
# flow of (96, 128)  is : 370.0
# flow of (97, 65)  is : -154.0
# flow of (97, 98)  is : 125.0
# flow of (97, 129)  is : 29.0
# flow of (98, 66)  is : -310.0
# flow of (98, 97)  is : -125.0
# flow of (98, 99)  is : -94.0
# flow of (98, 130)  is : 529.0
# flow of (99, 67)  is : -370.0
# flow of (99, 98)  is : 94.0
# flow of (99, 100)  is : 0
# flow of (99, 131)  is : 276.0
# flow of (100, 68)  is : -452.0
# flow of (100, 99)  is : 0
# flow of (100, 101)  is : 0
# flow of (100, 132)  is : 452.0
# flow of (101, 69)  is : -672.0
# flow of (101, 100)  is : 0
# flow of (101, 102)  is : -1.0
# flow of (101, 133)  is : 673.0
# flow of (102, 70)  is : -245.0
# flow of (102, 101)  is : 1.0
# flow of (102, 103)  is : 227.0
# flow of (102, 134)  is : 17.0
# flow of (103, 71)  is : -55.0
# flow of (103, 102)  is : -227.0
# flow of (103, 104)  is : 71.0
# flow of (103, 135)  is : 211.0
# flow of (104, 72)  is : -761.0
# flow of (104, 103)  is : -71.0
# flow of (104, 105)  is : -44.0
# flow of (104, 136)  is : 876.0
# flow of (105, 73)  is : -179.0
# flow of (105, 104)  is : 44.0
# flow of (105, 106)  is : 0
# flow of (105, 137)  is : 135.0
# flow of (106, 74)  is : -239.0
# flow of (106, 105)  is : 0
# flow of (106, 107)  is : 172.0
# flow of (106, 138)  is : 67.0
# flow of (107, 75)  is : -203.0
# flow of (107, 106)  is : -172.0
# flow of (107, 108)  is : -63.0
# flow of (107, 139)  is : 438.0
# flow of (108, 76)  is : -95.0
# flow of (108, 107)  is : 63.0
# flow of (108, 109)  is : -12.0
# flow of (108, 140)  is : 44.0
# flow of (109, 77)  is : -209.0
# flow of (109, 108)  is : 12.0
# flow of (109, 110)  is : -179.0
# flow of (109, 141)  is : 376.0
# flow of (110, 78)  is : -408.0
# flow of (110, 109)  is : 179.0
# flow of (110, 111)  is : 225.0
# flow of (110, 142)  is : 4.0
# flow of (111, 79)  is : -208.0
# flow of (111, 110)  is : -225.0
# flow of (111, 112)  is : 0
# flow of (111, 143)  is : 433.0
# flow of (112, 80)  is : -399.0
# flow of (112, 111)  is : 0
# flow of (112, 113)  is : 143.0
# flow of (112, 144)  is : 256.0
# flow of (113, 81)  is : -7.0
# flow of (113, 112)  is : -143.0
# flow of (113, 114)  is : -168.0
# flow of (113, 145)  is : 318.0
# flow of (114, 82)  is : -656.0
# flow of (114, 113)  is : 168.0
# flow of (114, 115)  is : -34.0
# flow of (114, 146)  is : 522.0
# flow of (115, 83)  is : -288.0
# flow of (115, 114)  is : 34.0
# flow of (115, 116)  is : 0
# flow of (115, 147)  is : 254.0
# flow of (116, 84)  is : -260.0
# flow of (116, 115)  is : 0
# flow of (116, 117)  is : 0
# flow of (116, 148)  is : 260.0
# flow of (117, 85)  is : -474.0
# flow of (117, 116)  is : 0
# flow of (117, 118)  is : 0
# flow of (117, 149)  is : 474.0
# flow of (118, 86)  is : -509.0
# flow of (118, 117)  is : 0
# flow of (118, 119)  is : 0
# flow of (118, 150)  is : 509.0
# flow of (119, 87)  is : -308.0
# flow of (119, 118)  is : 0
# flow of (119, 120)  is : 0
# flow of (119, 151)  is : 308.0
# flow of (120, 88)  is : -55.0
# flow of (120, 119)  is : 0
# flow of (120, 121)  is : 0
# flow of (120, 152)  is : 55.0
# flow of (121, 89)  is : -56.0
# flow of (121, 120)  is : 0
# flow of (121, 122)  is : 0
# flow of (121, 153)  is : 56.0
# flow of (122, 90)  is : -253.0
# flow of (122, 121)  is : 0
# flow of (122, 123)  is : 0
# flow of (122, 154)  is : 253.0
# flow of (123, 91)  is : -343.0
# flow of (123, 122)  is : 0
# flow of (123, 124)  is : 0
# flow of (123, 155)  is : 343.0
# flow of (124, 92)  is : -218.0
# flow of (124, 123)  is : 0
# flow of (124, 125)  is : -71.0
# flow of (124, 156)  is : 289.0
# flow of (125, 93)  is : -99.0
# flow of (125, 124)  is : 71.0
# flow of (125, 126)  is : 0
# flow of (125, 157)  is : 28.0
# flow of (126, 94)  is : -490.0
# flow of (126, 125)  is : 0
# flow of (126, 127)  is : 0
# flow of (126, 158)  is : 490.0
# flow of (127, 95)  is : -61.0
# flow of (127, 126)  is : 0
# flow of (127, 128)  is : 11.0
# flow of (127, 159)  is : 50.0
# flow of (128, 96)  is : -370.0
# flow of (128, 127)  is : -11.0
# flow of (128, 160)  is : 381.0
# flow of (129, 97)  is : -29.0
# flow of (129, 130)  is : 0
# flow of (129, 161)  is : 29.0
# flow of (130, 98)  is : -529.0
# flow of (130, 129)  is : 0
# flow of (130, 131)  is : 0
# flow of (130, 162)  is : 529.0
# flow of (131, 99)  is : -276.0
# flow of (131, 130)  is : 0
# flow of (131, 132)  is : 0
# flow of (131, 163)  is : 276.0
# flow of (132, 100)  is : -452.0
# flow of (132, 131)  is : 0
# flow of (132, 133)  is : 0
# flow of (132, 164)  is : 452.0
# flow of (133, 101)  is : -673.0
# flow of (133, 132)  is : 0
# flow of (133, 134)  is : 0
# flow of (133, 165)  is : 673.0
# flow of (134, 102)  is : -17.0
# flow of (134, 133)  is : 0
# flow of (134, 135)  is : 0
# flow of (134, 166)  is : 17.0
# flow of (135, 103)  is : -211.0
# flow of (135, 134)  is : 0
# flow of (135, 136)  is : 0
# flow of (135, 167)  is : 211.0
# flow of (136, 104)  is : -876.0
# flow of (136, 135)  is : 0
# flow of (136, 137)  is : 331.0
# flow of (136, 168)  is : 545.0
# flow of (137, 105)  is : -135.0
# flow of (137, 136)  is : -331.0
# flow of (137, 138)  is : 343.0
# flow of (137, 169)  is : 123.0
# flow of (138, 106)  is : -67.0
# flow of (138, 137)  is : -343.0
# flow of (138, 139)  is : 98.0
# flow of (138, 170)  is : 312.0
# flow of (139, 107)  is : -438.0
# flow of (139, 138)  is : -98.0
# flow of (139, 140)  is : 0
# flow of (139, 171)  is : 536.0
# flow of (140, 108)  is : -44.0
# flow of (140, 139)  is : 0
# flow of (140, 141)  is : -55.0
# flow of (140, 172)  is : 99.0
# flow of (141, 109)  is : -376.0
# flow of (141, 140)  is : 55.0
# flow of (141, 142)  is : 211.0
# flow of (141, 173)  is : 110.0
# flow of (142, 110)  is : -4.0
# flow of (142, 141)  is : -211.0
# flow of (142, 143)  is : -221.0
# flow of (142, 174)  is : 436.0
# flow of (143, 111)  is : -433.0
# flow of (143, 142)  is : 221.0
# flow of (143, 144)  is : -109.0
# flow of (143, 175)  is : 321.0
# flow of (144, 112)  is : -256.0
# flow of (144, 143)  is : 109.0
# flow of (144, 145)  is : 53.0
# flow of (144, 176)  is : 94.0
# flow of (145, 113)  is : -318.0
# flow of (145, 144)  is : -53.0
# flow of (145, 146)  is : -150.0
# flow of (145, 177)  is : 521.0
# flow of (146, 114)  is : -522.0
# flow of (146, 145)  is : 150.0
# flow of (146, 147)  is : 0
# flow of (146, 178)  is : 372.0
# flow of (147, 115)  is : -254.0
# flow of (147, 146)  is : 0
# flow of (147, 148)  is : -156.0
# flow of (147, 179)  is : 410.0
# flow of (148, 116)  is : -260.0
# flow of (148, 147)  is : 156.0
# flow of (148, 149)  is : 56.0
# flow of (148, 180)  is : 48.0
# flow of (149, 117)  is : -474.0
# flow of (149, 148)  is : -56.0
# flow of (149, 150)  is : 0
# flow of (149, 181)  is : 530.0
# flow of (150, 118)  is : -509.0
# flow of (150, 149)  is : 0
# flow of (150, 151)  is : 303.0
# flow of (150, 182)  is : 206.0
# flow of (151, 119)  is : -308.0
# flow of (151, 150)  is : -303.0
# flow of (151, 152)  is : 14.0
# flow of (151, 183)  is : 597.0
# flow of (152, 120)  is : -55.0
# flow of (152, 151)  is : -14.0
# flow of (152, 153)  is : -42.0
# flow of (152, 184)  is : 111.0
# flow of (153, 121)  is : -56.0
# flow of (153, 152)  is : 42.0
# flow of (153, 154)  is : 0
# flow of (153, 185)  is : 14.0
# flow of (154, 122)  is : -253.0
# flow of (154, 153)  is : 0
# flow of (154, 155)  is : 0
# flow of (154, 186)  is : 253.0
# flow of (155, 123)  is : -343.0
# flow of (155, 154)  is : 0
# flow of (155, 156)  is : 0
# flow of (155, 187)  is : 343.0
# flow of (156, 124)  is : -289.0
# flow of (156, 155)  is : 0
# flow of (156, 157)  is : 0
# flow of (156, 188)  is : 289.0
# flow of (157, 125)  is : -28.0
# flow of (157, 156)  is : 0
# flow of (157, 158)  is : 0
# flow of (157, 189)  is : 28.0
# flow of (158, 126)  is : -490.0
# flow of (158, 157)  is : 0
# flow of (158, 159)  is : 0
# flow of (158, 190)  is : 490.0
# flow of (159, 127)  is : -50.0
# flow of (159, 158)  is : 0
# flow of (159, 160)  is : 34.0
# flow of (159, 191)  is : 16.0
# flow of (160, 128)  is : -381.0
# flow of (160, 159)  is : -34.0
# flow of (160, 192)  is : 415.0
# flow of (161, 129)  is : -29.0
# flow of (161, 162)  is : 0
# flow of (161, 193)  is : 29.0
# flow of (162, 130)  is : -529.0
# flow of (162, 161)  is : 0
# flow of (162, 163)  is : 0
# flow of (162, 194)  is : 529.0
# flow of (163, 131)  is : -276.0
# flow of (163, 162)  is : 0
# flow of (163, 164)  is : 0
# flow of (163, 195)  is : 276.0
# flow of (164, 132)  is : -452.0
# flow of (164, 163)  is : 0
# flow of (164, 165)  is : -124.0
# flow of (164, 196)  is : 576.0
# flow of (165, 133)  is : -673.0
# flow of (165, 164)  is : 124.0
# flow of (165, 166)  is : 0
# flow of (165, 197)  is : 549.0
# flow of (166, 134)  is : -17.0
# flow of (166, 165)  is : 0
# flow of (166, 167)  is : 0
# flow of (166, 198)  is : 17.0
# flow of (167, 135)  is : -211.0
# flow of (167, 166)  is : 0
# flow of (167, 168)  is : 0
# flow of (167, 199)  is : 211.0
# flow of (168, 136)  is : -545.0
# flow of (168, 167)  is : 0
# flow of (168, 169)  is : 46.0
# flow of (168, 200)  is : 499.0
# flow of (169, 137)  is : -123.0
# flow of (169, 168)  is : -46.0
# flow of (169, 170)  is : 126.0
# flow of (169, 201)  is : 43.0
# flow of (170, 138)  is : -312.0
# flow of (170, 169)  is : -126.0
# flow of (170, 171)  is : 0
# flow of (170, 202)  is : 438.0
# flow of (171, 139)  is : -536.0
# flow of (171, 170)  is : 0
# flow of (171, 172)  is : 70.0
# flow of (171, 203)  is : 466.0
# flow of (172, 140)  is : -99.0
# flow of (172, 171)  is : -70.0
# flow of (172, 173)  is : 44.0
# flow of (172, 204)  is : 125.0
# flow of (173, 141)  is : -110.0
# flow of (173, 172)  is : -44.0
# flow of (173, 174)  is : 0
# flow of (173, 205)  is : 154.0
# flow of (174, 142)  is : -436.0
# flow of (174, 173)  is : 0
# flow of (174, 175)  is : 41.0
# flow of (174, 206)  is : 395.0
# flow of (175, 143)  is : -321.0
# flow of (175, 174)  is : -41.0
# flow of (175, 176)  is : -130.0
# flow of (175, 207)  is : 492.0
# flow of (176, 144)  is : -94.0
# flow of (176, 175)  is : 130.0
# flow of (176, 177)  is : -188.0
# flow of (176, 208)  is : 152.0
# flow of (177, 145)  is : -521.0
# flow of (177, 176)  is : 188.0
# flow of (177, 178)  is : -218.0
# flow of (177, 209)  is : 551.0
# flow of (178, 146)  is : -372.0
# flow of (178, 177)  is : 218.0
# flow of (178, 179)  is : 0
# flow of (178, 210)  is : 154.0
# flow of (179, 147)  is : -410.0
# flow of (179, 178)  is : 0
# flow of (179, 180)  is : 0
# flow of (179, 211)  is : 410.0
# flow of (180, 148)  is : -48.0
# flow of (180, 179)  is : 0
# flow of (180, 181)  is : 0
# flow of (180, 212)  is : 48.0
# flow of (181, 149)  is : -530.0
# flow of (181, 180)  is : 0
# flow of (181, 182)  is : 384.0
# flow of (181, 213)  is : 146.0
# flow of (182, 150)  is : -206.0
# flow of (182, 181)  is : -384.0
# flow of (182, 183)  is : 0
# flow of (182, 214)  is : 590.0
# flow of (183, 151)  is : -597.0
# flow of (183, 182)  is : 0
# flow of (183, 184)  is : 275.0
# flow of (183, 215)  is : 322.0
# flow of (184, 152)  is : -111.0
# flow of (184, 183)  is : -275.0
# flow of (184, 185)  is : 117.0
# flow of (184, 216)  is : 269.0
# flow of (185, 153)  is : -14.0
# flow of (185, 184)  is : -117.0
# flow of (185, 186)  is : -105.0
# flow of (185, 217)  is : 236.0
# flow of (186, 154)  is : -253.0
# flow of (186, 185)  is : 105.0
# flow of (186, 187)  is : 0
# flow of (186, 218)  is : 148.0
# flow of (187, 155)  is : -343.0
# flow of (187, 186)  is : 0
# flow of (187, 188)  is : 0
# flow of (187, 219)  is : 343.0
# flow of (188, 156)  is : -289.0
# flow of (188, 187)  is : 0
# flow of (188, 189)  is : 0
# flow of (188, 220)  is : 289.0
# flow of (189, 157)  is : -28.0
# flow of (189, 188)  is : 0
# flow of (189, 190)  is : -159.0
# flow of (189, 221)  is : 187.0
# flow of (190, 158)  is : -490.0
# flow of (190, 189)  is : 159.0
# flow of (190, 191)  is : 83.0
# flow of (190, 222)  is : 248.0
# flow of (191, 159)  is : -16.0
# flow of (191, 190)  is : -83.0
# flow of (191, 192)  is : -81.0
# flow of (191, 223)  is : 180.0
# flow of (192, 160)  is : -415.0
# flow of (192, 191)  is : 81.0
# flow of (192, 224)  is : 334.0
# flow of (193, 161)  is : -29.0
# flow of (193, 194)  is : 0
# flow of (193, 225)  is : 29.0
# flow of (194, 162)  is : -529.0
# flow of (194, 193)  is : 0
# flow of (194, 195)  is : 105.0
# flow of (194, 226)  is : 424.0
# flow of (195, 163)  is : -276.0
# flow of (195, 194)  is : -105.0
# flow of (195, 196)  is : -292.0
# flow of (195, 227)  is : 673.0
# flow of (196, 164)  is : -576.0
# flow of (196, 195)  is : 292.0
# flow of (196, 197)  is : 0
# flow of (196, 228)  is : 284.0
# flow of (197, 165)  is : -549.0
# flow of (197, 196)  is : 0
# flow of (197, 198)  is : 50.0
# flow of (197, 229)  is : 499.0
# flow of (198, 166)  is : -17.0
# flow of (198, 197)  is : -50.0
# flow of (198, 199)  is : -103.0
# flow of (198, 230)  is : 170.0
# flow of (199, 167)  is : -211.0
# flow of (199, 198)  is : 103.0
# flow of (199, 200)  is : 0
# flow of (199, 231)  is : 108.0
# flow of (200, 168)  is : -499.0
# flow of (200, 199)  is : 0
# flow of (200, 201)  is : 224.0
# flow of (200, 232)  is : 275.0
# flow of (201, 169)  is : -43.0
# flow of (201, 200)  is : -224.0
# flow of (201, 202)  is : -10.0
# flow of (201, 233)  is : 277.0
# flow of (202, 170)  is : -438.0
# flow of (202, 201)  is : 10.0
# flow of (202, 203)  is : 0
# flow of (202, 234)  is : 428.0
# flow of (203, 171)  is : -466.0
# flow of (203, 202)  is : 0
# flow of (203, 204)  is : 96.0
# flow of (203, 235)  is : 370.0
# flow of (204, 172)  is : -125.0
# flow of (204, 203)  is : -96.0
# flow of (204, 205)  is : 23.0
# flow of (204, 236)  is : 198.0
# flow of (205, 173)  is : -154.0
# flow of (205, 204)  is : -23.0
# flow of (205, 206)  is : -193.0
# flow of (205, 237)  is : 370.0
# flow of (206, 174)  is : -395.0
# flow of (206, 205)  is : 193.0
# flow of (206, 207)  is : 0
# flow of (206, 238)  is : 202.0
# flow of (207, 175)  is : -492.0
# flow of (207, 206)  is : 0
# flow of (207, 208)  is : 0
# flow of (207, 239)  is : 492.0
# flow of (208, 176)  is : -152.0
# flow of (208, 207)  is : 0
# flow of (208, 209)  is : 85.0
# flow of (208, 240)  is : 67.0
# flow of (209, 177)  is : -551.0
# flow of (209, 208)  is : -85.0
# flow of (209, 210)  is : -12.0
# flow of (209, 241)  is : 648.0
# flow of (210, 178)  is : -154.0
# flow of (210, 209)  is : 12.0
# flow of (210, 211)  is : -38.0
# flow of (210, 242)  is : 180.0
# flow of (211, 179)  is : -410.0
# flow of (211, 210)  is : 38.0
# flow of (211, 212)  is : 40.0
# flow of (211, 243)  is : 332.0
# flow of (212, 180)  is : -48.0
# flow of (212, 211)  is : -40.0
# flow of (212, 213)  is : -122.0
# flow of (212, 244)  is : 210.0
# flow of (213, 181)  is : -146.0
# flow of (213, 212)  is : 122.0
# flow of (213, 214)  is : -224.0
# flow of (213, 245)  is : 248.0
# flow of (214, 182)  is : -590.0
# flow of (214, 213)  is : 224.0
# flow of (214, 215)  is : 0
# flow of (214, 246)  is : 366.0
# flow of (215, 183)  is : -322.0
# flow of (215, 214)  is : 0
# flow of (215, 216)  is : 0
# flow of (215, 247)  is : 322.0
# flow of (216, 184)  is : -269.0
# flow of (216, 215)  is : 0
# flow of (216, 217)  is : 16.0
# flow of (216, 248)  is : 253.0
# flow of (217, 185)  is : -236.0
# flow of (217, 216)  is : -16.0
# flow of (217, 218)  is : 8.0
# flow of (217, 249)  is : 244.0
# flow of (218, 186)  is : -148.0
# flow of (218, 217)  is : -8.0
# flow of (218, 219)  is : -94.0
# flow of (218, 250)  is : 250.0
# flow of (219, 187)  is : -343.0
# flow of (219, 218)  is : 94.0
# flow of (219, 220)  is : 0
# flow of (219, 251)  is : 249.0
# flow of (220, 188)  is : -289.0
# flow of (220, 219)  is : 0
# flow of (220, 221)  is : 0
# flow of (220, 252)  is : 289.0
# flow of (221, 189)  is : -187.0
# flow of (221, 220)  is : 0
# flow of (221, 222)  is : 0
# flow of (221, 253)  is : 187.0
# flow of (222, 190)  is : -248.0
# flow of (222, 221)  is : 0
# flow of (222, 223)  is : 0
# flow of (222, 254)  is : 248.0
# flow of (223, 191)  is : -180.0
# flow of (223, 222)  is : 0
# flow of (223, 224)  is : 0
# flow of (223, 255)  is : 180.0
# flow of (224, 192)  is : -334.0
# flow of (224, 223)  is : 0
# flow of (224, 256)  is : 334.0
# flow of (225, 193)  is : -29.0
# flow of (225, 226)  is : 0
# flow of (225, 257)  is : 29.0
# flow of (226, 194)  is : -424.0
# flow of (226, 225)  is : 0
# flow of (226, 227)  is : 0
# flow of (226, 258)  is : 424.0
# flow of (227, 195)  is : -673.0
# flow of (227, 226)  is : 0
# flow of (227, 228)  is : 209.0
# flow of (227, 259)  is : 464.0
# flow of (228, 196)  is : -284.0
# flow of (228, 227)  is : -209.0
# flow of (228, 229)  is : -57.0
# flow of (228, 260)  is : 550.0
# flow of (229, 197)  is : -499.0
# flow of (229, 228)  is : 57.0
# flow of (229, 230)  is : 25.0
# flow of (229, 261)  is : 417.0
# flow of (230, 198)  is : -170.0
# flow of (230, 229)  is : -25.0
# flow of (230, 231)  is : 131.0
# flow of (230, 262)  is : 64.0
# flow of (231, 199)  is : -108.0
# flow of (231, 230)  is : -131.0
# flow of (231, 232)  is : -165.0
# flow of (231, 263)  is : 404.0
# flow of (232, 200)  is : -275.0
# flow of (232, 231)  is : 165.0
# flow of (232, 233)  is : -10.0
# flow of (232, 264)  is : 120.0
# flow of (233, 201)  is : -277.0
# flow of (233, 232)  is : 10.0
# flow of (233, 234)  is : 0
# flow of (233, 265)  is : 267.0
# flow of (234, 202)  is : -428.0
# flow of (234, 233)  is : 0
# flow of (234, 235)  is : 0
# flow of (234, 266)  is : 428.0
# flow of (235, 203)  is : -370.0
# flow of (235, 234)  is : 0
# flow of (235, 236)  is : 0
# flow of (235, 267)  is : 370.0
# flow of (236, 204)  is : -198.0
# flow of (236, 235)  is : 0
# flow of (236, 237)  is : 165.0
# flow of (236, 268)  is : 33.0
# flow of (237, 205)  is : -370.0
# flow of (237, 236)  is : -165.0
# flow of (237, 238)  is : -202.0
# flow of (237, 269)  is : 737.0
# flow of (238, 206)  is : -202.0
# flow of (238, 237)  is : 202.0
# flow of (238, 239)  is : -140.0
# flow of (238, 270)  is : 140.0
# flow of (239, 207)  is : -492.0
# flow of (239, 238)  is : 140.0
# flow of (239, 240)  is : 120.0
# flow of (239, 271)  is : 232.0
# flow of (240, 208)  is : -67.0
# flow of (240, 239)  is : -120.0
# flow of (240, 241)  is : 16.0
# flow of (240, 272)  is : 171.0
# flow of (241, 209)  is : -648.0
# flow of (241, 240)  is : -16.0
# flow of (241, 242)  is : 0
# flow of (241, 273)  is : 664.0
# flow of (242, 210)  is : -180.0
# flow of (242, 241)  is : 0
# flow of (242, 243)  is : 0
# flow of (242, 274)  is : 180.0
# flow of (243, 211)  is : -332.0
# flow of (243, 242)  is : 0
# flow of (243, 244)  is : -70.0
# flow of (243, 275)  is : 402.0
# flow of (244, 212)  is : -210.0
# flow of (244, 243)  is : 70.0
# flow of (244, 245)  is : -59.0
# flow of (244, 276)  is : 199.0
# flow of (245, 213)  is : -248.0
# flow of (245, 244)  is : 59.0
# flow of (245, 246)  is : 0
# flow of (245, 277)  is : 189.0
# flow of (246, 214)  is : -366.0
# flow of (246, 245)  is : 0
# flow of (246, 247)  is : -89.0
# flow of (246, 278)  is : 455.0
# flow of (247, 215)  is : -322.0
# flow of (247, 246)  is : 89.0
# flow of (247, 248)  is : 0
# flow of (247, 279)  is : 233.0
# flow of (248, 216)  is : -253.0
# flow of (248, 247)  is : 0
# flow of (248, 249)  is : 0
# flow of (248, 280)  is : 253.0
# flow of (249, 217)  is : -244.0
# flow of (249, 248)  is : 0
# flow of (249, 250)  is : 0
# flow of (249, 281)  is : 244.0
# flow of (250, 218)  is : -250.0
# flow of (250, 249)  is : 0
# flow of (250, 251)  is : 0
# flow of (250, 282)  is : 250.0
# flow of (251, 219)  is : -249.0
# flow of (251, 250)  is : 0
# flow of (251, 252)  is : 0
# flow of (251, 283)  is : 249.0
# flow of (252, 220)  is : -289.0
# flow of (252, 251)  is : 0
# flow of (252, 253)  is : 0
# flow of (252, 284)  is : 289.0
# flow of (253, 221)  is : -187.0
# flow of (253, 252)  is : 0
# flow of (253, 254)  is : -26.0
# flow of (253, 285)  is : 213.0
# flow of (254, 222)  is : -248.0
# flow of (254, 253)  is : 26.0
# flow of (254, 255)  is : 0
# flow of (254, 286)  is : 222.0
# flow of (255, 223)  is : -180.0
# flow of (255, 254)  is : 0
# flow of (255, 256)  is : -128.0
# flow of (255, 287)  is : 308.0
# flow of (256, 224)  is : -334.0
# flow of (256, 255)  is : 128.0
# flow of (256, 288)  is : 206.0
# flow of (257, 225)  is : -29.0
# flow of (257, 258)  is : -395.0
# flow of (257, 289)  is : 424.0
# flow of (258, 226)  is : -424.0
# flow of (258, 257)  is : 395.0
# flow of (258, 259)  is : -315.0
# flow of (258, 290)  is : 344.0
# flow of (259, 227)  is : -464.0
# flow of (259, 258)  is : 315.0
# flow of (259, 260)  is : 139.0
# flow of (259, 291)  is : 10.0
# flow of (260, 228)  is : -550.0
# flow of (260, 259)  is : -139.0
# flow of (260, 261)  is : -20.0
# flow of (260, 292)  is : 709.0
# flow of (261, 229)  is : -417.0
# flow of (261, 260)  is : 20.0
# flow of (261, 262)  is : 0
# flow of (261, 293)  is : 397.0
# flow of (262, 230)  is : -64.0
# flow of (262, 261)  is : 0
# flow of (262, 263)  is : 63.0
# flow of (262, 294)  is : 1.0
# flow of (263, 231)  is : -404.0
# flow of (263, 262)  is : -63.0
# flow of (263, 264)  is : 0
# flow of (263, 295)  is : 467.0
# flow of (264, 232)  is : -120.0
# flow of (264, 263)  is : 0
# flow of (264, 265)  is : 0
# flow of (264, 296)  is : 120.0
# flow of (265, 233)  is : -267.0
# flow of (265, 264)  is : 0
# flow of (265, 266)  is : -82.0
# flow of (265, 297)  is : 349.0
# flow of (266, 234)  is : -428.0
# flow of (266, 265)  is : 82.0
# flow of (266, 267)  is : 0
# flow of (266, 298)  is : 346.0
# flow of (267, 235)  is : -370.0
# flow of (267, 266)  is : 0
# flow of (267, 268)  is : 228.0
# flow of (267, 299)  is : 142.0
# flow of (268, 236)  is : -33.0
# flow of (268, 267)  is : -228.0
# flow of (268, 269)  is : -203.0
# flow of (268, 300)  is : 464.0
# flow of (269, 237)  is : -737.0
# flow of (269, 268)  is : 203.0
# flow of (269, 270)  is : 0
# flow of (269, 301)  is : 534.0
# flow of (270, 238)  is : -140.0
# flow of (270, 269)  is : 0
# flow of (270, 271)  is : -220.0
# flow of (270, 302)  is : 360.0
# flow of (271, 239)  is : -232.0
# flow of (271, 270)  is : 220.0
# flow of (271, 272)  is : -133.0
# flow of (271, 303)  is : 145.0
# flow of (272, 240)  is : -171.0
# flow of (272, 271)  is : 133.0
# flow of (272, 273)  is : -115.0
# flow of (272, 304)  is : 153.0
# flow of (273, 241)  is : -664.0
# flow of (273, 272)  is : 115.0
# flow of (273, 274)  is : -84.0
# flow of (273, 305)  is : 633.0
# flow of (274, 242)  is : -180.0
# flow of (274, 273)  is : 84.0
# flow of (274, 275)  is : -157.0
# flow of (274, 306)  is : 253.0
# flow of (275, 243)  is : -402.0
# flow of (275, 274)  is : 157.0
# flow of (275, 276)  is : 0
# flow of (275, 307)  is : 245.0
# flow of (276, 244)  is : -199.0
# flow of (276, 275)  is : 0
# flow of (276, 277)  is : 0
# flow of (276, 308)  is : 199.0
# flow of (277, 245)  is : -189.0
# flow of (277, 276)  is : 0
# flow of (277, 278)  is : 0
# flow of (277, 309)  is : 189.0
# flow of (278, 246)  is : -455.0
# flow of (278, 277)  is : 0
# flow of (278, 279)  is : 0
# flow of (278, 310)  is : 455.0
# flow of (279, 247)  is : -233.0
# flow of (279, 278)  is : 0
# flow of (279, 280)  is : 0
# flow of (279, 311)  is : 233.0
# flow of (280, 248)  is : -253.0
# flow of (280, 279)  is : 0
# flow of (280, 281)  is : 227.0
# flow of (280, 312)  is : 26.0
# flow of (281, 249)  is : -244.0
# flow of (281, 280)  is : -227.0
# flow of (281, 282)  is : -43.0
# flow of (281, 313)  is : 514.0
# flow of (282, 250)  is : -250.0
# flow of (282, 281)  is : 43.0
# flow of (282, 283)  is : 0
# flow of (282, 314)  is : 207.0
# flow of (283, 251)  is : -249.0
# flow of (283, 282)  is : 0
# flow of (283, 284)  is : 0
# flow of (283, 315)  is : 249.0
# flow of (284, 252)  is : -289.0
# flow of (284, 283)  is : 0
# flow of (284, 285)  is : 79.0
# flow of (284, 316)  is : 210.0
# flow of (285, 253)  is : -213.0
# flow of (285, 284)  is : -79.0
# flow of (285, 286)  is : -39.0
# flow of (285, 317)  is : 331.0
# flow of (286, 254)  is : -222.0
# flow of (286, 285)  is : 39.0
# flow of (286, 287)  is : 0
# flow of (286, 318)  is : 183.0
# flow of (287, 255)  is : -308.0
# flow of (287, 286)  is : 0
# flow of (287, 288)  is : 0
# flow of (287, 319)  is : 308.0
# flow of (288, 256)  is : -206.0
# flow of (288, 287)  is : 0
# flow of (288, 320)  is : 206.0
# flow of (289, 257)  is : -424.0
# flow of (289, 290)  is : -182.0
# flow of (289, 321)  is : 606.0
# flow of (290, 258)  is : -344.0
# flow of (290, 289)  is : 182.0
# flow of (290, 291)  is : 140.0
# flow of (290, 322)  is : 22.0
# flow of (291, 259)  is : -10.0
# flow of (291, 290)  is : -140.0
# flow of (291, 292)  is : -160.0
# flow of (291, 323)  is : 310.0
# flow of (292, 260)  is : -709.0
# flow of (292, 291)  is : 160.0
# flow of (292, 293)  is : 208.0
# flow of (292, 324)  is : 341.0
# flow of (293, 261)  is : -397.0
# flow of (293, 292)  is : -208.0
# flow of (293, 294)  is : 182.0
# flow of (293, 325)  is : 423.0
# flow of (294, 262)  is : -1.0
# flow of (294, 293)  is : -182.0
# flow of (294, 295)  is : -392.0
# flow of (294, 326)  is : 575.0
# flow of (295, 263)  is : -467.0
# flow of (295, 294)  is : 392.0
# flow of (295, 296)  is : 51.0
# flow of (295, 327)  is : 24.0
# flow of (296, 264)  is : -120.0
# flow of (296, 295)  is : -51.0
# flow of (296, 297)  is : -70.0
# flow of (296, 328)  is : 241.0
# flow of (297, 265)  is : -349.0
# flow of (297, 296)  is : 70.0
# flow of (297, 298)  is : 0
# flow of (297, 329)  is : 279.0
# flow of (298, 266)  is : -346.0
# flow of (298, 297)  is : 0
# flow of (298, 299)  is : 237.0
# flow of (298, 330)  is : 109.0
# flow of (299, 267)  is : -142.0
# flow of (299, 298)  is : -237.0
# flow of (299, 300)  is : 194.0
# flow of (299, 331)  is : 185.0
# flow of (300, 268)  is : -464.0
# flow of (300, 299)  is : -194.0
# flow of (300, 301)  is : 49.0
# flow of (300, 332)  is : 609.0
# flow of (301, 269)  is : -534.0
# flow of (301, 300)  is : -49.0
# flow of (301, 302)  is : 137.0
# flow of (301, 333)  is : 446.0
# flow of (302, 270)  is : -360.0
# flow of (302, 301)  is : -137.0
# flow of (302, 303)  is : -63.0
# flow of (302, 334)  is : 560.0
# flow of (303, 271)  is : -145.0
# flow of (303, 302)  is : 63.0
# flow of (303, 304)  is : 0
# flow of (303, 335)  is : 82.0
# flow of (304, 272)  is : -153.0
# flow of (304, 303)  is : 0
# flow of (304, 305)  is : 0
# flow of (304, 336)  is : 153.0
# flow of (305, 273)  is : -633.0
# flow of (305, 304)  is : 0
# flow of (305, 306)  is : 231.0
# flow of (305, 337)  is : 402.0
# flow of (306, 274)  is : -253.0
# flow of (306, 305)  is : -231.0
# flow of (306, 307)  is : 0
# flow of (306, 338)  is : 484.0
# flow of (307, 275)  is : -245.0
# flow of (307, 306)  is : 0
# flow of (307, 308)  is : 0
# flow of (307, 339)  is : 245.0
# flow of (308, 276)  is : -199.0
# flow of (308, 307)  is : 0
# flow of (308, 309)  is : 0
# flow of (308, 340)  is : 199.0
# flow of (309, 277)  is : -189.0
# flow of (309, 308)  is : 0
# flow of (309, 310)  is : 0
# flow of (309, 341)  is : 189.0
# flow of (310, 278)  is : -455.0
# flow of (310, 309)  is : 0
# flow of (310, 311)  is : 0
# flow of (310, 342)  is : 455.0
# flow of (311, 279)  is : -233.0
# flow of (311, 310)  is : 0
# flow of (311, 312)  is : 0
# flow of (311, 343)  is : 233.0
# flow of (312, 280)  is : -26.0
# flow of (312, 311)  is : 0
# flow of (312, 313)  is : 0
# flow of (312, 344)  is : 26.0
# flow of (313, 281)  is : -514.0
# flow of (313, 312)  is : 0
# flow of (313, 314)  is : -30.0
# flow of (313, 345)  is : 544.0
# flow of (314, 282)  is : -207.0
# flow of (314, 313)  is : 30.0
# flow of (314, 315)  is : 0
# flow of (314, 346)  is : 177.0
# flow of (315, 283)  is : -249.0
# flow of (315, 314)  is : 0
# flow of (315, 316)  is : 0
# flow of (315, 347)  is : 249.0
# flow of (316, 284)  is : -210.0
# flow of (316, 315)  is : 0
# flow of (316, 317)  is : 0
# flow of (316, 348)  is : 210.0
# flow of (317, 285)  is : -331.0
# flow of (317, 316)  is : 0
# flow of (317, 318)  is : 0
# flow of (317, 349)  is : 331.0
# flow of (318, 286)  is : -183.0
# flow of (318, 317)  is : 0
# flow of (318, 319)  is : 0
# flow of (318, 350)  is : 183.0
# flow of (319, 287)  is : -308.0
# flow of (319, 318)  is : 0
# flow of (319, 320)  is : -117.0
# flow of (319, 351)  is : 425.0
# flow of (320, 288)  is : -206.0
# flow of (320, 319)  is : 117.0
# flow of (320, 352)  is : 89.0
# flow of (321, 289)  is : -606.0
# flow of (321, 322)  is : 326.0
# flow of (321, 353)  is : 280.0
# flow of (322, 290)  is : -22.0
# flow of (322, 321)  is : -326.0
# flow of (322, 323)  is : -45.0
# flow of (322, 354)  is : 393.0
# flow of (323, 291)  is : -310.0
# flow of (323, 322)  is : 45.0
# flow of (323, 324)  is : 171.0
# flow of (323, 355)  is : 94.0
# flow of (324, 292)  is : -341.0
# flow of (324, 323)  is : -171.0
# flow of (324, 325)  is : -192.0
# flow of (324, 356)  is : 704.0
# flow of (325, 293)  is : -423.0
# flow of (325, 324)  is : 192.0
# flow of (325, 326)  is : -50.0
# flow of (325, 357)  is : 281.0
# flow of (326, 294)  is : -575.0
# flow of (326, 325)  is : 50.0
# flow of (326, 327)  is : -50.0
# flow of (326, 358)  is : 575.0
# flow of (327, 295)  is : -24.0
# flow of (327, 326)  is : 50.0
# flow of (327, 328)  is : -50.0
# flow of (327, 359)  is : 24.0
# flow of (328, 296)  is : -241.0
# flow of (328, 327)  is : 50.0
# flow of (328, 329)  is : -176.0
# flow of (328, 360)  is : 367.0
# flow of (329, 297)  is : -279.0
# flow of (329, 328)  is : 176.0
# flow of (329, 330)  is : -243.0
# flow of (329, 361)  is : 346.0
# flow of (330, 298)  is : -109.0
# flow of (330, 329)  is : 243.0
# flow of (330, 331)  is : -568.0
# flow of (330, 362)  is : 434.0
# flow of (331, 299)  is : -185.0
# flow of (331, 330)  is : 568.0
# flow of (331, 332)  is : -410.0
# flow of (331, 363)  is : 27.0
# flow of (332, 300)  is : -609.0
# flow of (332, 331)  is : 410.0
# flow of (332, 333)  is : -118.0
# flow of (332, 364)  is : 317.0
# flow of (333, 301)  is : -446.0
# flow of (333, 332)  is : 118.0
# flow of (333, 334)  is : 0
# flow of (333, 365)  is : 328.0
# flow of (334, 302)  is : -560.0
# flow of (334, 333)  is : 0
# flow of (334, 335)  is : 25.0
# flow of (334, 366)  is : 535.0
# flow of (335, 303)  is : -82.0
# flow of (335, 334)  is : -25.0
# flow of (335, 336)  is : -136.0
# flow of (335, 367)  is : 243.0
# flow of (336, 304)  is : -153.0
# flow of (336, 335)  is : 136.0
# flow of (336, 337)  is : 0
# flow of (336, 368)  is : 17.0
# flow of (337, 305)  is : -402.0
# flow of (337, 336)  is : 0
# flow of (337, 338)  is : 0
# flow of (337, 369)  is : 402.0
# flow of (338, 306)  is : -484.0
# flow of (338, 337)  is : 0
# flow of (338, 339)  is : 0
# flow of (338, 370)  is : 484.0
# flow of (339, 307)  is : -245.0
# flow of (339, 338)  is : 0
# flow of (339, 340)  is : 65.0
# flow of (339, 371)  is : 180.0
# flow of (340, 308)  is : -199.0
# flow of (340, 339)  is : -65.0
# flow of (340, 341)  is : 65.0
# flow of (340, 372)  is : 199.0
# flow of (341, 309)  is : -189.0
# flow of (341, 340)  is : -65.0
# flow of (341, 342)  is : -214.0
# flow of (341, 373)  is : 468.0
# flow of (342, 310)  is : -455.0
# flow of (342, 341)  is : 214.0
# flow of (342, 343)  is : 120.0
# flow of (342, 374)  is : 121.0
# flow of (343, 311)  is : -233.0
# flow of (343, 342)  is : -120.0
# flow of (343, 344)  is : 0
# flow of (343, 375)  is : 353.0
# flow of (344, 312)  is : -26.0
# flow of (344, 343)  is : 0
# flow of (344, 345)  is : 0
# flow of (344, 376)  is : 26.0
# flow of (345, 313)  is : -544.0
# flow of (345, 344)  is : 0
# flow of (345, 346)  is : 411.0
# flow of (345, 377)  is : 133.0
# flow of (346, 314)  is : -177.0
# flow of (346, 345)  is : -411.0
# flow of (346, 347)  is : -218.0
# flow of (346, 378)  is : 806.0
# flow of (347, 315)  is : -249.0
# flow of (347, 346)  is : 218.0
# flow of (347, 348)  is : 0
# flow of (347, 379)  is : 31.0
# flow of (348, 316)  is : -210.0
# flow of (348, 347)  is : 0
# flow of (348, 349)  is : 0
# flow of (348, 380)  is : 210.0
# flow of (349, 317)  is : -331.0
# flow of (349, 348)  is : 0
# flow of (349, 350)  is : 77.0
# flow of (349, 381)  is : 254.0
# flow of (350, 318)  is : -183.0
# flow of (350, 349)  is : -77.0
# flow of (350, 351)  is : -289.0
# flow of (350, 382)  is : 549.0
# flow of (351, 319)  is : -425.0
# flow of (351, 350)  is : 289.0
# flow of (351, 352)  is : 0
# flow of (351, 383)  is : 136.0
# flow of (352, 320)  is : -89.0
# flow of (352, 351)  is : 0
# flow of (352, 384)  is : 89.0
# flow of (353, 321)  is : -280.0
# flow of (353, 354)  is : -64.0
# flow of (353, 385)  is : 344.0
# flow of (354, 322)  is : -393.0
# flow of (354, 353)  is : 64.0
# flow of (354, 355)  is : 224.0
# flow of (354, 386)  is : 105.0
# flow of (355, 323)  is : -94.0
# flow of (355, 354)  is : -224.0
# flow of (355, 356)  is : -126.0
# flow of (355, 387)  is : 444.0
# flow of (356, 324)  is : -704.0
# flow of (356, 355)  is : 126.0
# flow of (356, 357)  is : 59.0
# flow of (356, 388)  is : 519.0
# flow of (357, 325)  is : -281.0
# flow of (357, 356)  is : -59.0
# flow of (357, 358)  is : 108.0
# flow of (357, 389)  is : 232.0
# flow of (358, 326)  is : -575.0
# flow of (358, 357)  is : -108.0
# flow of (358, 359)  is : 7.0
# flow of (358, 390)  is : 676.0
# flow of (359, 327)  is : -24.0
# flow of (359, 358)  is : -7.0
# flow of (359, 360)  is : -132.0
# flow of (359, 391)  is : 163.0
# flow of (360, 328)  is : -367.0
# flow of (360, 359)  is : 132.0
# flow of (360, 361)  is : -409.0
# flow of (360, 392)  is : 644.0
# flow of (361, 329)  is : -346.0
# flow of (361, 360)  is : 409.0
# flow of (361, 362)  is : -302.0
# flow of (361, 393)  is : 239.0
# flow of (362, 330)  is : -434.0
# flow of (362, 361)  is : 302.0
# flow of (362, 363)  is : 100.0
# flow of (362, 394)  is : 32.0
# flow of (363, 331)  is : -27.0
# flow of (363, 362)  is : -100.0
# flow of (363, 364)  is : -9.0
# flow of (363, 395)  is : 136.0
# flow of (364, 332)  is : -317.0
# flow of (364, 363)  is : 9.0
# flow of (364, 365)  is : -442.0
# flow of (364, 396)  is : 750.0
# flow of (365, 333)  is : -328.0
# flow of (365, 364)  is : 442.0
# flow of (365, 366)  is : -476.0
# flow of (365, 397)  is : 362.0
# flow of (366, 334)  is : -535.0
# flow of (366, 365)  is : 476.0
# flow of (366, 367)  is : 0
# flow of (366, 398)  is : 59.0
# flow of (367, 335)  is : -243.0
# flow of (367, 366)  is : 0
# flow of (367, 368)  is : 178.0
# flow of (367, 399)  is : 65.0
# flow of (368, 336)  is : -17.0
# flow of (368, 367)  is : -178.0
# flow of (368, 369)  is : -34.0
# flow of (368, 400)  is : 229.0
# flow of (369, 337)  is : -402.0
# flow of (369, 368)  is : 34.0
# flow of (369, 370)  is : -30.0
# flow of (369, 401)  is : 398.0
# flow of (370, 338)  is : -484.0
# flow of (370, 369)  is : 30.0
# flow of (370, 371)  is : 0
# flow of (370, 402)  is : 454.0
# flow of (371, 339)  is : -180.0
# flow of (371, 370)  is : 0
# flow of (371, 372)  is : 96.0
# flow of (371, 403)  is : 84.0
# flow of (372, 340)  is : -199.0
# flow of (372, 371)  is : -96.0
# flow of (372, 373)  is : -82.0
# flow of (372, 404)  is : 377.0
# flow of (373, 341)  is : -468.0
# flow of (373, 372)  is : 82.0
# flow of (373, 374)  is : -82.0
# flow of (373, 405)  is : 468.0
# flow of (374, 342)  is : -121.0
# flow of (374, 373)  is : 82.0
# flow of (374, 375)  is : 0
# flow of (374, 406)  is : 39.0
# flow of (375, 343)  is : -353.0
# flow of (375, 374)  is : 0
# flow of (375, 376)  is : 0
# flow of (375, 407)  is : 353.0
# flow of (376, 344)  is : -26.0
# flow of (376, 375)  is : 0
# flow of (376, 377)  is : 0
# flow of (376, 408)  is : 26.0
# flow of (377, 345)  is : -133.0
# flow of (377, 376)  is : 0
# flow of (377, 378)  is : 72.0
# flow of (377, 409)  is : 61.0
# flow of (378, 346)  is : -806.0
# flow of (378, 377)  is : -72.0
# flow of (378, 379)  is : 180.0
# flow of (378, 410)  is : 698.0
# flow of (379, 347)  is : -31.0
# flow of (379, 378)  is : -180.0
# flow of (379, 380)  is : -221.0
# flow of (379, 411)  is : 432.0
# flow of (380, 348)  is : -210.0
# flow of (380, 379)  is : 221.0
# flow of (380, 381)  is : -196.0
# flow of (380, 412)  is : 185.0
# flow of (381, 349)  is : -254.0
# flow of (381, 380)  is : 196.0
# flow of (381, 382)  is : -203.0
# flow of (381, 413)  is : 261.0
# flow of (382, 350)  is : -549.0
# flow of (382, 381)  is : 203.0
# flow of (382, 383)  is : -76.0
# flow of (382, 414)  is : 422.0
# flow of (383, 351)  is : -136.0
# flow of (383, 382)  is : 76.0
# flow of (383, 384)  is : 0
# flow of (383, 415)  is : 60.0
# flow of (384, 352)  is : -89.0
# flow of (384, 383)  is : 0
# flow of (384, 416)  is : 89.0
# flow of (385, 353)  is : -344.0
# flow of (385, 386)  is : 62.0
# flow of (385, 417)  is : 282.0
# flow of (386, 354)  is : -105.0
# flow of (386, 385)  is : -62.0
# flow of (386, 387)  is : 46.0
# flow of (386, 418)  is : 121.0
# flow of (387, 355)  is : -444.0
# flow of (387, 386)  is : -46.0
# flow of (387, 388)  is : 357.0
# flow of (387, 419)  is : 133.0
# flow of (388, 356)  is : -519.0
# flow of (388, 387)  is : -357.0
# flow of (388, 389)  is : 286.0
# flow of (388, 420)  is : 590.0
# flow of (389, 357)  is : -232.0
# flow of (389, 388)  is : -286.0
# flow of (389, 390)  is : 312.0
# flow of (389, 421)  is : 206.0
# flow of (390, 358)  is : -676.0
# flow of (390, 389)  is : -312.0
# flow of (390, 391)  is : 250.0
# flow of (390, 422)  is : 738.0
# flow of (391, 359)  is : -163.0
# flow of (391, 390)  is : -250.0
# flow of (391, 392)  is : -348.0
# flow of (391, 423)  is : 761.0
# flow of (392, 360)  is : -644.0
# flow of (392, 391)  is : 348.0
# flow of (392, 393)  is : -60.0
# flow of (392, 424)  is : 356.0
# flow of (393, 361)  is : -239.0
# flow of (393, 392)  is : 60.0
# flow of (393, 394)  is : -40.0
# flow of (393, 425)  is : 219.0
# flow of (394, 362)  is : -32.0
# flow of (394, 393)  is : 40.0
# flow of (394, 395)  is : -52.0
# flow of (394, 426)  is : 44.0
# flow of (395, 363)  is : -136.0
# flow of (395, 394)  is : 52.0
# flow of (395, 396)  is : -392.0
# flow of (395, 427)  is : 476.0
# flow of (396, 364)  is : -750.0
# flow of (396, 395)  is : 392.0
# flow of (396, 397)  is : -349.0
# flow of (396, 428)  is : 707.0
# flow of (397, 365)  is : -362.0
# flow of (397, 396)  is : 349.0
# flow of (397, 398)  is : -35.0
# flow of (397, 429)  is : 48.0
# flow of (398, 366)  is : -59.0
# flow of (398, 397)  is : 35.0
# flow of (398, 399)  is : -43.0
# flow of (398, 430)  is : 67.0
# flow of (399, 367)  is : -65.0
# flow of (399, 398)  is : 43.0
# flow of (399, 400)  is : 0
# flow of (399, 431)  is : 22.0
# flow of (400, 368)  is : -229.0
# flow of (400, 399)  is : 0
# flow of (400, 401)  is : 84.0
# flow of (400, 432)  is : 145.0
# flow of (401, 369)  is : -398.0
# flow of (401, 400)  is : -84.0
# flow of (401, 402)  is : 179.0
# flow of (401, 433)  is : 303.0
# ...
# flow of (900, 868)  is : -559.0
# flow of (900, 899)  is : 84.0
# flow of (900, 901)  is : 0
# flow of (900, 932)  is : 475.0
# flow of (901, 869)  is : -28.0
# flow of (901, 900)  is : 0
# flow of (901, 902)  is : -251.0
# flow of (901, 933)  is : 279.0
# flow of (902, 870)  is : -633.0
# flow of (902, 901)  is : 251.0
# flow of (902, 903)  is : 0
# flow of (902, 934)  is : 382.0
# flow of (903, 871)  is : -98.0
# flow of (903, 902)  is : 0
# flow of (903, 904)  is : -4.0
# flow of (903, 935)  is : 102.0
# flow of (904, 872)  is : -270.0
# flow of (904, 903)  is : 4.0
# flow of (904, 905)  is : 0
# flow of (904, 936)  is : 266.0
# flow of (905, 873)  is : -209.0
# flow of (905, 904)  is : 0
# flow of (905, 906)  is : 2.0
# flow of (905, 937)  is : 207.0
# flow of (906, 874)  is : -183.0
# flow of (906, 905)  is : -2.0
# flow of (906, 907)  is : -36.0
# flow of (906, 938)  is : 221.0
# flow of (907, 875)  is : -217.0
# flow of (907, 906)  is : 36.0
# flow of (907, 908)  is : 0
# flow of (907, 939)  is : 181.0
# flow of (908, 876)  is : -51.0
# flow of (908, 907)  is : 0
# flow of (908, 909)  is : 49.0
# flow of (908, 940)  is : 2.0
# flow of (909, 877)  is : -18.0
# flow of (909, 908)  is : -49.0
# flow of (909, 910)  is : 0
# flow of (909, 941)  is : 67.0
# flow of (910, 878)  is : -535.0
# flow of (910, 909)  is : 0
# flow of (910, 911)  is : 189.0
# flow of (910, 942)  is : 346.0
# flow of (911, 879)  is : -526.0
# flow of (911, 910)  is : -189.0
# flow of (911, 912)  is : 143.0
# flow of (911, 943)  is : 572.0
# flow of (912, 880)  is : -302.0
# flow of (912, 911)  is : -143.0
# flow of (912, 913)  is : -68.0
# flow of (912, 944)  is : 513.0
# flow of (913, 881)  is : -468.0
# flow of (913, 912)  is : 68.0
# flow of (913, 914)  is : 0
# flow of (913, 945)  is : 400.0
# flow of (914, 882)  is : -146.0
# flow of (914, 913)  is : 0
# flow of (914, 915)  is : 0
# flow of (914, 946)  is : 146.0
# flow of (915, 883)  is : -23.0
# flow of (915, 914)  is : 0
# flow of (915, 916)  is : 0
# flow of (915, 947)  is : 23.0
# flow of (916, 884)  is : -512.0
# flow of (916, 915)  is : 0
# flow of (916, 917)  is : 0
# flow of (916, 948)  is : 512.0
# flow of (917, 885)  is : -49.0
# flow of (917, 916)  is : 0
# flow of (917, 918)  is : 0
# flow of (917, 949)  is : 49.0
# flow of (918, 886)  is : -306.0
# flow of (918, 917)  is : 0
# flow of (918, 919)  is : 0
# flow of (918, 950)  is : 306.0
# flow of (919, 887)  is : -322.0
# flow of (919, 918)  is : 0
# flow of (919, 920)  is : 257.0
# flow of (919, 951)  is : 65.0
# flow of (920, 888)  is : -248.0
# flow of (920, 919)  is : -257.0
# flow of (920, 921)  is : 0
# flow of (920, 952)  is : 505.0
# flow of (921, 889)  is : -563.0
# flow of (921, 920)  is : 0
# flow of (921, 922)  is : 150.0
# flow of (921, 953)  is : 413.0
# flow of (922, 890)  is : -209.0
# flow of (922, 921)  is : -150.0
# flow of (922, 923)  is : -367.0
# flow of (922, 954)  is : 726.0
# flow of (923, 891)  is : -621.0
# flow of (923, 922)  is : 367.0
# flow of (923, 924)  is : 74.0
# flow of (923, 955)  is : 180.0
# flow of (924, 892)  is : -151.0
# flow of (924, 923)  is : -74.0
# flow of (924, 925)  is : 0
# flow of (924, 956)  is : 225.0
# flow of (925, 893)  is : -259.0
# flow of (925, 924)  is : 0
# flow of (925, 926)  is : 0
# flow of (925, 957)  is : 259.0
# flow of (926, 894)  is : -130.0
# flow of (926, 925)  is : 0
# flow of (926, 927)  is : -33.0
# flow of (926, 958)  is : 163.0
# flow of (927, 895)  is : -242.0
# flow of (927, 926)  is : 33.0
# flow of (927, 928)  is : 0
# flow of (927, 959)  is : 209.0
# flow of (928, 896)  is : -188.0
# flow of (928, 927)  is : 0
# flow of (928, 960)  is : 188.0
# flow of (929, 897)  is : -689.0
# flow of (929, 930)  is : 219.0
# flow of (929, 961)  is : 470.0
# flow of (930, 898)  is : -355.0
# flow of (930, 929)  is : -219.0
# flow of (930, 931)  is : -142.0
# flow of (930, 962)  is : 716.0
# flow of (931, 899)  is : -380.0
# flow of (931, 930)  is : 142.0
# flow of (931, 932)  is : -118.0
# flow of (931, 963)  is : 356.0
# flow of (932, 900)  is : -475.0
# flow of (932, 931)  is : 118.0
# flow of (932, 933)  is : 0
# flow of (932, 964)  is : 357.0
# flow of (933, 901)  is : -279.0
# flow of (933, 932)  is : 0
# flow of (933, 934)  is : 0
# flow of (933, 965)  is : 279.0
# flow of (934, 902)  is : -382.0
# flow of (934, 933)  is : 0
# flow of (934, 935)  is : 0
# flow of (934, 966)  is : 382.0
# flow of (935, 903)  is : -102.0
# flow of (935, 934)  is : 0
# flow of (935, 936)  is : -110.0
# flow of (935, 967)  is : 212.0
# flow of (936, 904)  is : -266.0
# flow of (936, 935)  is : 110.0
# flow of (936, 937)  is : 0
# flow of (936, 968)  is : 156.0
# flow of (937, 905)  is : -207.0
# flow of (937, 936)  is : 0
# flow of (937, 938)  is : 0
# flow of (937, 969)  is : 207.0
# flow of (938, 906)  is : -221.0
# flow of (938, 937)  is : 0
# flow of (938, 939)  is : 0
# flow of (938, 970)  is : 221.0
# flow of (939, 907)  is : -181.0
# flow of (939, 938)  is : 0
# flow of (939, 940)  is : 165.0
# flow of (939, 971)  is : 16.0
# flow of (940, 908)  is : -2.0
# flow of (940, 939)  is : -165.0
# flow of (940, 941)  is : 0
# flow of (940, 972)  is : 167.0
# flow of (941, 909)  is : -67.0
# flow of (941, 940)  is : 0
# flow of (941, 942)  is : 0
# flow of (941, 973)  is : 67.0
# flow of (942, 910)  is : -346.0
# flow of (942, 941)  is : 0
# flow of (942, 943)  is : 187.0
# flow of (942, 974)  is : 159.0
# flow of (943, 911)  is : -572.0
# flow of (943, 942)  is : -187.0
# flow of (943, 944)  is : 0
# flow of (943, 975)  is : 759.0
# flow of (944, 912)  is : -513.0
# flow of (944, 943)  is : 0
# flow of (944, 945)  is : 0
# flow of (944, 976)  is : 513.0
# flow of (945, 913)  is : -400.0
# flow of (945, 944)  is : 0
# flow of (945, 946)  is : 0
# flow of (945, 977)  is : 400.0
# flow of (946, 914)  is : -146.0
# flow of (946, 945)  is : 0
# flow of (946, 947)  is : -276.0
# flow of (946, 978)  is : 422.0
# flow of (947, 915)  is : -23.0
# flow of (947, 946)  is : 276.0
# flow of (947, 948)  is : -437.0
# flow of (947, 979)  is : 184.0
# flow of (948, 916)  is : -512.0
# flow of (948, 947)  is : 437.0
# flow of (948, 949)  is : 0
# flow of (948, 980)  is : 75.0
# flow of (949, 917)  is : -49.0
# flow of (949, 948)  is : 0
# flow of (949, 950)  is : 0
# flow of (949, 981)  is : 49.0
# flow of (950, 918)  is : -306.0
# flow of (950, 949)  is : 0
# flow of (950, 951)  is : 0
# flow of (950, 982)  is : 306.0
# flow of (951, 919)  is : -65.0
# flow of (951, 950)  is : 0
# flow of (951, 952)  is : 0
# flow of (951, 983)  is : 65.0
# flow of (952, 920)  is : -505.0
# flow of (952, 951)  is : 0
# flow of (952, 953)  is : 120.0
# flow of (952, 984)  is : 385.0
# flow of (953, 921)  is : -413.0
# flow of (953, 952)  is : -120.0
# flow of (953, 954)  is : 39.0
# flow of (953, 985)  is : 494.0
# flow of (954, 922)  is : -726.0
# flow of (954, 953)  is : -39.0
# flow of (954, 955)  is : 125.0
# flow of (954, 986)  is : 640.0
# flow of (955, 923)  is : -180.0
# flow of (955, 954)  is : -125.0
# flow of (955, 956)  is : 92.0
# flow of (955, 987)  is : 213.0
# flow of (956, 924)  is : -225.0
# flow of (956, 955)  is : -92.0
# flow of (956, 957)  is : 0
# flow of (956, 988)  is : 317.0
# flow of (957, 925)  is : -259.0
# flow of (957, 956)  is : 0
# flow of (957, 958)  is : 0
# flow of (957, 989)  is : 259.0
# flow of (958, 926)  is : -163.0
# flow of (958, 957)  is : 0
# flow of (958, 959)  is : -49.0
# flow of (958, 990)  is : 212.0
# flow of (959, 927)  is : -209.0
# flow of (959, 958)  is : 49.0
# flow of (959, 960)  is : 0
# flow of (959, 991)  is : 160.0
# flow of (960, 928)  is : -188.0
# flow of (960, 959)  is : 0
# flow of (960, 992)  is : 188.0
# flow of (961, 929)  is : -470.0
# flow of (961, 962)  is : 0
# flow of (961, 993)  is : 470.0
# flow of (962, 930)  is : -716.0
# flow of (962, 961)  is : 0
# flow of (962, 963)  is : 182.0
# flow of (962, 994)  is : 534.0
# flow of (963, 931)  is : -356.0
# flow of (963, 962)  is : -182.0
# flow of (963, 964)  is : -56.0
# flow of (963, 995)  is : 594.0
# flow of (964, 932)  is : -357.0
# flow of (964, 963)  is : 56.0
# flow of (964, 965)  is : 0
# flow of (964, 996)  is : 301.0
# flow of (965, 933)  is : -279.0
# flow of (965, 964)  is : 0
# flow of (965, 966)  is : 0
# flow of (965, 997)  is : 279.0
# flow of (966, 934)  is : -382.0
# flow of (966, 965)  is : 0
# flow of (966, 967)  is : -7.0
# flow of (966, 998)  is : 389.0
# flow of (967, 935)  is : -212.0
# flow of (967, 966)  is : 7.0
# flow of (967, 968)  is : 0
# flow of (967, 999)  is : 205.0
# flow of (968, 936)  is : -156.0
# flow of (968, 967)  is : 0
# flow of (968, 969)  is : 0
# flow of (968, 1000)  is : 156.0
# flow of (969, 937)  is : -207.0
# flow of (969, 968)  is : 0
# flow of (969, 970)  is : -2.0
# flow of (969, 1001)  is : 209.0
# flow of (970, 938)  is : -221.0
# flow of (970, 969)  is : 2.0
# flow of (970, 971)  is : 0
# flow of (970, 1002)  is : 219.0
# flow of (971, 939)  is : -16.0
# flow of (971, 970)  is : 0
# flow of (971, 972)  is : -24.0
# flow of (971, 1003)  is : 40.0
# flow of (972, 940)  is : -167.0
# flow of (972, 971)  is : 24.0
# flow of (972, 973)  is : 0
# flow of (972, 1004)  is : 143.0
# flow of (973, 941)  is : -67.0
# flow of (973, 972)  is : 0
# flow of (973, 974)  is : 0
# flow of (973, 1005)  is : 67.0
# flow of (974, 942)  is : -159.0
# flow of (974, 973)  is : 0
# flow of (974, 975)  is : -296.0
# flow of (974, 1006)  is : 455.0
# flow of (975, 943)  is : -759.0
# flow of (975, 974)  is : 296.0
# flow of (975, 976)  is : 0
# flow of (975, 1007)  is : 463.0
# flow of (976, 944)  is : -513.0
# flow of (976, 975)  is : 0
# flow of (976, 977)  is : 0
# flow of (976, 1008)  is : 513.0
# flow of (977, 945)  is : -400.0
# flow of (977, 976)  is : 0
# flow of (977, 978)  is : 0
# flow of (977, 1009)  is : 400.0
# flow of (978, 946)  is : -422.0
# flow of (978, 977)  is : 0
# flow of (978, 979)  is : -73.0
# flow of (978, 1010)  is : 495.0
# flow of (979, 947)  is : -184.0
# flow of (979, 978)  is : 73.0
# flow of (979, 980)  is : 0
# flow of (979, 1011)  is : 111.0
# flow of (980, 948)  is : -75.0
# flow of (980, 979)  is : 0
# flow of (980, 981)  is : 0
# flow of (980, 1012)  is : 75.0
# flow of (981, 949)  is : -49.0
# flow of (981, 980)  is : 0
# flow of (981, 982)  is : -97.0
# flow of (981, 1013)  is : 146.0
# flow of (982, 950)  is : -306.0
# flow of (982, 981)  is : 97.0
# flow of (982, 983)  is : 0
# flow of (982, 1014)  is : 209.0
# flow of (983, 951)  is : -65.0
# flow of (983, 982)  is : 0
# flow of (983, 984)  is : -312.0
# flow of (983, 1015)  is : 377.0
# flow of (984, 952)  is : -385.0
# flow of (984, 983)  is : 312.0
# flow of (984, 985)  is : 0
# flow of (984, 1016)  is : 73.0
# flow of (985, 953)  is : -494.0
# flow of (985, 984)  is : 0
# flow of (985, 986)  is : -204.0
# flow of (985, 1017)  is : 698.0
# flow of (986, 954)  is : -640.0
# flow of (986, 985)  is : 204.0
# flow of (986, 987)  is : 146.0
# flow of (986, 1018)  is : 290.0
# flow of (987, 955)  is : -213.0
# flow of (987, 986)  is : -146.0
# flow of (987, 988)  is : 0
# flow of (987, 1019)  is : 359.0
# flow of (988, 956)  is : -317.0
# flow of (988, 987)  is : 0
# flow of (988, 989)  is : 0
# flow of (988, 1020)  is : 317.0
# flow of (989, 957)  is : -259.0
# flow of (989, 988)  is : 0
# flow of (989, 990)  is : 0
# flow of (989, 1021)  is : 259.0
# flow of (990, 958)  is : -212.0
# flow of (990, 989)  is : 0
# flow of (990, 991)  is : 0
# flow of (990, 1022)  is : 212.0
# flow of (991, 959)  is : -160.0
# flow of (991, 990)  is : 0
# flow of (991, 992)  is : 0
# flow of (991, 1023)  is : 160.0
# flow of (992, 960)  is : -188.0
# flow of (992, 991)  is : 0
# flow of (992, 1024)  is : 188.0
# flow of (993, 961)  is : -470.0
# flow of (993, 994)  is : 0
# flow of (993, 1025)  is : 470.0
# flow of (994, 962)  is : -534.0
# flow of (994, 993)  is : 0
# flow of (994, 995)  is : 0
# flow of (994, 1025)  is : 534.0
# flow of (995, 963)  is : -594.0
# flow of (995, 994)  is : 0
# flow of (995, 996)  is : 0
# flow of (995, 1025)  is : 594.0
# flow of (996, 964)  is : -301.0
# flow of (996, 995)  is : 0
# flow of (996, 997)  is : 0
# flow of (996, 1025)  is : 301.0
# flow of (997, 965)  is : -279.0
# flow of (997, 996)  is : 0
# flow of (997, 998)  is : 0
# flow of (997, 1025)  is : 279.0
# flow of (998, 966)  is : -389.0
# flow of (998, 997)  is : 0
# flow of (998, 999)  is : 0
# flow of (998, 1025)  is : 389.0
# flow of (999, 967)  is : -205.0
# flow of (999, 998)  is : 0
# flow of (999, 1000)  is : 0
# flow of (999, 1025)  is : 205.0
# flow of (1000, 968)  is : -156.0
# flow of (1000, 999)  is : 0
# flow of (1000, 1001)  is : 0
# flow of (1000, 1025)  is : 156.0
# flow of (1001, 969)  is : -209.0
# flow of (1001, 1000)  is : 0
# flow of (1001, 1002)  is : 0
# flow of (1001, 1025)  is : 209.0
# flow of (1002, 970)  is : -219.0
# flow of (1002, 1001)  is : 0
# flow of (1002, 1003)  is : 0
# flow of (1002, 1025)  is : 219.0
# flow of (1003, 971)  is : -40.0
# flow of (1003, 1002)  is : 0
# flow of (1003, 1004)  is : 0
# flow of (1003, 1025)  is : 40.0
# flow of (1004, 972)  is : -143.0
# flow of (1004, 1003)  is : 0
# flow of (1004, 1005)  is : 0
# flow of (1004, 1025)  is : 143.0
# flow of (1005, 973)  is : -67.0
# flow of (1005, 1004)  is : 0
# flow of (1005, 1006)  is : 0
# flow of (1005, 1025)  is : 67.0
# flow of (1006, 974)  is : -455.0
# flow of (1006, 1005)  is : 0
# flow of (1006, 1007)  is : 0
# flow of (1006, 1025)  is : 455.0
# flow of (1007, 975)  is : -463.0
# flow of (1007, 1006)  is : 0
# flow of (1007, 1008)  is : 0
# flow of (1007, 1025)  is : 463.0
# flow of (1008, 976)  is : -513.0
# flow of (1008, 1007)  is : 0
# flow of (1008, 1009)  is : 0
# flow of (1008, 1025)  is : 513.0
# flow of (1009, 977)  is : -400.0
# flow of (1009, 1008)  is : 0
# flow of (1009, 1010)  is : 0
# flow of (1009, 1025)  is : 400.0
# flow of (1010, 978)  is : -495.0
# flow of (1010, 1009)  is : 0
# flow of (1010, 1011)  is : 0
# flow of (1010, 1025)  is : 495.0
# flow of (1011, 979)  is : -111.0
# flow of (1011, 1010)  is : 0
# flow of (1011, 1012)  is : 0
# flow of (1011, 1025)  is : 111.0
# flow of (1012, 980)  is : -75.0
# flow of (1012, 1011)  is : 0
# flow of (1012, 1013)  is : 0
# flow of (1012, 1025)  is : 75.0
# flow of (1013, 981)  is : -146.0
# flow of (1013, 1012)  is : 0
# flow of (1013, 1014)  is : 0
# flow of (1013, 1025)  is : 146.0
# flow of (1014, 982)  is : -209.0
# flow of (1014, 1013)  is : 0
# flow of (1014, 1015)  is : 0
# flow of (1014, 1025)  is : 209.0
# flow of (1015, 983)  is : -377.0
# flow of (1015, 1014)  is : 0
# flow of (1015, 1016)  is : 0
# flow of (1015, 1025)  is : 377.0
# flow of (1016, 984)  is : -73.0
# flow of (1016, 1015)  is : 0
# flow of (1016, 1017)  is : 0
# flow of (1016, 1025)  is : 73.0
# flow of (1017, 985)  is : -698.0
# flow of (1017, 1016)  is : 0
# flow of (1017, 1018)  is : -110.0
# flow of (1017, 1025)  is : 808.0
# flow of (1018, 986)  is : -290.0
# flow of (1018, 1017)  is : 110.0
# flow of (1018, 1019)  is : 0
# flow of (1018, 1025)  is : 180.0
# flow of (1019, 987)  is : -359.0
# flow of (1019, 1018)  is : 0
# flow of (1019, 1020)  is : 0
# flow of (1019, 1025)  is : 359.0
# flow of (1020, 988)  is : -317.0
# flow of (1020, 1019)  is : 0
# flow of (1020, 1021)  is : 0
# flow of (1020, 1025)  is : 317.0
# flow of (1021, 989)  is : -259.0
# flow of (1021, 1020)  is : 0
# flow of (1021, 1022)  is : 0
# flow of (1021, 1025)  is : 259.0
# flow of (1022, 990)  is : -212.0
# flow of (1022, 1021)  is : 0
# flow of (1022, 1023)  is : -118.0
# flow of (1022, 1025)  is : 330.0
# flow of (1023, 991)  is : -160.0
# flow of (1023, 1022)  is : 118.0
# flow of (1023, 1024)  is : 0
# flow of (1023, 1025)  is : 42.0
# flow of (1024, 992)  is : -188.0
# flow of (1024, 1023)  is : 0
# flow of (1024, 1025)  is : 188.0
# flow of (1025, 993)  is : -470.0
# flow of (1025, 994)  is : -534.0
# flow of (1025, 995)  is : -594.0
# flow of (1025, 996)  is : -301.0
# flow of (1025, 997)  is : -279.0
# flow of (1025, 998)  is : -389.0
# flow of (1025, 999)  is : -205.0
# flow of (1025, 1000)  is : -156.0
# flow of (1025, 1001)  is : -209.0
# flow of (1025, 1002)  is : -219.0
# flow of (1025, 1003)  is : -40.0
# flow of (1025, 1004)  is : -143.0
# flow of (1025, 1005)  is : -67.0
# flow of (1025, 1006)  is : -455.0
# flow of (1025, 1007)  is : -463.0
# flow of (1025, 1008)  is : -513.0
# flow of (1025, 1009)  is : -400.0
# flow of (1025, 1010)  is : -495.0
# flow of (1025, 1011)  is : -111.0
# flow of (1025, 1012)  is : -75.0
# flow of (1025, 1013)  is : -146.0
# flow of (1025, 1014)  is : -209.0
# flow of (1025, 1015)  is : -377.0
# flow of (1025, 1016)  is : -73.0
# flow of (1025, 1017)  is : -808.0
# flow of (1025, 1018)  is : -180.0
# flow of (1025, 1019)  is : -359.0
# flow of (1025, 1020)  is : -317.0
# flow of (1025, 1021)  is : -259.0
# flow of (1025, 1022)  is : -330.0
# flow of (1025, 1023)  is : -42.0
# flow of (1025, 1024)  is : -188.0

# %%
from networkx.algorithms.flow import shortest_augmenting_path
result2 = shortest_augmenting_path(G, 0, 1025,capacity='weight')
flow_value3 = nx.maximum_flow_value(G, 0, 1025,capacity='weight')
print("optimal flow from shortest_augmenting_path algorithm is:",flow_value3)

for g in G.edges():
    print("flow of",g," is :",result2[g[0]][g[1]]['flow'])
# Out:
# optimal flow from shortest_augmenting_path algorithm is: 9406.0
# flow of (0, 1)  is : 394.0
# flow of (0, 2)  is : 401.0
# flow of (0, 3)  is : 108.0
# flow of (0, 4)  is : 186.0
# flow of (0, 5)  is : 744.0
# flow of (0, 6)  is : 94.0
# flow of (0, 7)  is : 70.0
# flow of (0, 8)  is : 371.0
# flow of (0, 9)  is : 748.0
# flow of (0, 10)  is : 310.0
# flow of (0, 11)  is : 267.0
# flow of (0, 12)  is : 13.0
# flow of (0, 13)  is : 315.0
# flow of (0, 14)  is : 406.0
# flow of (0, 15)  is : 64.0
# flow of (0, 16)  is : 196.0
# flow of (0, 17)  is : 437.0
# flow of (0, 18)  is : 318.0
# flow of (0, 19)  is : 371.0
# flow of (0, 20)  is : 444.0
# flow of (0, 21)  is : 468.0
# flow of (0, 22)  is : 305.0
# flow of (0, 23)  is : 349.0
# flow of (0, 24)  is : 130.0
# flow of (0, 25)  is : 551.0
# flow of (0, 26)  is : 20.0
# flow of (0, 27)  is : 228.0
# flow of (0, 28)  is : 18.0
# flow of (0, 29)  is : 227.0
# flow of (0, 30)  is : 490.0
# flow of (0, 31)  is : 42.0
# flow of (0, 32)  is : 321.0
# flow of (1, 0)  is : -394.0
# flow of (1, 2)  is : 331.0
# flow of (1, 33)  is : 63.0
# flow of (2, 0)  is : -401.0
# flow of (2, 1)  is : -331.0
# flow of (2, 3)  is : 257.0
# flow of (2, 34)  is : 475.0
# flow of (3, 0)  is : -108.0
# flow of (3, 2)  is : -257.0
# flow of (3, 4)  is : 166.0
# flow of (3, 35)  is : 199.0
# flow of (4, 0)  is : -186.0
# flow of (4, 3)  is : -166.0
# flow of (4, 5)  is : -5.0
# flow of (4, 36)  is : 357.0
# flow of (5, 0)  is : -744.0
# flow of (5, 4)  is : 5.0
# flow of (5, 6)  is : 184.0
# flow of (5, 37)  is : 555.0
# flow of (6, 0)  is : -94.0
# flow of (6, 5)  is : -184.0
# flow of (6, 7)  is : -4.0
# flow of (6, 38)  is : 282.0
# flow of (7, 0)  is : -70.0
# flow of (7, 6)  is : 4.0
# flow of (7, 8)  is : -251.0
# flow of (7, 39)  is : 317.0
# flow of (8, 0)  is : -371.0
# flow of (8, 7)  is : 251.0
# flow of (8, 9)  is : 0
# flow of (8, 40)  is : 120.0
# flow of (9, 0)  is : -748.0
# flow of (9, 8)  is : 0
# flow of (9, 10)  is : 0
# flow of (9, 41)  is : 748.0
# flow of (10, 0)  is : -310.0
# flow of (10, 9)  is : 0
# flow of (10, 11)  is : 0
# flow of (10, 42)  is : 310.0
# flow of (11, 0)  is : -267.0
# flow of (11, 10)  is : 0
# flow of (11, 12)  is : 95.0
# flow of (11, 43)  is : 172.0
# flow of (12, 0)  is : -13.0
# flow of (12, 11)  is : -95.0
# flow of (12, 13)  is : 0
# flow of (12, 44)  is : 108.0
# flow of (13, 0)  is : -315.0
# flow of (13, 12)  is : 0
# flow of (13, 14)  is : 73.0
# flow of (13, 45)  is : 242.0
# flow of (14, 0)  is : -406.0
# flow of (14, 13)  is : -73.0
# flow of (14, 15)  is : 98.0
# flow of (14, 46)  is : 381.0
# flow of (15, 0)  is : -64.0
# flow of (15, 14)  is : -98.0
# flow of (15, 16)  is : 0
# flow of (15, 47)  is : 162.0
# flow of (16, 0)  is : -196.0
# flow of (16, 15)  is : 0
# flow of (16, 17)  is : 54.0
# flow of (16, 48)  is : 142.0
# flow of (17, 0)  is : -437.0
# flow of (17, 16)  is : -54.0
# flow of (17, 18)  is : 255.0
# flow of (17, 49)  is : 236.0
# flow of (18, 0)  is : -318.0
# flow of (18, 17)  is : -255.0
# flow of (18, 19)  is : -19.0
# flow of (18, 50)  is : 592.0
# flow of (19, 0)  is : -371.0
# flow of (19, 18)  is : 19.0
# flow of (19, 20)  is : 0
# flow of (19, 51)  is : 352.0
# flow of (20, 0)  is : -444.0
# flow of (20, 19)  is : 0
# flow of (20, 21)  is : 94.0
# flow of (20, 52)  is : 350.0
# flow of (21, 0)  is : -468.0
# flow of (21, 20)  is : -94.0
# flow of (21, 22)  is : 88.0
# flow of (21, 53)  is : 474.0
# flow of (22, 0)  is : -305.0
# flow of (22, 21)  is : -88.0
# flow of (22, 23)  is : -282.0
# flow of (22, 54)  is : 675.0
# flow of (23, 0)  is : -349.0
# flow of (23, 22)  is : 282.0
# flow of (23, 24)  is : 0
# flow of (23, 55)  is : 67.0
# flow of (24, 0)  is : -130.0
# flow of (24, 23)  is : 0
# flow of (24, 25)  is : 0
# flow of (24, 56)  is : 130.0
# flow of (25, 0)  is : -551.0
# flow of (25, 24)  is : 0
# flow of (25, 26)  is : 172.0
# flow of (25, 57)  is : 379.0
# flow of (26, 0)  is : -20.0
# flow of (26, 25)  is : -172.0
# flow of (26, 27)  is : -101.0
# flow of (26, 58)  is : 293.0
# flow of (27, 0)  is : -228.0
# flow of (27, 26)  is : 101.0
# flow of (27, 28)  is : 0
# flow of (27, 59)  is : 127.0
# flow of (28, 0)  is : -18.0
# flow of (28, 27)  is : 0
# flow of (28, 29)  is : 0
# flow of (28, 60)  is : 18.0
# flow of (29, 0)  is : -227.0
# flow of (29, 28)  is : 0
# flow of (29, 30)  is : 0
# flow of (29, 61)  is : 227.0
# flow of (30, 0)  is : -490.0
# flow of (30, 29)  is : 0
# flow of (30, 31)  is : 0
# flow of (30, 62)  is : 490.0
# flow of (31, 0)  is : -42.0
# flow of (31, 30)  is : 0
# flow of (31, 32)  is : 9.0
# flow of (31, 63)  is : 33.0
# flow of (32, 0)  is : -321.0
# flow of (32, 31)  is : -9.0
# flow of (32, 64)  is : 330.0
# flow of (33, 1)  is : -63.0
# flow of (33, 34)  is : -125.0
# flow of (33, 65)  is : 188.0
# flow of (34, 2)  is : -475.0
# flow of (34, 33)  is : 125.0
# flow of (34, 35)  is : 136.0
# flow of (34, 66)  is : 214.0
# flow of (35, 3)  is : -199.0
# flow of (35, 34)  is : -136.0
# flow of (35, 36)  is : -117.0
# flow of (35, 67)  is : 452.0
# flow of (36, 4)  is : -357.0
# flow of (36, 35)  is : 117.0
# flow of (36, 37)  is : -150.0
# flow of (36, 68)  is : 390.0
# flow of (37, 5)  is : -555.0
# flow of (37, 36)  is : 150.0
# flow of (37, 38)  is : 0
# flow of (37, 69)  is : 405.0
# flow of (38, 6)  is : -282.0
# flow of (38, 37)  is : 0
# flow of (38, 39)  is : -230.0
# flow of (38, 70)  is : 512.0
# flow of (39, 7)  is : -317.0
# flow of (39, 38)  is : 230.0
# flow of (39, 40)  is : 21.0
# flow of (39, 71)  is : 66.0
# flow of (40, 8)  is : -120.0
# flow of (40, 39)  is : -21.0
# flow of (40, 41)  is : -48.0
# flow of (40, 72)  is : 189.0
# flow of (41, 9)  is : -748.0
# flow of (41, 40)  is : 48.0
# flow of (41, 42)  is : 4.0
# flow of (41, 73)  is : 696.0
# flow of (42, 10)  is : -310.0
# flow of (42, 41)  is : -4.0
# flow of (42, 43)  is : 31.0
# flow of (42, 74)  is : 283.0
# flow of (43, 11)  is : -172.0
# flow of (43, 42)  is : -31.0
# flow of (43, 44)  is : 0
# flow of (43, 75)  is : 203.0
# flow of (44, 12)  is : -108.0
# flow of (44, 43)  is : 0
# flow of (44, 45)  is : -145.0
# flow of (44, 76)  is : 253.0
# flow of (45, 13)  is : -242.0
# flow of (45, 44)  is : 145.0
# flow of (45, 46)  is : 0
# flow of (45, 77)  is : 97.0
# flow of (46, 14)  is : -381.0
# flow of (46, 45)  is : 0
# flow of (46, 47)  is : 0
# flow of (46, 78)  is : 381.0
# flow of (47, 15)  is : -162.0
# flow of (47, 46)  is : 0
# flow of (47, 48)  is : 0
# flow of (47, 79)  is : 162.0
# flow of (48, 16)  is : -142.0
# flow of (48, 47)  is : 0
# flow of (48, 49)  is : 0
# flow of (48, 80)  is : 142.0
# flow of (49, 17)  is : -236.0
# flow of (49, 48)  is : 0
# flow of (49, 50)  is : 0
# flow of (49, 81)  is : 236.0
# flow of (50, 18)  is : -592.0
# flow of (50, 49)  is : 0
# flow of (50, 51)  is : -64.0
# flow of (50, 82)  is : 656.0
# flow of (51, 19)  is : -352.0
# flow of (51, 50)  is : 64.0
# flow of (51, 52)  is : 0
# flow of (51, 83)  is : 288.0
# flow of (52, 20)  is : -350.0
# flow of (52, 51)  is : 0
# flow of (52, 53)  is : 0
# flow of (52, 84)  is : 350.0
# flow of (53, 21)  is : -474.0
# flow of (53, 52)  is : 0
# flow of (53, 54)  is : 0
# flow of (53, 85)  is : 474.0
# flow of (54, 22)  is : -675.0
# flow of (54, 53)  is : 0
# flow of (54, 55)  is : 0
# flow of (54, 86)  is : 675.0
# flow of (55, 23)  is : -67.0
# flow of (55, 54)  is : 0
# flow of (55, 56)  is : 0
# flow of (55, 87)  is : 67.0
# flow of (56, 24)  is : -130.0
# flow of (56, 55)  is : 0
# flow of (56, 57)  is : 0
# flow of (56, 88)  is : 130.0
# flow of (57, 25)  is : -379.0
# flow of (57, 56)  is : 0
# flow of (57, 58)  is : 100.0
# flow of (57, 89)  is : 279.0
# flow of (58, 26)  is : -293.0
# flow of (58, 57)  is : -100.0
# flow of (58, 59)  is : 3.0
# flow of (58, 90)  is : 390.0
# flow of (59, 27)  is : -127.0
# flow of (59, 58)  is : -3.0
# flow of (59, 60)  is : 72.0
# flow of (59, 91)  is : 58.0
# flow of (60, 28)  is : -18.0
# flow of (60, 59)  is : -72.0
# flow of (60, 61)  is : -8.0
# flow of (60, 92)  is : 98.0
# flow of (61, 29)  is : -227.0
# flow of (61, 60)  is : 8.0
# flow of (61, 62)  is : 0
# flow of (61, 93)  is : 219.0
# flow of (62, 30)  is : -490.0
# flow of (62, 61)  is : 0
# flow of (62, 63)  is : 0
# flow of (62, 94)  is : 490.0
# flow of (63, 31)  is : -33.0
# flow of (63, 62)  is : 0
# flow of (63, 64)  is : 17.0
# flow of (63, 95)  is : 16.0
# flow of (64, 32)  is : -330.0
# flow of (64, 63)  is : -17.0
# flow of (64, 96)  is : 347.0
# flow of (65, 33)  is : -188.0
# flow of (65, 66)  is : 34.0
# flow of (65, 97)  is : 154.0
# flow of (66, 34)  is : -214.0
# flow of (66, 65)  is : -34.0
# flow of (66, 67)  is : -62.0
# flow of (66, 98)  is : 310.0
# flow of (67, 35)  is : -452.0
# flow of (67, 66)  is : 62.0
# flow of (67, 68)  is : 0
# flow of (67, 99)  is : 390.0
# flow of (68, 36)  is : -390.0
# flow of (68, 67)  is : 0
# flow of (68, 69)  is : -62.0
# flow of (68, 100)  is : 452.0
# flow of (69, 37)  is : -405.0
# flow of (69, 68)  is : 62.0
# flow of (69, 70)  is : -285.0
# flow of (69, 101)  is : 628.0
# flow of (70, 38)  is : -512.0
# flow of (70, 69)  is : 285.0
# flow of (70, 71)  is : 0
# flow of (70, 102)  is : 227.0
# flow of (71, 39)  is : -66.0
# flow of (71, 70)  is : 0
# flow of (71, 72)  is : 11.0
# flow of (71, 103)  is : 55.0
# flow of (72, 40)  is : -189.0
# flow of (72, 71)  is : -11.0
# flow of (72, 73)  is : -561.0
# flow of (72, 104)  is : 761.0
# flow of (73, 41)  is : -696.0
# flow of (73, 72)  is : 561.0
# flow of (73, 74)  is : -44.0
# flow of (73, 105)  is : 179.0
# flow of (74, 42)  is : -283.0
# flow of (74, 73)  is : 44.0
# flow of (74, 75)  is : 0
# flow of (74, 106)  is : 239.0
# flow of (75, 43)  is : -203.0
# flow of (75, 74)  is : 0
# flow of (75, 76)  is : 0
# flow of (75, 107)  is : 203.0
# flow of (76, 44)  is : -253.0
# flow of (76, 75)  is : 0
# flow of (76, 77)  is : 158.0
# flow of (76, 108)  is : 95.0
# flow of (77, 45)  is : -97.0
# flow of (77, 76)  is : -158.0
# flow of (77, 78)  is : 46.0
# flow of (77, 109)  is : 209.0
# flow of (78, 46)  is : -381.0
# flow of (78, 77)  is : -46.0
# flow of (78, 79)  is : 74.0
# flow of (78, 110)  is : 353.0
# flow of (79, 47)  is : -162.0
# flow of (79, 78)  is : -74.0
# flow of (79, 80)  is : -133.0
# flow of (79, 111)  is : 369.0
# flow of (80, 48)  is : -142.0
# flow of (80, 79)  is : 133.0
# flow of (80, 81)  is : -229.0
# flow of (80, 112)  is : 238.0
# flow of (81, 49)  is : -236.0
# flow of (81, 80)  is : 229.0
# flow of (81, 82)  is : 0
# flow of (81, 113)  is : 7.0
# flow of (82, 50)  is : -656.0
# flow of (82, 81)  is : 0
# flow of (82, 83)  is : 0
# flow of (82, 114)  is : 656.0
# flow of (83, 51)  is : -288.0
# flow of (83, 82)  is : 0
# flow of (83, 84)  is : -121.0
# flow of (83, 115)  is : 409.0
# flow of (84, 52)  is : -350.0
# flow of (84, 83)  is : 121.0
# flow of (84, 85)  is : 0
# flow of (84, 116)  is : 229.0
# flow of (85, 53)  is : -474.0
# flow of (85, 84)  is : 0
# flow of (85, 86)  is : 0
# flow of (85, 117)  is : 474.0
# flow of (86, 54)  is : -675.0
# flow of (86, 85)  is : 0
# flow of (86, 87)  is : 166.0
# flow of (86, 118)  is : 509.0
# flow of (87, 55)  is : -67.0
# flow of (87, 86)  is : -166.0
# flow of (87, 88)  is : -75.0
# flow of (87, 119)  is : 308.0
# flow of (88, 56)  is : -130.0
# flow of (88, 87)  is : 75.0
# flow of (88, 89)  is : 0
# flow of (88, 120)  is : 55.0
# flow of (89, 57)  is : -279.0
# flow of (89, 88)  is : 0
# flow of (89, 90)  is : 223.0
# flow of (89, 121)  is : 56.0
# flow of (90, 58)  is : -390.0
# flow of (90, 89)  is : -223.0
# flow of (90, 91)  is : 360.0
# flow of (90, 122)  is : 253.0
# flow of (91, 59)  is : -58.0
# flow of (91, 90)  is : -360.0
# flow of (91, 92)  is : 0
# flow of (91, 123)  is : 418.0
# flow of (92, 60)  is : -98.0
# flow of (92, 91)  is : 0
# flow of (92, 93)  is : -120.0
# flow of (92, 124)  is : 218.0
# flow of (93, 61)  is : -219.0
# flow of (93, 92)  is : 120.0
# flow of (93, 94)  is : 0
# flow of (93, 125)  is : 99.0
# flow of (94, 62)  is : -490.0
# flow of (94, 93)  is : 0
# flow of (94, 95)  is : 0
# flow of (94, 126)  is : 490.0
# flow of (95, 63)  is : -16.0
# flow of (95, 94)  is : 0
# flow of (95, 96)  is : 0
# flow of (95, 127)  is : 16.0
# flow of (96, 64)  is : -347.0
# flow of (96, 95)  is : 0
# flow of (96, 128)  is : 347.0
# flow of (97, 65)  is : -154.0
# flow of (97, 98)  is : 125.0
# flow of (97, 129)  is : 29.0
# flow of (98, 66)  is : -310.0
# flow of (98, 97)  is : -125.0
# flow of (98, 99)  is : -114.0
# flow of (98, 130)  is : 549.0
# flow of (99, 67)  is : -390.0
# flow of (99, 98)  is : 114.0
# flow of (99, 100)  is : 0
# flow of (99, 131)  is : 276.0
# flow of (100, 68)  is : -452.0
# flow of (100, 99)  is : 0
# flow of (100, 101)  is : 0
# flow of (100, 132)  is : 452.0
# flow of (101, 69)  is : -628.0
# flow of (101, 100)  is : 0
# flow of (101, 102)  is : 0
# flow of (101, 133)  is : 628.0
# flow of (102, 70)  is : -227.0
# flow of (102, 101)  is : 0
# flow of (102, 103)  is : 210.0
# flow of (102, 134)  is : 17.0
# flow of (103, 71)  is : -55.0
# flow of (103, 102)  is : -210.0
# flow of (103, 104)  is : -20.0
# flow of (103, 135)  is : 285.0
# flow of (104, 72)  is : -761.0
# flow of (104, 103)  is : 20.0
# flow of (104, 105)  is : -44.0
# flow of (104, 136)  is : 785.0
# flow of (105, 73)  is : -179.0
# flow of (105, 104)  is : 44.0
# flow of (105, 106)  is : 0
# flow of (105, 137)  is : 135.0
# flow of (106, 74)  is : -239.0
# flow of (106, 105)  is : 0
# flow of (106, 107)  is : 172.0
# flow of (106, 138)  is : 67.0
# flow of (107, 75)  is : -203.0
# flow of (107, 106)  is : -172.0
# flow of (107, 108)  is : -169.0
# flow of (107, 139)  is : 544.0
# flow of (108, 76)  is : -95.0
# flow of (108, 107)  is : 169.0
# flow of (108, 109)  is : -118.0
# flow of (108, 140)  is : 44.0
# flow of (109, 77)  is : -209.0
# flow of (109, 108)  is : 118.0
# flow of (109, 110)  is : -285.0
# flow of (109, 141)  is : 376.0
# flow of (110, 78)  is : -353.0
# flow of (110, 109)  is : 285.0
# flow of (110, 111)  is : 64.0
# flow of (110, 142)  is : 4.0
# flow of (111, 79)  is : -369.0
# flow of (111, 110)  is : -64.0
# flow of (111, 112)  is : 0
# flow of (111, 143)  is : 433.0
# flow of (112, 80)  is : -238.0
# flow of (112, 111)  is : 0
# flow of (112, 113)  is : 75.0
# flow of (112, 144)  is : 163.0
# flow of (113, 81)  is : -7.0
# flow of (113, 112)  is : -75.0
# flow of (113, 114)  is : -236.0
# flow of (113, 145)  is : 318.0
# flow of (114, 82)  is : -656.0
# flow of (114, 113)  is : 236.0
# flow of (114, 115)  is : -155.0
# flow of (114, 146)  is : 575.0
# flow of (115, 83)  is : -409.0
# flow of (115, 114)  is : 155.0
# flow of (115, 116)  is : 0
# flow of (115, 147)  is : 254.0
# flow of (116, 84)  is : -229.0
# flow of (116, 115)  is : 0
# flow of (116, 117)  is : 0
# flow of (116, 148)  is : 229.0
# flow of (117, 85)  is : -474.0
# flow of (117, 116)  is : 0
# flow of (117, 118)  is : 0
# flow of (117, 149)  is : 474.0
# flow of (118, 86)  is : -509.0
# flow of (118, 117)  is : 0
# flow of (118, 119)  is : 0
# flow of (118, 150)  is : 509.0
# flow of (119, 87)  is : -308.0
# flow of (119, 118)  is : 0
# flow of (119, 120)  is : 0
# flow of (119, 151)  is : 308.0
# flow of (120, 88)  is : -55.0
# flow of (120, 119)  is : 0
# flow of (120, 121)  is : 0
# flow of (120, 152)  is : 55.0
# flow of (121, 89)  is : -56.0
# flow of (121, 120)  is : 0
# flow of (121, 122)  is : 0
# flow of (121, 153)  is : 56.0
# flow of (122, 90)  is : -253.0
# flow of (122, 121)  is : 0
# flow of (122, 123)  is : 0
# flow of (122, 154)  is : 253.0
# flow of (123, 91)  is : -418.0
# flow of (123, 122)  is : 0
# flow of (123, 124)  is : 0
# flow of (123, 155)  is : 418.0
# flow of (124, 92)  is : -218.0
# flow of (124, 123)  is : 0
# flow of (124, 125)  is : -71.0
# flow of (124, 156)  is : 289.0
# flow of (125, 93)  is : -99.0
# flow of (125, 124)  is : 71.0
# flow of (125, 126)  is : 0
# flow of (125, 157)  is : 28.0
# flow of (126, 94)  is : -490.0
# flow of (126, 125)  is : 0
# flow of (126, 127)  is : 0
# flow of (126, 158)  is : 490.0
# flow of (127, 95)  is : -16.0
# flow of (127, 126)  is : 0
# flow of (127, 128)  is : 0
# flow of (127, 159)  is : 16.0
# flow of (128, 96)  is : -347.0
# flow of (128, 127)  is : 0
# flow of (128, 160)  is : 347.0
# flow of (129, 97)  is : -29.0
# flow of (129, 130)  is : 0
# flow of (129, 161)  is : 29.0
# flow of (130, 98)  is : -549.0
# flow of (130, 129)  is : 0
# flow of (130, 131)  is : 0
# flow of (130, 162)  is : 549.0
# flow of (131, 99)  is : -276.0
# flow of (131, 130)  is : 0
# flow of (131, 132)  is : 0
# flow of (131, 163)  is : 276.0
# flow of (132, 100)  is : -452.0
# flow of (132, 131)  is : 0
# flow of (132, 133)  is : 0
# flow of (132, 164)  is : 452.0
# flow of (133, 101)  is : -628.0
# flow of (133, 132)  is : 0
# flow of (133, 134)  is : 0
# flow of (133, 165)  is : 628.0
# flow of (134, 102)  is : -17.0
# flow of (134, 133)  is : 0
# flow of (134, 135)  is : 0
# flow of (134, 166)  is : 17.0
# flow of (135, 103)  is : -285.0
# flow of (135, 134)  is : 0
# flow of (135, 136)  is : 0
# flow of (135, 167)  is : 285.0
# flow of (136, 104)  is : -785.0
# flow of (136, 135)  is : 0
# flow of (136, 137)  is : 289.0
# flow of (136, 168)  is : 496.0
# flow of (137, 105)  is : -135.0
# flow of (137, 136)  is : -289.0
# flow of (137, 138)  is : 301.0
# flow of (137, 169)  is : 123.0
# flow of (138, 106)  is : -67.0
# flow of (138, 137)  is : -301.0
# flow of (138, 139)  is : 56.0
# flow of (138, 170)  is : 312.0
# flow of (139, 107)  is : -544.0
# flow of (139, 138)  is : -56.0
# flow of (139, 140)  is : 0
# flow of (139, 171)  is : 600.0
# flow of (140, 108)  is : -44.0
# flow of (140, 139)  is : 0
# flow of (140, 141)  is : -55.0
# flow of (140, 172)  is : 99.0
# flow of (141, 109)  is : -376.0
# flow of (141, 140)  is : 55.0
# flow of (141, 142)  is : 211.0
# flow of (141, 173)  is : 110.0
# flow of (142, 110)  is : -4.0
# flow of (142, 141)  is : -211.0
# flow of (142, 143)  is : -181.0
# flow of (142, 174)  is : 396.0
# flow of (143, 111)  is : -433.0
# flow of (143, 142)  is : 181.0
# flow of (143, 144)  is : -69.0
# flow of (143, 175)  is : 321.0
# flow of (144, 112)  is : -163.0
# flow of (144, 143)  is : 69.0
# flow of (144, 145)  is : 0
# flow of (144, 176)  is : 94.0
# flow of (145, 113)  is : -318.0
# flow of (145, 144)  is : 0
# flow of (145, 146)  is : -203.0
# flow of (145, 177)  is : 521.0
# flow of (146, 114)  is : -575.0
# flow of (146, 145)  is : 203.0
# flow of (146, 147)  is : 0
# flow of (146, 178)  is : 372.0
# flow of (147, 115)  is : -254.0
# flow of (147, 146)  is : 0
# flow of (147, 148)  is : -156.0
# flow of (147, 179)  is : 410.0
# flow of (148, 116)  is : -229.0
# flow of (148, 147)  is : 156.0
# flow of (148, 149)  is : 25.0
# flow of (148, 180)  is : 48.0
# flow of (149, 117)  is : -474.0
# flow of (149, 148)  is : -25.0
# flow of (149, 150)  is : 0
# flow of (149, 181)  is : 499.0
# flow of (150, 118)  is : -509.0
# flow of (150, 149)  is : 0
# flow of (150, 151)  is : 303.0
# flow of (150, 182)  is : 206.0
# flow of (151, 119)  is : -308.0
# flow of (151, 150)  is : -303.0
# flow of (151, 152)  is : 14.0
# flow of (151, 183)  is : 597.0
# flow of (152, 120)  is : -55.0
# flow of (152, 151)  is : -14.0
# flow of (152, 153)  is : -42.0
# flow of (152, 184)  is : 111.0
# flow of (153, 121)  is : -56.0
# flow of (153, 152)  is : 42.0
# flow of (153, 154)  is : 0
# flow of (153, 185)  is : 14.0
# flow of (154, 122)  is : -253.0
# flow of (154, 153)  is : 0
# flow of (154, 155)  is : 0
# flow of (154, 186)  is : 253.0
# flow of (155, 123)  is : -418.0
# flow of (155, 154)  is : 0
# flow of (155, 156)  is : 0
# flow of (155, 187)  is : 418.0
# flow of (156, 124)  is : -289.0
# flow of (156, 155)  is : 0
# flow of (156, 157)  is : 0
# flow of (156, 188)  is : 289.0
# flow of (157, 125)  is : -28.0
# flow of (157, 156)  is : 0
# flow of (157, 158)  is : 0
# flow of (157, 189)  is : 28.0
# flow of (158, 126)  is : -490.0
# flow of (158, 157)  is : 0
# flow of (158, 159)  is : 0
# flow of (158, 190)  is : 490.0
# flow of (159, 127)  is : -16.0
# flow of (159, 158)  is : 0
# flow of (159, 160)  is : 0
# flow of (159, 191)  is : 16.0
# flow of (160, 128)  is : -347.0
# flow of (160, 159)  is : 0
# flow of (160, 192)  is : 347.0
# flow of (161, 129)  is : -29.0
# flow of (161, 162)  is : 0
# flow of (161, 193)  is : 29.0
# flow of (162, 130)  is : -549.0
# flow of (162, 161)  is : 0
# flow of (162, 163)  is : 0
# flow of (162, 194)  is : 549.0
# flow of (163, 131)  is : -276.0
# flow of (163, 162)  is : 0
# flow of (163, 164)  is : 0
# flow of (163, 195)  is : 276.0
# flow of (164, 132)  is : -452.0
# flow of (164, 163)  is : 0
# flow of (164, 165)  is : -79.0
# flow of (164, 196)  is : 531.0
# flow of (165, 133)  is : -628.0
# flow of (165, 164)  is : 79.0
# flow of (165, 166)  is : 0
# flow of (165, 197)  is : 549.0
# flow of (166, 134)  is : -17.0
# flow of (166, 165)  is : 0
# flow of (166, 167)  is : 0
# flow of (166, 198)  is : 17.0
# flow of (167, 135)  is : -285.0
# flow of (167, 166)  is : 0
# flow of (167, 168)  is : 0
# flow of (167, 199)  is : 285.0
# flow of (168, 136)  is : -496.0
# flow of (168, 167)  is : 0
# flow of (168, 169)  is : 5.0
# flow of (168, 200)  is : 491.0
# flow of (169, 137)  is : -123.0
# flow of (169, 168)  is : -5.0
# flow of (169, 170)  is : 85.0
# flow of (169, 201)  is : 43.0
# flow of (170, 138)  is : -312.0
# flow of (170, 169)  is : -85.0
# flow of (170, 171)  is : -8.0
# flow of (170, 202)  is : 405.0
# flow of (171, 139)  is : -600.0
# flow of (171, 170)  is : 8.0
# flow of (171, 172)  is : 45.0
# flow of (171, 203)  is : 547.0
# flow of (172, 140)  is : -99.0
# flow of (172, 171)  is : -45.0
# flow of (172, 173)  is : 19.0
# flow of (172, 204)  is : 125.0
# flow of (173, 141)  is : -110.0
# flow of (173, 172)  is : -19.0
# flow of (173, 174)  is : -25.0
# flow of (173, 205)  is : 154.0
# flow of (174, 142)  is : -396.0
# flow of (174, 173)  is : 25.0
# flow of (174, 175)  is : 0
# flow of (174, 206)  is : 371.0
# flow of (175, 143)  is : -321.0
# flow of (175, 174)  is : 0
# flow of (175, 176)  is : -138.0
# flow of (175, 207)  is : 459.0
# flow of (176, 144)  is : -94.0
# flow of (176, 175)  is : 138.0
# flow of (176, 177)  is : -188.0
# flow of (176, 208)  is : 144.0
# flow of (177, 145)  is : -521.0
# flow of (177, 176)  is : 188.0
# flow of (177, 178)  is : -218.0
# flow of (177, 209)  is : 551.0
# flow of (178, 146)  is : -372.0
# flow of (178, 177)  is : 218.0
# flow of (178, 179)  is : 0
# flow of (178, 210)  is : 154.0
# flow of (179, 147)  is : -410.0
# flow of (179, 178)  is : 0
# flow of (179, 180)  is : 0
# flow of (179, 211)  is : 410.0
# flow of (180, 148)  is : -48.0
# flow of (180, 179)  is : 0
# flow of (180, 181)  is : 0
# flow of (180, 212)  is : 48.0
# flow of (181, 149)  is : -499.0
# flow of (181, 180)  is : 0
# flow of (181, 182)  is : 353.0
# flow of (181, 213)  is : 146.0
# flow of (182, 150)  is : -206.0
# flow of (182, 181)  is : -353.0
# flow of (182, 183)  is : 0
# flow of (182, 214)  is : 559.0
# flow of (183, 151)  is : -597.0
# flow of (183, 182)  is : 0
# flow of (183, 184)  is : 268.0
# flow of (183, 215)  is : 329.0
# flow of (184, 152)  is : -111.0
# flow of (184, 183)  is : -268.0
# flow of (184, 185)  is : 117.0
# flow of (184, 216)  is : 262.0
# flow of (185, 153)  is : -14.0
# flow of (185, 184)  is : -117.0
# flow of (185, 186)  is : -105.0
# flow of (185, 217)  is : 236.0
# flow of (186, 154)  is : -253.0
# flow of (186, 185)  is : 105.0
# flow of (186, 187)  is : 0
# flow of (186, 218)  is : 148.0
# flow of (187, 155)  is : -418.0
# flow of (187, 186)  is : 0
# flow of (187, 188)  is : 0
# flow of (187, 219)  is : 418.0
# flow of (188, 156)  is : -289.0
# flow of (188, 187)  is : 0
# flow of (188, 189)  is : 0
# flow of (188, 220)  is : 289.0
# flow of (189, 157)  is : -28.0
# flow of (189, 188)  is : 0
# flow of (189, 190)  is : -159.0
# flow of (189, 221)  is : 187.0
# flow of (190, 158)  is : -490.0
# flow of (190, 189)  is : 159.0
# flow of (190, 191)  is : 110.0
# flow of (190, 222)  is : 221.0
# flow of (191, 159)  is : -16.0
# flow of (191, 190)  is : -110.0
# flow of (191, 192)  is : -54.0
# flow of (191, 223)  is : 180.0
# flow of (192, 160)  is : -347.0
# flow of (192, 191)  is : 54.0
# flow of (192, 224)  is : 293.0
# flow of (193, 161)  is : -29.0
# flow of (193, 194)  is : 0
# flow of (193, 225)  is : 29.0
# flow of (194, 162)  is : -549.0
# flow of (194, 193)  is : 0
# flow of (194, 195)  is : 125.0
# flow of (194, 226)  is : 424.0
# flow of (195, 163)  is : -276.0
# flow of (195, 194)  is : -125.0
# flow of (195, 196)  is : -247.0
# flow of (195, 227)  is : 648.0
# flow of (196, 164)  is : -531.0
# flow of (196, 195)  is : 247.0
# flow of (196, 197)  is : 0
# flow of (196, 228)  is : 284.0
# flow of (197, 165)  is : -549.0
# flow of (197, 196)  is : 0
# flow of (197, 198)  is : 50.0
# flow of (197, 229)  is : 499.0
# flow of (198, 166)  is : -17.0
# flow of (198, 197)  is : -50.0
# flow of (198, 199)  is : -177.0
# flow of (198, 230)  is : 244.0
# flow of (199, 167)  is : -285.0
# flow of (199, 198)  is : 177.0
# flow of (199, 200)  is : 0
# flow of (199, 231)  is : 108.0
# flow of (200, 168)  is : -491.0
# flow of (200, 199)  is : 0
# flow of (200, 201)  is : 216.0
# flow of (200, 232)  is : 275.0
# flow of (201, 169)  is : -43.0
# flow of (201, 200)  is : -216.0
# flow of (201, 202)  is : -8.0
# flow of (201, 233)  is : 267.0
# flow of (202, 170)  is : -405.0
# flow of (202, 201)  is : 8.0
# flow of (202, 203)  is : 0
# flow of (202, 234)  is : 397.0
# flow of (203, 171)  is : -547.0
# flow of (203, 202)  is : 0
# flow of (203, 204)  is : 177.0
# flow of (203, 235)  is : 370.0
# flow of (204, 172)  is : -125.0
# flow of (204, 203)  is : -177.0
# flow of (204, 205)  is : 47.0
# flow of (204, 236)  is : 255.0
# flow of (205, 173)  is : -154.0
# flow of (205, 204)  is : -47.0
# flow of (205, 206)  is : -169.0
# flow of (205, 237)  is : 370.0
# flow of (206, 174)  is : -371.0
# flow of (206, 205)  is : 169.0
# flow of (206, 207)  is : 0
# flow of (206, 238)  is : 202.0
# flow of (207, 175)  is : -459.0
# flow of (207, 206)  is : 0
# flow of (207, 208)  is : 0
# flow of (207, 239)  is : 459.0
# flow of (208, 176)  is : -144.0
# flow of (208, 207)  is : 0
# flow of (208, 209)  is : 77.0
# flow of (208, 240)  is : 67.0
# flow of (209, 177)  is : -551.0
# flow of (209, 208)  is : -77.0
# flow of (209, 210)  is : -16.0
# flow of (209, 241)  is : 644.0
# flow of (210, 178)  is : -154.0
# flow of (210, 209)  is : 16.0
# flow of (210, 211)  is : -42.0
# flow of (210, 242)  is : 180.0
# flow of (211, 179)  is : -410.0
# flow of (211, 210)  is : 42.0
# flow of (211, 212)  is : 36.0
# flow of (211, 243)  is : 332.0
# flow of (212, 180)  is : -48.0
# flow of (212, 211)  is : -36.0
# flow of (212, 213)  is : -126.0
# flow of (212, 244)  is : 210.0
# flow of (213, 181)  is : -146.0
# flow of (213, 212)  is : 126.0
# flow of (213, 214)  is : -193.0
# flow of (213, 245)  is : 213.0
# flow of (214, 182)  is : -559.0
# flow of (214, 213)  is : 193.0
# flow of (214, 215)  is : 0
# flow of (214, 246)  is : 366.0
# flow of (215, 183)  is : -329.0
# flow of (215, 214)  is : 0
# flow of (215, 216)  is : 0
# flow of (215, 247)  is : 329.0
# flow of (216, 184)  is : -262.0
# flow of (216, 215)  is : 0
# flow of (216, 217)  is : 16.0
# flow of (216, 248)  is : 246.0
# flow of (217, 185)  is : -236.0
# flow of (217, 216)  is : -16.0
# flow of (217, 218)  is : 8.0
# flow of (217, 249)  is : 244.0
# flow of (218, 186)  is : -148.0
# flow of (218, 217)  is : -8.0
# flow of (218, 219)  is : -169.0
# flow of (218, 250)  is : 325.0
# flow of (219, 187)  is : -418.0
# flow of (219, 218)  is : 169.0
# flow of (219, 220)  is : 0
# flow of (219, 251)  is : 249.0
# flow of (220, 188)  is : -289.0
# flow of (220, 219)  is : 0
# flow of (220, 221)  is : 0
# flow of (220, 252)  is : 289.0
# flow of (221, 189)  is : -187.0
# flow of (221, 220)  is : 0
# flow of (221, 222)  is : 0
# flow of (221, 253)  is : 187.0
# flow of (222, 190)  is : -221.0
# flow of (222, 221)  is : 0
# flow of (222, 223)  is : 0
# flow of (222, 254)  is : 221.0
# flow of (223, 191)  is : -180.0
# flow of (223, 222)  is : 0
# flow of (223, 224)  is : 0
# flow of (223, 255)  is : 180.0
# flow of (224, 192)  is : -293.0
# flow of (224, 223)  is : 0
# flow of (224, 256)  is : 293.0
# flow of (225, 193)  is : -29.0
# flow of (225, 226)  is : 0
# flow of (225, 257)  is : 29.0
# flow of (226, 194)  is : -424.0
# flow of (226, 225)  is : 0
# flow of (226, 227)  is : 0
# flow of (226, 258)  is : 424.0
# flow of (227, 195)  is : -648.0
# flow of (227, 226)  is : 0
# flow of (227, 228)  is : 164.0
# flow of (227, 259)  is : 484.0
# flow of (228, 196)  is : -284.0
# flow of (228, 227)  is : -164.0
# flow of (228, 229)  is : -102.0
# flow of (228, 260)  is : 550.0
# flow of (229, 197)  is : -499.0
# flow of (229, 228)  is : 102.0
# flow of (229, 230)  is : 0
# flow of (229, 261)  is : 397.0
# flow of (230, 198)  is : -244.0
# flow of (230, 229)  is : 0
# flow of (230, 231)  is : 131.0
# flow of (230, 262)  is : 113.0
# flow of (231, 199)  is : -108.0
# flow of (231, 230)  is : -131.0
# flow of (231, 232)  is : -116.0
# flow of (231, 263)  is : 355.0
# flow of (232, 200)  is : -275.0
# flow of (232, 231)  is : 116.0
# flow of (232, 233)  is : 0
# flow of (232, 264)  is : 159.0
# flow of (233, 201)  is : -267.0
# flow of (233, 232)  is : 0
# flow of (233, 234)  is : 0
# flow of (233, 265)  is : 267.0
# flow of (234, 202)  is : -397.0
# flow of (234, 233)  is : 0
# flow of (234, 235)  is : 0
# flow of (234, 266)  is : 397.0
# flow of (235, 203)  is : -370.0
# flow of (235, 234)  is : 0
# flow of (235, 236)  is : 0
# flow of (235, 267)  is : 370.0
# flow of (236, 204)  is : -255.0
# flow of (236, 235)  is : 0
# flow of (236, 237)  is : 222.0
# flow of (236, 268)  is : 33.0
# flow of (237, 205)  is : -370.0
# flow of (237, 236)  is : -222.0
# flow of (237, 238)  is : -130.0
# flow of (237, 269)  is : 722.0
# flow of (238, 206)  is : -202.0
# flow of (238, 237)  is : 130.0
# flow of (238, 239)  is : -140.0
# flow of (238, 270)  is : 212.0
# flow of (239, 207)  is : -459.0
# flow of (239, 238)  is : 140.0
# flow of (239, 240)  is : 87.0
# flow of (239, 271)  is : 232.0
# flow of (240, 208)  is : -67.0
# flow of (240, 239)  is : -87.0
# flow of (240, 241)  is : -17.0
# flow of (240, 272)  is : 171.0
# flow of (241, 209)  is : -644.0
# flow of (241, 240)  is : 17.0
# flow of (241, 242)  is : 0
# flow of (241, 273)  is : 627.0
# flow of (242, 210)  is : -180.0
# flow of (242, 241)  is : 0
# flow of (242, 243)  is : 0
# flow of (242, 274)  is : 180.0
# flow of (243, 211)  is : -332.0
# flow of (243, 242)  is : 0
# flow of (243, 244)  is : -34.0
# flow of (243, 275)  is : 366.0
# flow of (244, 212)  is : -210.0
# flow of (244, 243)  is : 34.0
# flow of (244, 245)  is : -24.0
# flow of (244, 276)  is : 200.0
# flow of (245, 213)  is : -213.0
# flow of (245, 244)  is : 24.0
# flow of (245, 246)  is : 0
# flow of (245, 277)  is : 189.0
# flow of (246, 214)  is : -366.0
# flow of (246, 245)  is : 0
# flow of (246, 247)  is : -96.0
# flow of (246, 278)  is : 462.0
# flow of (247, 215)  is : -329.0
# flow of (247, 246)  is : 96.0
# flow of (247, 248)  is : 0
# flow of (247, 279)  is : 233.0
# flow of (248, 216)  is : -246.0
# flow of (248, 247)  is : 0
# flow of (248, 249)  is : 0
# flow of (248, 280)  is : 246.0
# flow of (249, 217)  is : -244.0
# flow of (249, 248)  is : 0
# flow of (249, 250)  is : 0
# flow of (249, 281)  is : 244.0
# flow of (250, 218)  is : -325.0
# flow of (250, 249)  is : 0
# flow of (250, 251)  is : 0
# flow of (250, 282)  is : 325.0
# flow of (251, 219)  is : -249.0
# flow of (251, 250)  is : 0
# flow of (251, 252)  is : 0
# flow of (251, 283)  is : 249.0
# flow of (252, 220)  is : -289.0
# flow of (252, 251)  is : 0
# flow of (252, 253)  is : 0
# flow of (252, 284)  is : 289.0
# flow of (253, 221)  is : -187.0
# flow of (253, 252)  is : 0
# flow of (253, 254)  is : -26.0
# flow of (253, 285)  is : 213.0
# flow of (254, 222)  is : -221.0
# flow of (254, 253)  is : 26.0
# flow of (254, 255)  is : 0
# flow of (254, 286)  is : 195.0
# flow of (255, 223)  is : -180.0
# flow of (255, 254)  is : 0
# flow of (255, 256)  is : -128.0
# flow of (255, 287)  is : 308.0
# flow of (256, 224)  is : -293.0
# flow of (256, 255)  is : 128.0
# flow of (256, 288)  is : 165.0
# flow of (257, 225)  is : -29.0
# flow of (257, 258)  is : -395.0
# flow of (257, 289)  is : 424.0
# flow of (258, 226)  is : -424.0
# flow of (258, 257)  is : 395.0
# flow of (258, 259)  is : -315.0
# flow of (258, 290)  is : 344.0
# flow of (259, 227)  is : -484.0
# flow of (259, 258)  is : 315.0
# flow of (259, 260)  is : 159.0
# flow of (259, 291)  is : 10.0
# flow of (260, 228)  is : -550.0
# flow of (260, 259)  is : -159.0
# flow of (260, 261)  is : 0
# flow of (260, 292)  is : 709.0
# flow of (261, 229)  is : -397.0
# flow of (261, 260)  is : 0
# flow of (261, 262)  is : 0
# flow of (261, 293)  is : 397.0
# flow of (262, 230)  is : -113.0
# flow of (262, 261)  is : 0
# flow of (262, 263)  is : 112.0
# flow of (262, 294)  is : 1.0
# flow of (263, 231)  is : -355.0
# flow of (263, 262)  is : -112.0
# flow of (263, 264)  is : 0
# flow of (263, 295)  is : 467.0
# flow of (264, 232)  is : -159.0
# flow of (264, 263)  is : 0
# flow of (264, 265)  is : 39.0
# flow of (264, 296)  is : 120.0
# flow of (265, 233)  is : -267.0
# flow of (265, 264)  is : -39.0
# flow of (265, 266)  is : -43.0
# flow of (265, 297)  is : 349.0
# flow of (266, 234)  is : -397.0
# flow of (266, 265)  is : 43.0
# flow of (266, 267)  is : 0
# flow of (266, 298)  is : 354.0
# flow of (267, 235)  is : -370.0
# flow of (267, 266)  is : 0
# flow of (267, 268)  is : 228.0
# flow of (267, 299)  is : 142.0
# flow of (268, 236)  is : -33.0
# flow of (268, 267)  is : -228.0
# flow of (268, 269)  is : -203.0
# flow of (268, 300)  is : 464.0
# flow of (269, 237)  is : -722.0
# flow of (269, 268)  is : 203.0
# flow of (269, 270)  is : -65.0
# flow of (269, 301)  is : 584.0
# flow of (270, 238)  is : -212.0
# flow of (270, 269)  is : 65.0
# flow of (270, 271)  is : -213.0
# flow of (270, 302)  is : 360.0
# flow of (271, 239)  is : -232.0
# flow of (271, 270)  is : 213.0
# flow of (271, 272)  is : -126.0
# flow of (271, 303)  is : 145.0
# flow of (272, 240)  is : -171.0
# flow of (272, 271)  is : 126.0
# flow of (272, 273)  is : -61.0
# flow of (272, 304)  is : 106.0
# flow of (273, 241)  is : -627.0
# flow of (273, 272)  is : 61.0
# flow of (273, 274)  is : 14.0
# flow of (273, 305)  is : 552.0
# flow of (274, 242)  is : -180.0
# flow of (274, 273)  is : -14.0
# flow of (274, 275)  is : -119.0
# flow of (274, 306)  is : 313.0
# flow of (275, 243)  is : -366.0
# flow of (275, 274)  is : 119.0
# flow of (275, 276)  is : 0
# flow of (275, 307)  is : 247.0
# flow of (276, 244)  is : -200.0
# flow of (276, 275)  is : 0
# flow of (276, 277)  is : 0
# flow of (276, 308)  is : 200.0
# flow of (277, 245)  is : -189.0
# flow of (277, 276)  is : 0
# flow of (277, 278)  is : 0
# flow of (277, 309)  is : 189.0
# flow of (278, 246)  is : -462.0
# flow of (278, 277)  is : 0
# flow of (278, 279)  is : 0
# flow of (278, 310)  is : 462.0
# flow of (279, 247)  is : -233.0
# flow of (279, 278)  is : 0
# flow of (279, 280)  is : 0
# flow of (279, 311)  is : 233.0
# flow of (280, 248)  is : -246.0
# flow of (280, 279)  is : 0
# flow of (280, 281)  is : 220.0
# flow of (280, 312)  is : 26.0
# flow of (281, 249)  is : -244.0
# flow of (281, 280)  is : -220.0
# flow of (281, 282)  is : -50.0
# flow of (281, 313)  is : 514.0
# flow of (282, 250)  is : -325.0
# flow of (282, 281)  is : 50.0
# flow of (282, 283)  is : 0
# flow of (282, 314)  is : 275.0
# flow of (283, 251)  is : -249.0
# flow of (283, 282)  is : 0
# flow of (283, 284)  is : 0
# flow of (283, 315)  is : 249.0
# flow of (284, 252)  is : -289.0
# flow of (284, 283)  is : 0
# flow of (284, 285)  is : 79.0
# flow of (284, 316)  is : 210.0
# flow of (285, 253)  is : -213.0
# flow of (285, 284)  is : -79.0
# flow of (285, 286)  is : -12.0
# flow of (285, 317)  is : 304.0
# flow of (286, 254)  is : -195.0
# flow of (286, 285)  is : 12.0
# flow of (286, 287)  is : 0
# flow of (286, 318)  is : 183.0
# flow of (287, 255)  is : -308.0
# flow of (287, 286)  is : 0
# flow of (287, 288)  is : 0
# flow of (287, 319)  is : 308.0
# flow of (288, 256)  is : -165.0
# flow of (288, 287)  is : 0
# flow of (288, 320)  is : 165.0
# flow of (289, 257)  is : -424.0
# flow of (289, 290)  is : -182.0
# flow of (289, 321)  is : 606.0
# flow of (290, 258)  is : -344.0
# flow of (290, 289)  is : 182.0
# flow of (290, 291)  is : 140.0
# flow of (290, 322)  is : 22.0
# flow of (291, 259)  is : -10.0
# flow of (291, 290)  is : -140.0
# flow of (291, 292)  is : -184.0
# flow of (291, 323)  is : 334.0
# flow of (292, 260)  is : -709.0
# flow of (292, 291)  is : 184.0
# flow of (292, 293)  is : 184.0
# flow of (292, 324)  is : 341.0
# flow of (293, 261)  is : -397.0
# flow of (293, 292)  is : -184.0
# flow of (293, 294)  is : 242.0
# flow of (293, 325)  is : 339.0
# flow of (294, 262)  is : -1.0
# flow of (294, 293)  is : -242.0
# flow of (294, 295)  is : -332.0
# flow of (294, 326)  is : 575.0
# flow of (295, 263)  is : -467.0
# flow of (295, 294)  is : 332.0
# flow of (295, 296)  is : 111.0
# flow of (295, 327)  is : 24.0
# flow of (296, 264)  is : -120.0
# flow of (296, 295)  is : -111.0
# flow of (296, 297)  is : -70.0
# flow of (296, 328)  is : 301.0
# flow of (297, 265)  is : -349.0
# flow of (297, 296)  is : 70.0
# flow of (297, 298)  is : 0
# flow of (297, 329)  is : 279.0
# flow of (298, 266)  is : -354.0
# flow of (298, 297)  is : 0
# flow of (298, 299)  is : 245.0
# flow of (298, 330)  is : 109.0
# flow of (299, 267)  is : -142.0
# flow of (299, 298)  is : -245.0
# flow of (299, 300)  is : 202.0
# flow of (299, 331)  is : 185.0
# flow of (300, 268)  is : -464.0
# flow of (300, 299)  is : -202.0
# flow of (300, 301)  is : 57.0
# flow of (300, 332)  is : 609.0
# flow of (301, 269)  is : -584.0
# flow of (301, 300)  is : -57.0
# flow of (301, 302)  is : 195.0
# flow of (301, 333)  is : 446.0
# flow of (302, 270)  is : -360.0
# flow of (302, 301)  is : -195.0
# flow of (302, 303)  is : -63.0
# flow of (302, 334)  is : 618.0
# flow of (303, 271)  is : -145.0
# flow of (303, 302)  is : 63.0
# flow of (303, 304)  is : 0
# flow of (303, 335)  is : 82.0
# flow of (304, 272)  is : -106.0
# flow of (304, 303)  is : 0
# flow of (304, 305)  is : 0
# flow of (304, 336)  is : 106.0
# flow of (305, 273)  is : -552.0
# flow of (305, 304)  is : 0
# flow of (305, 306)  is : 150.0
# flow of (305, 337)  is : 402.0
# flow of (306, 274)  is : -313.0
# flow of (306, 305)  is : -150.0
# flow of (306, 307)  is : -10.0
# flow of (306, 338)  is : 473.0
# flow of (307, 275)  is : -247.0
# flow of (307, 306)  is : 10.0
# flow of (307, 308)  is : -1.0
# flow of (307, 339)  is : 238.0
# flow of (308, 276)  is : -200.0
# flow of (308, 307)  is : 1.0
# flow of (308, 309)  is : 0
# flow of (308, 340)  is : 199.0
# flow of (309, 277)  is : -189.0
# flow of (309, 308)  is : 0
# flow of (309, 310)  is : 0
# flow of (309, 341)  is : 189.0
# flow of (310, 278)  is : -462.0
# flow of (310, 309)  is : 0
# flow of (310, 311)  is : 0
# flow of (310, 342)  is : 462.0
# flow of (311, 279)  is : -233.0
# flow of (311, 310)  is : 0
# flow of (311, 312)  is : 0
# flow of (311, 343)  is : 233.0
# flow of (312, 280)  is : -26.0
# flow of (312, 311)  is : 0
# flow of (312, 313)  is : 0
# flow of (312, 344)  is : 26.0
# flow of (313, 281)  is : -514.0
# flow of (313, 312)  is : 0
# flow of (313, 314)  is : -98.0
# flow of (313, 345)  is : 612.0
# flow of (314, 282)  is : -275.0
# flow of (314, 313)  is : 98.0
# flow of (314, 315)  is : 0
# flow of (314, 346)  is : 177.0
# flow of (315, 283)  is : -249.0
# flow of (315, 314)  is : 0
# flow of (315, 316)  is : 0
# flow of (315, 347)  is : 249.0
# flow of (316, 284)  is : -210.0
# flow of (316, 315)  is : 0
# flow of (316, 317)  is : 0
# flow of (316, 348)  is : 210.0
# flow of (317, 285)  is : -304.0
# flow of (317, 316)  is : 0
# flow of (317, 318)  is : 0
# flow of (317, 349)  is : 304.0
# flow of (318, 286)  is : -183.0
# flow of (318, 317)  is : 0
# flow of (318, 319)  is : 0
# flow of (318, 350)  is : 183.0
# flow of (319, 287)  is : -308.0
# flow of (319, 318)  is : 0
# flow of (319, 320)  is : -76.0
# flow of (319, 351)  is : 384.0
# flow of (320, 288)  is : -165.0
# flow of (320, 319)  is : 76.0
# flow of (320, 352)  is : 89.0
# flow of (321, 289)  is : -606.0
# flow of (321, 322)  is : 326.0
# flow of (321, 353)  is : 280.0
# flow of (322, 290)  is : -22.0
# flow of (322, 321)  is : -326.0
# flow of (322, 323)  is : -45.0
# flow of (322, 354)  is : 393.0
# flow of (323, 291)  is : -334.0
# flow of (323, 322)  is : 45.0
# flow of (323, 324)  is : 195.0
# flow of (323, 355)  is : 94.0
# flow of (324, 292)  is : -341.0
# flow of (324, 323)  is : -195.0
# flow of (324, 325)  is : -168.0
# flow of (324, 356)  is : 704.0
# flow of (325, 293)  is : -339.0
# flow of (325, 324)  is : 168.0
# flow of (325, 326)  is : -110.0
# flow of (325, 357)  is : 281.0
# flow of (326, 294)  is : -575.0
# flow of (326, 325)  is : 110.0
# flow of (326, 327)  is : -110.0
# flow of (326, 358)  is : 575.0
# flow of (327, 295)  is : -24.0
# flow of (327, 326)  is : 110.0
# flow of (327, 328)  is : -110.0
# flow of (327, 359)  is : 24.0
# flow of (328, 296)  is : -301.0
# flow of (328, 327)  is : 110.0
# flow of (328, 329)  is : -176.0
# flow of (328, 360)  is : 367.0
# flow of (329, 297)  is : -279.0
# flow of (329, 328)  is : 176.0
# flow of (329, 330)  is : -243.0
# flow of (329, 361)  is : 346.0
# flow of (330, 298)  is : -109.0
# flow of (330, 329)  is : 243.0
# flow of (330, 331)  is : -568.0
# flow of (330, 362)  is : 434.0
# flow of (331, 299)  is : -185.0
# flow of (331, 330)  is : 568.0
# flow of (331, 332)  is : -410.0
# flow of (331, 363)  is : 27.0
# flow of (332, 300)  is : -609.0
# flow of (332, 331)  is : 410.0
# flow of (332, 333)  is : -118.0
# flow of (332, 364)  is : 317.0
# flow of (333, 301)  is : -446.0
# flow of (333, 332)  is : 118.0
# flow of (333, 334)  is : 0
# flow of (333, 365)  is : 328.0
# flow of (334, 302)  is : -618.0
# flow of (334, 333)  is : 0
# flow of (334, 335)  is : 83.0
# flow of (334, 366)  is : 535.0
# flow of (335, 303)  is : -82.0
# flow of (335, 334)  is : -83.0
# flow of (335, 336)  is : -89.0
# flow of (335, 367)  is : 254.0
# flow of (336, 304)  is : -106.0
# flow of (336, 335)  is : 89.0
# flow of (336, 337)  is : 0
# flow of (336, 368)  is : 17.0
# flow of (337, 305)  is : -402.0
# flow of (337, 336)  is : 0
# flow of (337, 338)  is : 0
# flow of (337, 369)  is : 402.0
# flow of (338, 306)  is : -473.0
# flow of (338, 337)  is : 0
# flow of (338, 339)  is : 0
# flow of (338, 370)  is : 473.0
# flow of (339, 307)  is : -238.0
# flow of (339, 338)  is : 0
# flow of (339, 340)  is : 65.0
# flow of (339, 371)  is : 173.0
# flow of (340, 308)  is : -199.0
# flow of (340, 339)  is : -65.0
# flow of (340, 341)  is : 65.0
# flow of (340, 372)  is : 199.0
# flow of (341, 309)  is : -189.0
# flow of (341, 340)  is : -65.0
# flow of (341, 342)  is : -214.0
# flow of (341, 373)  is : 468.0
# flow of (342, 310)  is : -462.0
# flow of (342, 341)  is : 214.0
# flow of (342, 343)  is : 120.0
# flow of (342, 374)  is : 128.0
# flow of (343, 311)  is : -233.0
# flow of (343, 342)  is : -120.0
# flow of (343, 344)  is : 0
# flow of (343, 375)  is : 353.0
# flow of (344, 312)  is : -26.0
# flow of (344, 343)  is : 0
# flow of (344, 345)  is : 0
# flow of (344, 376)  is : 26.0
# flow of (345, 313)  is : -612.0
# flow of (345, 344)  is : 0
# flow of (345, 346)  is : 411.0
# flow of (345, 377)  is : 201.0
# flow of (346, 314)  is : -177.0
# flow of (346, 345)  is : -411.0
# flow of (346, 347)  is : -218.0
# flow of (346, 378)  is : 806.0
# flow of (347, 315)  is : -249.0
# flow of (347, 346)  is : 218.0
# flow of (347, 348)  is : 0
# flow of (347, 379)  is : 31.0
# flow of (348, 316)  is : -210.0
# flow of (348, 347)  is : 0
# flow of (348, 349)  is : 0
# flow of (348, 380)  is : 210.0
# flow of (349, 317)  is : -304.0
# flow of (349, 348)  is : 0
# flow of (349, 350)  is : 50.0
# flow of (349, 381)  is : 254.0
# flow of (350, 318)  is : -183.0
# flow of (350, 349)  is : -50.0
# flow of (350, 351)  is : -316.0
# flow of (350, 382)  is : 549.0
# flow of (351, 319)  is : -384.0
# flow of (351, 350)  is : 316.0
# flow of (351, 352)  is : 0
# flow of (351, 383)  is : 68.0
# flow of (352, 320)  is : -89.0
# flow of (352, 351)  is : 0
# flow of (352, 384)  is : 89.0
# flow of (353, 321)  is : -280.0
# flow of (353, 354)  is : -64.0
# flow of (353, 385)  is : 344.0
# flow of (354, 322)  is : -393.0
# flow of (354, 353)  is : 64.0
# flow of (354, 355)  is : 224.0
# flow of (354, 386)  is : 105.0
# flow of (355, 323)  is : -94.0
# flow of (355, 354)  is : -224.0
# flow of (355, 356)  is : -126.0
# flow of (355, 387)  is : 444.0
# flow of (356, 324)  is : -704.0
# flow of (356, 355)  is : 126.0
# flow of (356, 357)  is : 59.0
# flow of (356, 388)  is : 519.0
# flow of (357, 325)  is : -281.0
# flow of (357, 356)  is : -59.0
# flow of (357, 358)  is : 108.0
# flow of (357, 389)  is : 232.0
# flow of (358, 326)  is : -575.0
# flow of (358, 357)  is : -108.0
# flow of (358, 359)  is : 7.0
# flow of (358, 390)  is : 676.0
# flow of (359, 327)  is : -24.0
# flow of (359, 358)  is : -7.0
# flow of (359, 360)  is : -132.0
# flow of (359, 391)  is : 163.0
# flow of (360, 328)  is : -367.0
# flow of (360, 359)  is : 132.0
# flow of (360, 361)  is : -373.0
# flow of (360, 392)  is : 608.0
# flow of (361, 329)  is : -346.0
# flow of (361, 360)  is : 373.0
# flow of (361, 362)  is : -274.0
# flow of (361, 393)  is : 247.0
# flow of (362, 330)  is : -434.0
# flow of (362, 361)  is : 274.0
# flow of (362, 363)  is : 99.0
# flow of (362, 394)  is : 61.0
# flow of (363, 331)  is : -27.0
# flow of (363, 362)  is : -99.0
# flow of (363, 364)  is : -9.0
# flow of (363, 395)  is : 135.0
# flow of (364, 332)  is : -317.0
# flow of (364, 363)  is : 9.0
# flow of (364, 365)  is : -442.0
# flow of (364, 396)  is : 750.0
# flow of (365, 333)  is : -328.0
# flow of (365, 364)  is : 442.0
# flow of (365, 366)  is : -476.0
# flow of (365, 397)  is : 362.0
# flow of (366, 334)  is : -535.0
# flow of (366, 365)  is : 476.0
# flow of (366, 367)  is : 0
# flow of (366, 398)  is : 59.0
# flow of (367, 335)  is : -254.0
# flow of (367, 366)  is : 0
# flow of (367, 368)  is : 189.0
# flow of (367, 399)  is : 65.0
# flow of (368, 336)  is : -17.0
# flow of (368, 367)  is : -189.0
# flow of (368, 369)  is : -23.0
# flow of (368, 400)  is : 229.0
# flow of (369, 337)  is : -402.0
# flow of (369, 368)  is : 23.0
# flow of (369, 370)  is : -19.0
# flow of (369, 401)  is : 398.0
# flow of (370, 338)  is : -473.0
# flow of (370, 369)  is : 19.0
# flow of (370, 371)  is : 0
# flow of (370, 402)  is : 454.0
# flow of (371, 339)  is : -173.0
# flow of (371, 370)  is : 0
# flow of (371, 372)  is : 89.0
# flow of (371, 403)  is : 84.0
# flow of (372, 340)  is : -199.0
# flow of (372, 371)  is : -89.0
# flow of (372, 373)  is : -89.0
# flow of (372, 404)  is : 377.0
# flow of (373, 341)  is : -468.0
# flow of (373, 372)  is : 89.0
# flow of (373, 374)  is : -89.0
# flow of (373, 405)  is : 468.0
# flow of (374, 342)  is : -128.0
# flow of (374, 373)  is : 89.0
# flow of (374, 375)  is : 0
# flow of (374, 406)  is : 39.0
# flow of (375, 343)  is : -353.0
# flow of (375, 374)  is : 0
# flow of (375, 376)  is : 0
# flow of (375, 407)  is : 353.0
# flow of (376, 344)  is : -26.0
# flow of (376, 375)  is : 0
# flow of (376, 377)  is : 0
# flow of (376, 408)  is : 26.0
# flow of (377, 345)  is : -201.0
# flow of (377, 376)  is : 0
# flow of (377, 378)  is : 140.0
# flow of (377, 409)  is : 61.0
# flow of (378, 346)  is : -806.0
# flow of (378, 377)  is : -140.0
# flow of (378, 379)  is : 248.0
# flow of (378, 410)  is : 698.0
# flow of (379, 347)  is : -31.0
# flow of (379, 378)  is : -248.0
# flow of (379, 380)  is : -209.0
# flow of (379, 411)  is : 488.0
# flow of (380, 348)  is : -210.0
# flow of (380, 379)  is : 209.0
# flow of (380, 381)  is : -128.0
# flow of (380, 412)  is : 129.0
# flow of (381, 349)  is : -254.0
# flow of (381, 380)  is : 128.0
# flow of (381, 382)  is : -135.0
# flow of (381, 413)  is : 261.0
# flow of (382, 350)  is : -549.0
# flow of (382, 381)  is : 135.0
# flow of (382, 383)  is : -8.0
# flow of (382, 414)  is : 422.0
# flow of (383, 351)  is : -68.0
# flow of (383, 382)  is : 8.0
# flow of (383, 384)  is : 0
# flow of (383, 415)  is : 60.0
# flow of (384, 352)  is : -89.0
# flow of (384, 383)  is : 0
# flow of (384, 416)  is : 89.0
# flow of (385, 353)  is : -344.0
# flow of (385, 386)  is : 62.0
# flow of (385, 417)  is : 282.0
# flow of (386, 354)  is : -105.0
# flow of (386, 385)  is : -62.0
# flow of (386, 387)  is : 46.0
# flow of (386, 418)  is : 121.0
# flow of (387, 355)  is : -444.0
# flow of (387, 386)  is : -46.0
# flow of (387, 388)  is : 326.0
# flow of (387, 419)  is : 164.0
# flow of (388, 356)  is : -519.0
# flow of (388, 387)  is : -326.0
# flow of (388, 389)  is : 286.0
# flow of (388, 420)  is : 559.0
# flow of (389, 357)  is : -232.0
# flow of (389, 388)  is : -286.0
# flow of (389, 390)  is : 334.0
# flow of (389, 421)  is : 184.0
# flow of (390, 358)  is : -676.0
# flow of (390, 389)  is : -334.0
# flow of (390, 391)  is : 250.0
# flow of (390, 422)  is : 760.0
# flow of (391, 359)  is : -163.0
# flow of (391, 390)  is : -250.0
# flow of (391, 392)  is : -252.0
# flow of (391, 423)  is : 665.0
# flow of (392, 360)  is : -608.0
# flow of (392, 391)  is : 252.0
# flow of (392, 393)  is : 0
# flow of (392, 424)  is : 356.0
# flow of (393, 361)  is : -247.0
# flow of (393, 392)  is : 0
# flow of (393, 394)  is : 0
# flow of (393, 425)  is : 247.0
# flow of (394, 362)  is : -61.0
# flow of (394, 393)  is : 0
# flow of (394, 395)  is : 0
# flow of (394, 426)  is : 61.0
# flow of (395, 363)  is : -135.0
# flow of (395, 394)  is : 0
# flow of (395, 396)  is : -392.0
# flow of (395, 427)  is : 527.0
# flow of (396, 364)  is : -750.0
# flow of (396, 395)  is : 392.0
# flow of (396, 397)  is : -349.0
# flow of (396, 428)  is : 707.0
# flow of (397, 365)  is : -362.0
# flow of (397, 396)  is : 349.0
# flow of (397, 398)  is : -35.0
# flow of (397, 429)  is : 48.0
# flow of (398, 366)  is : -59.0
# flow of (398, 397)  is : 35.0
# flow of (398, 399)  is : -43.0
# flow of (398, 430)  is : 67.0
# flow of (399, 367)  is : -65.0
# flow of (399, 398)  is : 43.0
# flow of (399, 400)  is : 0
# flow of (399, 431)  is : 22.0
# flow of (400, 368)  is : -229.0
# flow of (400, 399)  is : 0
# flow of (400, 401)  is : 84.0
# flow of (400, 432)  is : 145.0
# flow of (401, 369)  is : -398.0
# flow of (401, 400)  is : -84.0
# flow of (401, 402)  is : 179.0
# flow of (401, 433)  is : 303.0
# flow of (402, 370)  is : -454.0
# ...
# flow of (900, 868)  is : -559.0
# flow of (900, 899)  is : 60.0
# flow of (900, 901)  is : 151.0
# flow of (900, 932)  is : 348.0
# flow of (901, 869)  is : -28.0
# flow of (901, 900)  is : -151.0
# flow of (901, 902)  is : -150.0
# flow of (901, 933)  is : 329.0
# flow of (902, 870)  is : -532.0
# flow of (902, 901)  is : 150.0
# flow of (902, 903)  is : 0
# flow of (902, 934)  is : 382.0
# flow of (903, 871)  is : -98.0
# flow of (903, 902)  is : 0
# flow of (903, 904)  is : -4.0
# flow of (903, 935)  is : 102.0
# flow of (904, 872)  is : -270.0
# flow of (904, 903)  is : 4.0
# flow of (904, 905)  is : 0
# flow of (904, 936)  is : 266.0
# flow of (905, 873)  is : -209.0
# flow of (905, 904)  is : 0
# flow of (905, 906)  is : 2.0
# flow of (905, 937)  is : 207.0
# flow of (906, 874)  is : -183.0
# flow of (906, 905)  is : -2.0
# flow of (906, 907)  is : -36.0
# flow of (906, 938)  is : 221.0
# flow of (907, 875)  is : -305.0
# flow of (907, 906)  is : 36.0
# flow of (907, 908)  is : 0
# flow of (907, 939)  is : 269.0
# flow of (908, 876)  is : -51.0
# flow of (908, 907)  is : 0
# flow of (908, 909)  is : 49.0
# flow of (908, 940)  is : 2.0
# flow of (909, 877)  is : -18.0
# flow of (909, 908)  is : -49.0
# flow of (909, 910)  is : 0
# flow of (909, 941)  is : 67.0
# flow of (910, 878)  is : -508.0
# flow of (910, 909)  is : 0
# flow of (910, 911)  is : 189.0
# flow of (910, 942)  is : 319.0
# flow of (911, 879)  is : -526.0
# flow of (911, 910)  is : -189.0
# flow of (911, 912)  is : 143.0
# flow of (911, 943)  is : 572.0
# flow of (912, 880)  is : -302.0
# flow of (912, 911)  is : -143.0
# flow of (912, 913)  is : -68.0
# flow of (912, 944)  is : 513.0
# flow of (913, 881)  is : -468.0
# flow of (913, 912)  is : 68.0
# flow of (913, 914)  is : 0
# flow of (913, 945)  is : 400.0
# flow of (914, 882)  is : -146.0
# flow of (914, 913)  is : 0
# flow of (914, 915)  is : 0
# flow of (914, 946)  is : 146.0
# flow of (915, 883)  is : -23.0
# flow of (915, 914)  is : 0
# flow of (915, 916)  is : 0
# flow of (915, 947)  is : 23.0
# flow of (916, 884)  is : -512.0
# flow of (916, 915)  is : 0
# flow of (916, 917)  is : 0
# flow of (916, 948)  is : 512.0
# flow of (917, 885)  is : -49.0
# flow of (917, 916)  is : 0
# flow of (917, 918)  is : 0
# flow of (917, 949)  is : 49.0
# flow of (918, 886)  is : -306.0
# flow of (918, 917)  is : 0
# flow of (918, 919)  is : 0
# flow of (918, 950)  is : 306.0
# flow of (919, 887)  is : -322.0
# flow of (919, 918)  is : 0
# flow of (919, 920)  is : 257.0
# flow of (919, 951)  is : 65.0
# flow of (920, 888)  is : -248.0
# flow of (920, 919)  is : -257.0
# flow of (920, 921)  is : 0
# flow of (920, 952)  is : 505.0
# flow of (921, 889)  is : -563.0
# flow of (921, 920)  is : 0
# flow of (921, 922)  is : 150.0
# flow of (921, 953)  is : 413.0
# flow of (922, 890)  is : -209.0
# flow of (922, 921)  is : -150.0
# flow of (922, 923)  is : -367.0
# flow of (922, 954)  is : 726.0
# flow of (923, 891)  is : -621.0
# flow of (923, 922)  is : 367.0
# flow of (923, 924)  is : 74.0
# flow of (923, 955)  is : 180.0
# flow of (924, 892)  is : -151.0
# flow of (924, 923)  is : -74.0
# flow of (924, 925)  is : 0
# flow of (924, 956)  is : 225.0
# flow of (925, 893)  is : -259.0
# flow of (925, 924)  is : 0
# flow of (925, 926)  is : 0
# flow of (925, 957)  is : 259.0
# flow of (926, 894)  is : -130.0
# flow of (926, 925)  is : 0
# flow of (926, 927)  is : -33.0
# flow of (926, 958)  is : 163.0
# flow of (927, 895)  is : -155.0
# flow of (927, 926)  is : 33.0
# flow of (927, 928)  is : 0
# flow of (927, 959)  is : 122.0
# flow of (928, 896)  is : -315.0
# flow of (928, 927)  is : 0
# flow of (928, 960)  is : 315.0
# flow of (929, 897)  is : -689.0
# flow of (929, 930)  is : 219.0
# flow of (929, 961)  is : 470.0
# flow of (930, 898)  is : -355.0
# flow of (930, 929)  is : -219.0
# flow of (930, 931)  is : 0
# flow of (930, 962)  is : 574.0
# flow of (931, 899)  is : -356.0
# flow of (931, 930)  is : 0
# flow of (931, 932)  is : 0
# flow of (931, 963)  is : 356.0
# flow of (932, 900)  is : -348.0
# flow of (932, 931)  is : 0
# flow of (932, 933)  is : 47.0
# flow of (932, 964)  is : 301.0
# flow of (933, 901)  is : -329.0
# flow of (933, 932)  is : -47.0
# flow of (933, 934)  is : 0
# flow of (933, 965)  is : 376.0
# flow of (934, 902)  is : -382.0
# flow of (934, 933)  is : 0
# flow of (934, 935)  is : 0
# flow of (934, 966)  is : 382.0
# flow of (935, 903)  is : -102.0
# flow of (935, 934)  is : 0
# flow of (935, 936)  is : -110.0
# flow of (935, 967)  is : 212.0
# flow of (936, 904)  is : -266.0
# flow of (936, 935)  is : 110.0
# flow of (936, 937)  is : 0
# flow of (936, 968)  is : 156.0
# flow of (937, 905)  is : -207.0
# flow of (937, 936)  is : 0
# flow of (937, 938)  is : 0
# flow of (937, 969)  is : 207.0
# flow of (938, 906)  is : -221.0
# flow of (938, 937)  is : 0
# flow of (938, 939)  is : 0
# flow of (938, 970)  is : 221.0
# flow of (939, 907)  is : -269.0
# flow of (939, 938)  is : 0
# flow of (939, 940)  is : 253.0
# flow of (939, 971)  is : 16.0
# flow of (940, 908)  is : -2.0
# flow of (940, 939)  is : -253.0
# flow of (940, 941)  is : 0
# flow of (940, 972)  is : 255.0
# flow of (941, 909)  is : -67.0
# flow of (941, 940)  is : 0
# flow of (941, 942)  is : 0
# flow of (941, 973)  is : 67.0
# flow of (942, 910)  is : -319.0
# flow of (942, 941)  is : 0
# flow of (942, 943)  is : 160.0
# flow of (942, 974)  is : 159.0
# flow of (943, 911)  is : -572.0
# flow of (943, 942)  is : -160.0
# flow of (943, 944)  is : 0
# flow of (943, 975)  is : 732.0
# flow of (944, 912)  is : -513.0
# flow of (944, 943)  is : 0
# flow of (944, 945)  is : 0
# flow of (944, 976)  is : 513.0
# flow of (945, 913)  is : -400.0
# flow of (945, 944)  is : 0
# flow of (945, 946)  is : 0
# flow of (945, 977)  is : 400.0
# flow of (946, 914)  is : -146.0
# flow of (946, 945)  is : 0
# flow of (946, 947)  is : -276.0
# flow of (946, 978)  is : 422.0
# flow of (947, 915)  is : -23.0
# flow of (947, 946)  is : 276.0
# flow of (947, 948)  is : -437.0
# flow of (947, 979)  is : 184.0
# flow of (948, 916)  is : -512.0
# flow of (948, 947)  is : 437.0
# flow of (948, 949)  is : 0
# flow of (948, 980)  is : 75.0
# flow of (949, 917)  is : -49.0
# flow of (949, 948)  is : 0
# flow of (949, 950)  is : 0
# flow of (949, 981)  is : 49.0
# flow of (950, 918)  is : -306.0
# flow of (950, 949)  is : 0
# flow of (950, 951)  is : 0
# flow of (950, 982)  is : 306.0
# flow of (951, 919)  is : -65.0
# flow of (951, 950)  is : 0
# flow of (951, 952)  is : 0
# flow of (951, 983)  is : 65.0
# flow of (952, 920)  is : -505.0
# flow of (952, 951)  is : 0
# flow of (952, 953)  is : 120.0
# flow of (952, 984)  is : 385.0
# flow of (953, 921)  is : -413.0
# flow of (953, 952)  is : -120.0
# flow of (953, 954)  is : 39.0
# flow of (953, 985)  is : 494.0
# flow of (954, 922)  is : -726.0
# flow of (954, 953)  is : -39.0
# flow of (954, 955)  is : 125.0
# flow of (954, 986)  is : 640.0
# flow of (955, 923)  is : -180.0
# flow of (955, 954)  is : -125.0
# flow of (955, 956)  is : 92.0
# flow of (955, 987)  is : 213.0
# flow of (956, 924)  is : -225.0
# flow of (956, 955)  is : -92.0
# flow of (956, 957)  is : 0
# flow of (956, 988)  is : 317.0
# flow of (957, 925)  is : -259.0
# flow of (957, 956)  is : 0
# flow of (957, 958)  is : 0
# flow of (957, 989)  is : 259.0
# flow of (958, 926)  is : -163.0
# flow of (958, 957)  is : 0
# flow of (958, 959)  is : -49.0
# flow of (958, 990)  is : 212.0
# flow of (959, 927)  is : -122.0
# flow of (959, 958)  is : 49.0
# flow of (959, 960)  is : 31.0
# flow of (959, 991)  is : 42.0
# flow of (960, 928)  is : -315.0
# flow of (960, 959)  is : -31.0
# flow of (960, 992)  is : 346.0
# flow of (961, 929)  is : -470.0
# flow of (961, 962)  is : 0
# flow of (961, 993)  is : 470.0
# flow of (962, 930)  is : -574.0
# flow of (962, 961)  is : 0
# flow of (962, 963)  is : 40.0
# flow of (962, 994)  is : 534.0
# flow of (963, 931)  is : -356.0
# flow of (963, 962)  is : -40.0
# flow of (963, 964)  is : 0
# flow of (963, 995)  is : 396.0
# flow of (964, 932)  is : -301.0
# flow of (964, 963)  is : 0
# flow of (964, 965)  is : 0
# flow of (964, 996)  is : 301.0
# flow of (965, 933)  is : -376.0
# flow of (965, 964)  is : 0
# flow of (965, 966)  is : 0
# flow of (965, 997)  is : 376.0
# flow of (966, 934)  is : -382.0
# flow of (966, 965)  is : 0
# flow of (966, 967)  is : -7.0
# flow of (966, 998)  is : 389.0
# flow of (967, 935)  is : -212.0
# flow of (967, 966)  is : 7.0
# flow of (967, 968)  is : 0
# flow of (967, 999)  is : 205.0
# flow of (968, 936)  is : -156.0
# flow of (968, 967)  is : 0
# flow of (968, 969)  is : 0
# flow of (968, 1000)  is : 156.0
# flow of (969, 937)  is : -207.0
# flow of (969, 968)  is : 0
# flow of (969, 970)  is : -2.0
# flow of (969, 1001)  is : 209.0
# flow of (970, 938)  is : -221.0
# flow of (970, 969)  is : 2.0
# flow of (970, 971)  is : 0
# flow of (970, 1002)  is : 219.0
# flow of (971, 939)  is : -16.0
# flow of (971, 970)  is : 0
# flow of (971, 972)  is : -98.0
# flow of (971, 1003)  is : 114.0
# flow of (972, 940)  is : -255.0
# flow of (972, 971)  is : 98.0
# flow of (972, 973)  is : 14.0
# flow of (972, 1004)  is : 143.0
# flow of (973, 941)  is : -67.0
# flow of (973, 972)  is : -14.0
# flow of (973, 974)  is : 0
# flow of (973, 1005)  is : 81.0
# flow of (974, 942)  is : -159.0
# flow of (974, 973)  is : 0
# flow of (974, 975)  is : -269.0
# flow of (974, 1006)  is : 428.0
# flow of (975, 943)  is : -732.0
# flow of (975, 974)  is : 269.0
# flow of (975, 976)  is : 0
# flow of (975, 1007)  is : 463.0
# flow of (976, 944)  is : -513.0
# flow of (976, 975)  is : 0
# flow of (976, 977)  is : 0
# flow of (976, 1008)  is : 513.0
# flow of (977, 945)  is : -400.0
# flow of (977, 976)  is : 0
# flow of (977, 978)  is : 0
# flow of (977, 1009)  is : 400.0
# flow of (978, 946)  is : -422.0
# flow of (978, 977)  is : 0
# flow of (978, 979)  is : -73.0
# flow of (978, 1010)  is : 495.0
# flow of (979, 947)  is : -184.0
# flow of (979, 978)  is : 73.0
# flow of (979, 980)  is : 0
# flow of (979, 1011)  is : 111.0
# flow of (980, 948)  is : -75.0
# flow of (980, 979)  is : 0
# flow of (980, 981)  is : 0
# flow of (980, 1012)  is : 75.0
# flow of (981, 949)  is : -49.0
# flow of (981, 980)  is : 0
# flow of (981, 982)  is : -97.0
# flow of (981, 1013)  is : 146.0
# flow of (982, 950)  is : -306.0
# flow of (982, 981)  is : 97.0
# flow of (982, 983)  is : 0
# flow of (982, 1014)  is : 209.0
# flow of (983, 951)  is : -65.0
# flow of (983, 982)  is : 0
# flow of (983, 984)  is : -312.0
# flow of (983, 1015)  is : 377.0
# flow of (984, 952)  is : -385.0
# flow of (984, 983)  is : 312.0
# flow of (984, 985)  is : 0
# flow of (984, 1016)  is : 73.0
# flow of (985, 953)  is : -494.0
# flow of (985, 984)  is : 0
# flow of (985, 986)  is : -204.0
# flow of (985, 1017)  is : 698.0
# flow of (986, 954)  is : -640.0
# flow of (986, 985)  is : 204.0
# flow of (986, 987)  is : 256.0
# flow of (986, 1018)  is : 180.0
# flow of (987, 955)  is : -213.0
# flow of (987, 986)  is : -256.0
# flow of (987, 988)  is : 0
# flow of (987, 1019)  is : 469.0
# flow of (988, 956)  is : -317.0
# flow of (988, 987)  is : 0
# flow of (988, 989)  is : 0
# flow of (988, 1020)  is : 317.0
# flow of (989, 957)  is : -259.0
# flow of (989, 988)  is : 0
# flow of (989, 990)  is : 0
# flow of (989, 1021)  is : 259.0
# flow of (990, 958)  is : -212.0
# flow of (990, 989)  is : 0
# flow of (990, 991)  is : 0
# flow of (990, 1022)  is : 212.0
# flow of (991, 959)  is : -42.0
# flow of (991, 990)  is : 0
# flow of (991, 992)  is : 0
# flow of (991, 1023)  is : 42.0
# flow of (992, 960)  is : -346.0
# flow of (992, 991)  is : 0
# flow of (992, 1024)  is : 346.0
# flow of (993, 961)  is : -470.0
# flow of (993, 994)  is : 0
# flow of (993, 1025)  is : 470.0
# flow of (994, 962)  is : -534.0
# flow of (994, 993)  is : 0
# flow of (994, 995)  is : 0
# flow of (994, 1025)  is : 534.0
# flow of (995, 963)  is : -396.0
# flow of (995, 994)  is : 0
# flow of (995, 996)  is : 0
# flow of (995, 1025)  is : 396.0
# flow of (996, 964)  is : -301.0
# flow of (996, 995)  is : 0
# flow of (996, 997)  is : 0
# flow of (996, 1025)  is : 301.0
# flow of (997, 965)  is : -376.0
# flow of (997, 996)  is : 0
# flow of (997, 998)  is : 0
# flow of (997, 1025)  is : 376.0
# flow of (998, 966)  is : -389.0
# flow of (998, 997)  is : 0
# flow of (998, 999)  is : 0
# flow of (998, 1025)  is : 389.0
# flow of (999, 967)  is : -205.0
# flow of (999, 998)  is : 0
# flow of (999, 1000)  is : 0
# flow of (999, 1025)  is : 205.0
# flow of (1000, 968)  is : -156.0
# flow of (1000, 999)  is : 0
# flow of (1000, 1001)  is : 0
# flow of (1000, 1025)  is : 156.0
# flow of (1001, 969)  is : -209.0
# flow of (1001, 1000)  is : 0
# flow of (1001, 1002)  is : 0
# flow of (1001, 1025)  is : 209.0
# flow of (1002, 970)  is : -219.0
# flow of (1002, 1001)  is : 0
# flow of (1002, 1003)  is : 0
# flow of (1002, 1025)  is : 219.0
# flow of (1003, 971)  is : -114.0
# flow of (1003, 1002)  is : 0
# flow of (1003, 1004)  is : 0
# flow of (1003, 1025)  is : 114.0
# flow of (1004, 972)  is : -143.0
# flow of (1004, 1003)  is : 0
# flow of (1004, 1005)  is : 0
# flow of (1004, 1025)  is : 143.0
# flow of (1005, 973)  is : -81.0
# flow of (1005, 1004)  is : 0
# flow of (1005, 1006)  is : 0
# flow of (1005, 1025)  is : 81.0
# flow of (1006, 974)  is : -428.0
# flow of (1006, 1005)  is : 0
# flow of (1006, 1007)  is : 0
# flow of (1006, 1025)  is : 428.0
# flow of (1007, 975)  is : -463.0
# flow of (1007, 1006)  is : 0
# flow of (1007, 1008)  is : 0
# flow of (1007, 1025)  is : 463.0
# flow of (1008, 976)  is : -513.0
# flow of (1008, 1007)  is : 0
# flow of (1008, 1009)  is : 0
# flow of (1008, 1025)  is : 513.0
# flow of (1009, 977)  is : -400.0
# flow of (1009, 1008)  is : 0
# flow of (1009, 1010)  is : 0
# flow of (1009, 1025)  is : 400.0
# flow of (1010, 978)  is : -495.0
# flow of (1010, 1009)  is : 0
# flow of (1010, 1011)  is : 0
# flow of (1010, 1025)  is : 495.0
# flow of (1011, 979)  is : -111.0
# flow of (1011, 1010)  is : 0
# flow of (1011, 1012)  is : 0
# flow of (1011, 1025)  is : 111.0
# flow of (1012, 980)  is : -75.0
# flow of (1012, 1011)  is : 0
# flow of (1012, 1013)  is : 0
# flow of (1012, 1025)  is : 75.0
# flow of (1013, 981)  is : -146.0
# flow of (1013, 1012)  is : 0
# flow of (1013, 1014)  is : 0
# flow of (1013, 1025)  is : 146.0
# flow of (1014, 982)  is : -209.0
# flow of (1014, 1013)  is : 0
# flow of (1014, 1015)  is : 0
# flow of (1014, 1025)  is : 209.0
# flow of (1015, 983)  is : -377.0
# flow of (1015, 1014)  is : 0
# flow of (1015, 1016)  is : 0
# flow of (1015, 1025)  is : 377.0
# flow of (1016, 984)  is : -73.0
# flow of (1016, 1015)  is : 0
# flow of (1016, 1017)  is : 0
# flow of (1016, 1025)  is : 73.0
# flow of (1017, 985)  is : -698.0
# flow of (1017, 1016)  is : 0
# flow of (1017, 1018)  is : 0
# flow of (1017, 1025)  is : 698.0
# flow of (1018, 986)  is : -180.0
# flow of (1018, 1017)  is : 0
# flow of (1018, 1019)  is : 0
# flow of (1018, 1025)  is : 180.0
# flow of (1019, 987)  is : -469.0
# flow of (1019, 1018)  is : 0
# flow of (1019, 1020)  is : 0
# flow of (1019, 1025)  is : 469.0
# flow of (1020, 988)  is : -317.0
# flow of (1020, 1019)  is : 0
# flow of (1020, 1021)  is : 0
# flow of (1020, 1025)  is : 317.0
# flow of (1021, 989)  is : -259.0
# flow of (1021, 1020)  is : 0
# flow of (1021, 1022)  is : 0
# flow of (1021, 1025)  is : 259.0
# flow of (1022, 990)  is : -212.0
# flow of (1022, 1021)  is : 0
# flow of (1022, 1023)  is : 0
# flow of (1022, 1025)  is : 212.0
# flow of (1023, 991)  is : -42.0
# flow of (1023, 1022)  is : 0
# flow of (1023, 1024)  is : 0
# flow of (1023, 1025)  is : 42.0
# flow of (1024, 992)  is : -346.0
# flow of (1024, 1023)  is : 0
# flow of (1024, 1025)  is : 346.0
# flow of (1025, 993)  is : -470.0
# flow of (1025, 994)  is : -534.0
# flow of (1025, 995)  is : -396.0
# flow of (1025, 996)  is : -301.0
# flow of (1025, 997)  is : -376.0
# flow of (1025, 998)  is : -389.0
# flow of (1025, 999)  is : -205.0
# flow of (1025, 1000)  is : -156.0
# flow of (1025, 1001)  is : -209.0
# flow of (1025, 1002)  is : -219.0
# flow of (1025, 1003)  is : -114.0
# flow of (1025, 1004)  is : -143.0
# flow of (1025, 1005)  is : -81.0
# flow of (1025, 1006)  is : -428.0
# flow of (1025, 1007)  is : -463.0
# flow of (1025, 1008)  is : -513.0
# flow of (1025, 1009)  is : -400.0
# flow of (1025, 1010)  is : -495.0
# flow of (1025, 1011)  is : -111.0
# flow of (1025, 1012)  is : -75.0
# flow of (1025, 1013)  is : -146.0
# flow of (1025, 1014)  is : -209.0
# flow of (1025, 1015)  is : -377.0
# flow of (1025, 1016)  is : -73.0
# flow of (1025, 1017)  is : -698.0
# flow of (1025, 1018)  is : -180.0
# flow of (1025, 1019)  is : -469.0
# flow of (1025, 1020)  is : -317.0
# flow of (1025, 1021)  is : -259.0
# flow of (1025, 1022)  is : -212.0
# flow of (1025, 1023)  is : -42.0
# flow of (1025, 1024)  is : -346.0
